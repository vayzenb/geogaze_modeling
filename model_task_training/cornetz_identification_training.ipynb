# %%
import os
import time
import csv
import json
import io
import shlex
import subprocess
from pathlib import Path
from collections import defaultdict

import numpy as np
import pandas as pd
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision

# %%
# put all of the main settings in one place
# this makes it easy to check the paths, training settings, and loss weights before running

config = {
    # data paths
    "train_images": "/zpool/vladlab/data_drive/stimulus_sets/geogaze_COCO_stim/coco_working/working_v3/train_working3",
    "train_csv": "/zpool/vladlab/data_drive/stimulus_sets/geogaze_COCO_stim/coco_working/working_v3/instances_train_filtered3_bboxes.csv",
    "val_images": "/zpool/vladlab/data_drive/stimulus_sets/geogaze_COCO_stim/coco_working/working_v3/val_working3",
    "val_csv": "/zpool/vladlab/data_drive/stimulus_sets/geogaze_COCO_stim/coco_working/working_v3/instances_val_filtered3_bboxes.csv",

    # where to save the model checkpoints and label map
    "output_path": "/zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2",

    # task settings
    "num_classes": 70, #classes present in the training dataset 
    "num_queries": 10, #how many objects to find in each image (no-object included)

    # transformer head settings
    "d_model": 256,
    "nhead": 8,
    "num_decoder_layers": 4,
    "dim_feedforward": 1024,
    "dropout": 0.1,

    # training settings
    "epochs": 200,
    "batch_size": 16,
    "workers": 4,
    "lr": 1e-4,
    "backbone_lr": 1e-4,
    "weight_decay": 1e-4,
    "ngpus": 1,
    "resume": None,

    # matching costs
    "cost_class": 1.0,
    "cost_bbox": 5.0,
    "cost_giou": 2.0,

    # loss weights 
    "no_object_weight": 0.1,
    "loss_bbox": 5.0,
    "loss_giou": 2.0,
}

# %%
# import hungarian matching
# this is used to match each predicted query to the best ground-truth object

from scipy.optimize import linear_sum_assignment

print("using scipy hungarian matching")
# Out:
# using scipy hungarian matching

# %%
# pick the gpu with the most free memory
# this is useful when more than one gpu is available on the server

def set_gpus(n=1):
    cmd = "nvidia-smi --query-gpu=index,memory.free,memory.total --format=csv,nounits"
    gpu_info = subprocess.run(shlex.split(cmd), check=True, stdout=subprocess.PIPE).stdout

    gpus = pd.read_csv(io.BytesIO(gpu_info), sep=", ", engine="python")
    gpus = gpus[gpus["memory.total [MiB]"] > 10000]

    # if cuda devices are already restricted, only choose from those
    if os.environ.get("CUDA_VISIBLE_DEVICES") is not None:
        visible = [int(i) for i in os.environ["CUDA_VISIBLE_DEVICES"].split(",")]
        gpus = gpus[gpus["index"].isin(visible)]

    gpus = gpus.sort_values("memory.free [MiB]", ascending=False)

    os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
    os.environ["CUDA_VISIBLE_DEVICES"] = ",".join(str(i) for i in gpus["index"].iloc[:n])


# set the gpu before making the model
if config["ngpus"] > 0:
    set_gpus(config["ngpus"])

# use cuda if we asked for a gpu and one is available
device = torch.device("cuda" if torch.cuda.is_available() and config["ngpus"] > 0 else "cpu")

print("device:", device)
print("torch:", torch.__version__)
print("torchvision:", torchvision.__version__)
# Out:
# device: cuda
# torch: 2.7.1
# torchvision: 0.22.0

# %%
# make a label map from the training csv
# each category name gets a number from 0 to num_classes - 1

def build_label_map_from_csv(csv_path, expected_classes=None):
    labels = set()

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)

        for row in reader:
            labels.add(row["category_name"].strip())

    labels = sorted(labels)

    # sanity check that the dataset has the number of classes we expect
    if expected_classes is not None and len(labels) != expected_classes:
        print(f"warning: found {len(labels)} classes, but expected {expected_classes}")
        print(f"csv checked: {csv_path}")

    label_to_idx = {label: i for i, label in enumerate(labels)}
    idx_to_label = {i: label for label, i in label_to_idx.items()}

    return label_to_idx, idx_to_label

# %%
# box helper functions
# the model predicts boxes as cx, cy, w, h
# the dataset gives boxes as xyxy
# the loss needs both formats, so these functions convert between them

def xyxy_to_cxcywh(xyxy):
    # split the box into the left, top, right, and bottom edges
    x1, y1, x2, y2 = xyxy.unbind(-1)

    # center x and center y are halfway between the two edges
    cx = (x1 + x2) * 0.5
    cy = (y1 + y2) * 0.5

    # width and height are the distance between the edges
    # clamp keeps them from becoming zero or negative
    w = (x2 - x1).clamp(min=1e-6)
    h = (y2 - y1).clamp(min=1e-6)

    return torch.stack([cx, cy, w, h], dim=-1)


def cxcywh_to_xyxy(cxcywh):
    # split the box into center x, center y, width, and height
    cx, cy, w, h = cxcywh.unbind(-1)

    # move half the width/height away from the center to get the edges
    x1 = cx - 0.5 * w
    y1 = cy - 0.5 * h
    x2 = cx + 0.5 * w
    y2 = cy + 0.5 * h

    return torch.stack([x1, y1, x2, y2], dim=-1)


def box_area_xyxy(boxes):
    # area is width times height
    # clamp keeps bad boxes from having negative area
    x1, y1, x2, y2 = boxes.unbind(-1)

    return (x2 - x1).clamp(min=0) * (y2 - y1).clamp(min=0)


def generalized_box_iou_xyxy(boxes1, boxes2):
    # calculate generalized iou between every box in boxes1 and every box in boxes2
    # boxes should already be in xyxy format

    # get the top-left and bottom-right corners of the overlapping region
    lt = torch.max(boxes1[:, None, :2], boxes2[None, :, :2])
    rb = torch.min(boxes1[:, None, 2:], boxes2[None, :, 2:])

    # if the boxes do not overlap, clamp makes the overlap width/height zero
    wh = (rb - lt).clamp(min=0)
    inter = wh[..., 0] * wh[..., 1]

    # get the area of each box
    area1 = box_area_xyxy(boxes1)[:, None]
    area2 = box_area_xyxy(boxes2)[None, :]

    # union is both box areas minus the overlap counted twice
    union = area1 + area2 - inter

    # regular iou is overlap divided by union
    iou = inter / union.clamp(min=1e-6)

    # now find the smallest box that contains both boxes
    lt_c = torch.min(boxes1[:, None, :2], boxes2[None, :, :2])
    rb_c = torch.max(boxes1[:, None, 2:], boxes2[None, :, 2:])

    # area of that enclosing box
    wh_c = (rb_c - lt_c).clamp(min=0)
    area_c = wh_c[..., 0] * wh_c[..., 1]

    # generalized iou penalizes boxes that are far apart even if they do not overlap
    giou = iou - (area_c - union) / area_c.clamp(min=1e-6)

    return giou

# %%
# dataset for the bbox csv
# this reads in all object boxes for each image and keeps them grouped by image

class DetectionBBoxCSVDataset(torch.utils.data.Dataset):
    def __init__(self, images_root, csv_path, label_to_idx, transform):
        self.images_root = Path(images_root)
        self.csv_path = Path(csv_path)
        self.label_to_idx = label_to_idx
        self.transform = transform

        # save all boxes for each image
        img_to_anns = defaultdict(list)

        with open(self.csv_path, "r", newline="") as f:
            reader = csv.DictReader(f)
            for row in reader:
                img_name = row["image_file_name"]
                cat_name = row["category_name"].strip()

                # only use categories in the label map
                if cat_name not in self.label_to_idx:
                    continue
                # csv boxes are x, y, width, height
                x = float(row["bbox_x"])
                y = float(row["bbox_y"])
                w = float(row["bbox_w"])
                h = float(row["bbox_h"])

                # model loss wants x1, y1, x2, y2
                box = [x, y, x + w, y + h]
                label = self.label_to_idx[cat_name]

                img_to_anns[img_name].append((label, box))
        # only keep images that are actually in the image folder
        self.items = []
        missing = 0
        for img_name, anns in img_to_anns.items():
            img_path = self.images_root / img_name
            if img_path.exists():
                self.items.append((img_path, anns))
            else:
                missing += 1

        # stop early if something is wrong with the paths
        if len(self.items) == 0:
            raise RuntimeError(f"no matched images found in {self.images_root}")

        if missing:
            print(f"warning: {missing} images from the csv were missing from {self.images_root}")
    def __len__(self):
        return len(self.items)
    def __getitem__(self, idx):
        img_path, ann_list = self.items[idx]

        image = Image.open(img_path).convert("RGB")
        orig_w, orig_h = image.size

        labels = []
        boxes = []
        for label, (x1, y1, x2, y2) in ann_list:
            # normalize boxes by the original image size
            x1 = max(0.0, min(1.0, x1 / orig_w))
            x2 = max(0.0, min(1.0, x2 / orig_w))
            y1 = max(0.0, min(1.0, y1 / orig_h))
            y2 = max(0.0, min(1.0, y2 / orig_h))

            # skip boxes that became invalid for any reason
            if x2 <= x1 or y2 <= y1:
                continue

            labels.append(label)
            boxes.append([x1, y1, x2, y2])

        labels = torch.tensor(labels, dtype=torch.long)
        boxes = torch.tensor(boxes, dtype=torch.float32)

        image = self.transform(image)

        target = {"boxes_xyxy": boxes, "labels": labels, "image_path": str(img_path)}
        return image, target
# each image can have a different number of boxes
# this keeps the images and targets as lists instead of forcing them into one tensor

def detection_collate(batch):
    images, targets = zip(*batch)
    return list(images), list(targets)

# %%
# set up image transforms
# cornet expects 224 x 224 images with imagenet normalization
normalize = torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((224, 224)),
    torchvision.transforms.ToTensor(),
    normalize,
])

# %%
# set up the output folder
# this is where checkpoints and the label map will be saved

outdir = Path(config["output_path"])
outdir.mkdir(parents=True, exist_ok=True)
# make the category-name-to-number mapping from the training csv
# save it so we know exactly what each class index means later

label_to_idx, idx_to_label = build_label_map_from_csv(
    config["train_csv"],
    expected_classes=config["num_classes"],
)
label_map_path = outdir / "label_map.json"
with open(label_map_path, "w") as f:
    json.dump({"label_to_idx": label_to_idx, "idx_to_label": idx_to_label}, f, indent=2)

print("saved label map to:", label_map_path)
# Out:
# saved label map to: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/label_map.json

# %%
# make the train and validation datasets
# these read the csv files and load the matching images

train_ds = DetectionBBoxCSVDataset(config["train_images"], config["train_csv"], label_to_idx, transform)
val_ds = DetectionBBoxCSVDataset(config["val_images"], config["val_csv"], label_to_idx, transform)

# make the dataloaders
# shuffle train so the model sees images in a different order each epoch
# do not shuffle validation so it stays consistent

train_loader = torch.utils.data.DataLoader(
    train_ds,
    batch_size=config["batch_size"],
    shuffle=True,
    num_workers=config["workers"],
    pin_memory=(device.type == "cuda"),
    collate_fn=detection_collate,
)

val_loader = torch.utils.data.DataLoader(
    val_ds,
    batch_size=config["batch_size"],
    shuffle=False,
    num_workers=config["workers"],
    pin_memory=(device.type == "cuda"),
    collate_fn=detection_collate,
)

# quick check that the datasets loaded correctly
print("number of training images:", len(train_ds))
print("number of validation images:", len(val_ds))
# Out:
# number of training images: 33953
# number of validation images: 1436

# %%
# positional encoding for the transformer
# this gives each spot in the feature map some information about where it is

class PositionEmbeddingSine(nn.Module):
    def __init__(self, num_pos_feats=128, temperature=10000):
        super().__init__()

        self.num_pos_feats = num_pos_feats
        self.temperature = temperature

    def forward(self, x):
        b, _, h, w = x.shape
        device = x.device

        # make a grid of y and x positions from 0 to 1
        y_embed = torch.linspace(0, 1, h, device=device).unsqueeze(1).repeat(1, w)
        x_embed = torch.linspace(0, 1, w, device=device).unsqueeze(0).repeat(h, 1)

        # make different frequencies for the sine/cosine position values
        dim_t = torch.arange(self.num_pos_feats, device=device, dtype=torch.float32)
        dim_t = self.temperature ** (2 * (dim_t // 2) / self.num_pos_feats)

        # turn each x/y location into a vector of sine/cosine values
        pos_x = x_embed[..., None] / dim_t
        pos_y = y_embed[..., None] / dim_t

        pos_x = torch.stack((pos_x[..., 0::2].sin(), pos_x[..., 1::2].cos()), dim=3).flatten(2)
        pos_y = torch.stack((pos_y[..., 0::2].sin(), pos_y[..., 1::2].cos()), dim=3).flatten(2)

        # combine y and x position information
        pos = torch.cat((pos_y, pos_x), dim=2)

        # put it in the same shape as a feature map: b, channels, h, w
        pos = pos.permute(2, 0, 1).unsqueeze(0).repeat(b, 1, 1, 1)

        return pos

# %%
# point python to the local cornet repo

cornet_repo = Path("/zpool/vladlab/active_drive/omaltz/git_repos/CORnet")
import sys
sys.path.insert(0, str(cornet_repo))
import cornet
print("imported cornet from:", cornet.__file__)
# Out:
# imported cornet from: /zpool/vladlab/active_drive/omaltz/git_repos/CORnet/cornet/__init__.py

# %%
# set up cornet-z
cornet_base = cornet.cornet_z(pretrained=False, map_location=device)
# unwrap if cornet gives back a dataparallel model
if hasattr(cornet_base, "module"):
    cornet_base = cornet_base.module

# sanity check that the model has the layers we expect
print("cornet base type:", type(cornet_base))
print("has IT layer:", hasattr(cornet_base, "IT"))
print("has decoder:", hasattr(cornet_base, "decoder"))
# Out:
# cornet base type: <class 'torch.nn.modules.container.Sequential'>
# has IT layer: True
# has decoder: True

# %%
# cornet-z feature extractor
# this runs the full cornet model, but saves the IT layer output with a hook
class CornetITSpatialBackbone(nn.Module):
    def __init__(self, cornet_model):
        super().__init__()

        self.model = cornet_model
        self.feat = None
        # sanity check that cornet-z has the IT layer
        if not hasattr(self.model, "IT"):
            raise ValueError("cornet model does not have an IT layer")

        # this hook saves the IT activations during the forward pass
        def hook_fn(module, inp, out):
            self.feat = out
        self.model.IT.register_forward_hook(hook_fn)

    def forward(self, x):
        # run cornet normally
        # the hook above grabs the IT feature map while it runs
        _ = self.model(x)
        if self.feat is None:
            raise RuntimeError("IT hook did not capture an output")
        return self.feat

# %%
# full model
# cornet-z gives us the IT feature map
# the transformer head uses object queries to predict classes and boxes

class CornetITDETR(nn.Module):
    def __init__(
        self,
        cornet_base,
        num_classes,
        num_queries=10,
        d_model=256,
        nhead=8,
        num_decoder_layers=4,
        dim_feedforward=1024,
        dropout=0.1,
    ):
        super().__init__()

        self.num_classes = num_classes
        self.num_queries = num_queries
        self.no_object_class = num_classes
        # get the IT feature map from cornet-z
        self.backbone = CornetITSpatialBackbone(cornet_base)
        # this gets made during the first forward pass
        # we need to see the IT feature size before making the projection layer
        self.proj = None
        self.d_model = d_model
        # tells the transformer where each feature-map location came from
        self.pos_embed = PositionEmbeddingSine(num_pos_feats=d_model // 2)
        # transformer decoder
        # the object queries attend to the IT feature map
        decoder_layer = nn.TransformerDecoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True,
        )
        self.decoder = nn.TransformerDecoder(decoder_layer, num_layers=num_decoder_layers)
        # learned object queries
        # each query can predict one object
        self.query_embed = nn.Embedding(num_queries, d_model)

        # class prediction
        # +1 is for the no-object class
        self.class_head = nn.Linear(d_model, num_classes + 1)

        # box prediction
        # sigmoid at the end of forward keeps boxes between 0 and 1
        self.box_head = nn.Sequential(nn.Linear(d_model, d_model), nn.ReLU(), nn.Linear(d_model, 4))

    def _ensure_proj(self, feat):
        # make the 1x1 projection once we know how many IT channels there are
        if self.proj is None:
            in_ch = feat.shape[1]
            self.proj = nn.Conv2d(in_ch, self.d_model, kernel_size=1).to(feat.device)
            self.add_module("input_proj", self.proj)

    def forward(self, x):
        # get IT feature map
        feat = self.backbone(x)
        # project IT features into transformer dimension
        self._ensure_proj(feat)
        src = self.proj(feat)
        # add spatial position information
        pos = self.pos_embed(src)
        b, d, h, w = src.shape
        # flatten feature mapinto tokens for the transformer
        src_tokens = src.flatten(2).permute(0, 2, 1)
        pos_tokens = pos.flatten(2).permute(0, 2, 1)
        # repeat learned queries for each image in the batch
        q = self.query_embed.weight.unsqueeze(0).repeat(b, 1, 1)
        # each query attends to t feature tokens
        hs = self.decoder(tgt=q, memory=src_tokens + pos_tokens)
        # predict object class and box for each query
        logits = self.class_head(hs)
        boxes = torch.sigmoid(self.box_head(hs))
        return {"pred_logits": logits, "pred_boxes": boxes}

# %%
# match predicted queries to real objects
# this decides which query should be compared to which ground-truth box

def hungarian_matcher(
    pred_logits,
    pred_boxes,
    tgt_labels,
    tgt_boxes_xyxy,
    cost_class=1.0,
    cost_bbox=5.0,
    cost_giou=2.0,
):
    q, _ = pred_logits.shape
    n = tgt_labels.shape[0]
    # if there are no objects in the image, there is nothing to match
    if n == 0:
        return torch.empty((0,), dtype=torch.long), torch.empty((0,), dtype=torch.long)
    # class cost
    # lower cost means the query gives higher probability to the correct class
    prob = pred_logits.softmax(-1)
    cost_cls = -prob[:, tgt_labels]

    # box cost
    # convert predicted boxes to xyxy so they match the target box format
    pred_xyxy = cxcywh_to_xyxy(pred_boxes).clamp(0, 1)
    cost_l1 = torch.cdist(pred_xyxy, tgt_boxes_xyxy, p=1)

    # giou cost
    # better overlap should give a lower matching cost
    giou = generalized_box_iou_xyxy(pred_xyxy, tgt_boxes_xyxy)
    cost_giou_matrix = -giou

    # final matching cost
    cost = cost_class * cost_cls + cost_bbox * cost_l1 + cost_giou * cost_giou_matrix

    # scipy does the actual hungarian matching
    cost = cost.detach().cpu().numpy()
    pred_idx, tgt_idx = linear_sum_assignment(cost)
    return torch.as_tensor(pred_idx, dtype=torch.long), torch.as_tensor(tgt_idx, dtype=torch.long)

# %%
# set loss for the detr-style head
# first match predictions to targets, then calculate class and box losses

class SetCriterion(nn.Module):
    def __init__(
        self,
        num_classes,
        no_object_weight=0.1,
        cost_class=1.0,
        cost_bbox=5.0,
        cost_giou=2.0,
        loss_bbox=5.0,
        loss_giou=2.0,
    ):
        super().__init__()

        self.num_classes = num_classes
        self.no_object = num_classes
        # costs are used for matching
        self.cost_class = cost_class
        self.cost_bbox = cost_bbox
        self.cost_giou = cost_giou
        # weights are used for the final loss
        self.loss_bbox = loss_bbox
        self.loss_giou = loss_giou

        # downweight the no-object class so it does not dominate training
        weight = torch.ones(num_classes + 1)
        weight[self.no_object] = no_object_weight
        self.register_buffer("ce_weight", weight)

    def forward(self, outputs, targets):
        pred_logits = outputs["pred_logits"]
        pred_boxes = outputs["pred_boxes"]
        b, q, _ = pred_logits.shape
        total_ce = 0.0
        total_l1 = 0.0
        total_giou = 0.0
        n_targets = 0
        for i in range(b):
            tgt_labels = targets[i]["labels"]
            tgt_xyxy = targets[i]["boxes_xyxy"]

            n_targets += tgt_labels.shape[0]

            # match predicted queries to the real boxes in this image
            pred_idx, tgt_idx = hungarian_matcher(
                pred_logits[i],
                pred_boxes[i],
                tgt_labels,
                tgt_xyxy,
                cost_class=self.cost_class,
                cost_bbox=self.cost_bbox,
                cost_giou=self.cost_giou,
            )
            # start by saying every query predicted no object
            target_classes = torch.full((q,), self.no_object, dtype=torch.long, device=pred_logits.device)
            # then fill in the matched queries with their real class labels
            if pred_idx.numel() > 0:
                target_classes[pred_idx.to(pred_logits.device)] = tgt_labels[tgt_idx].to(pred_logits.device)
            # class loss is calculated for every query
            ce = F.cross_entropy(pred_logits[i], target_classes, weight=self.ce_weight)
            total_ce += ce
            # box loss is only calculated for matched predictions
            if pred_idx.numel() > 0:
                p_boxes = pred_boxes[i, pred_idx.to(pred_boxes.device)]
                p_xyxy = cxcywh_to_xyxy(p_boxes).clamp(0, 1)
                t_xyxy = tgt_xyxy[tgt_idx].to(pred_boxes.device)

                l1 = F.l1_loss(p_xyxy, t_xyxy, reduction="mean")
                giou = generalized_box_iou_xyxy(p_xyxy, t_xyxy).diag()
                giou_loss = (1.0 - giou).mean()

                total_l1 += l1
                total_giou += giou_loss
        # average losses over the batch
        denom = max(b, 1)

        losses = {
            "loss_ce": total_ce / denom,
            "loss_bbox": total_l1 / denom,
            "loss_giou": total_giou / denom,
        }
        losses["loss_total"] = losses["loss_ce"] + self.loss_bbox * losses["loss_bbox"] + self.loss_giou * losses["loss_giou"]
        losses["n_targets"] = n_targets

        return losses

# %%
# run one full pass through either the train or validation set
# train=True updates the model
# train=False just checks the loss

def run_epoch(model, criterion, loader, optimizer, device, train=True, print_every=50):
    model.train() if train else model.eval()

    meters = {"loss_total": [], "loss_ce": [], "loss_bbox": [], "loss_giou": []}
    t0 = time.time()
    for it, (images, targets) in enumerate(loader):
        images = torch.stack(images, dim=0).to(device)
        # move the target boxes and labels to the gpu
        target_list = []
        for t in targets:
            target_list.append({
                "boxes_xyxy": t["boxes_xyxy"].to(device),
                "labels": t["labels"].to(device),
                "image_path": t.get("image_path", ""),
            })
        # only track gradients during training
        with torch.set_grad_enabled(train):
            outputs = model(images)
            losses = criterion(outputs, target_list)
            if train:
                optimizer.zero_grad(set_to_none=True)
                losses["loss_total"].backward()
                optimizer.step()
        # save losses so we can average them later
        for key in meters:
            meters[key].append(float(losses[key].detach().cpu()))

        # print progress every so often
        if (it + 1) % print_every == 0:
            dt = time.time() - t0
            split = "train" if train else "val"
            print(
                f"{split} iter {it + 1}/{len(loader)} "
                f"loss={np.mean(meters['loss_total'][-print_every:]):.4f} "
                f"ce={np.mean(meters['loss_ce'][-print_every:]):.4f} "
                f"bbox={np.mean(meters['loss_bbox'][-print_every:]):.4f} "
                f"giou={np.mean(meters['loss_giou'][-print_every:]):.4f} "
                f"time={dt:.1f}s"
            )

            t0 = time.time()
    # return average loss for the epoch
    return {key: float(np.mean(values)) for key, values in meters.items()}

# %%
# build the full model and move it to the gpu
# cornet-z gives the IT features, then the transformer head predicts classes and boxes

model = CornetITDETR(
    cornet_base=cornet_base,
    num_classes=config["num_classes"],
    num_queries=config["num_queries"],
    d_model=config["d_model"],
    nhead=config["nhead"],
    num_decoder_layers=config["num_decoder_layers"],
    dim_feedforward=config["dim_feedforward"],
    dropout=config["dropout"],
).to(device)

print(model)
# Out:
# CornetITDETR(
#   (backbone): CornetITSpatialBackbone(
#     (model): Sequential(
#       (V1): CORblock_Z(
#         (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#         (nonlin): ReLU(inplace=True)
#         (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         (output): Identity()
#       )
#       (V2): CORblock_Z(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (nonlin): ReLU(inplace=True)
#         (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         (output): Identity()
#       )
#       (V4): CORblock_Z(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (nonlin): ReLU(inplace=True)
#         (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         (output): Identity()
#       )
#       (IT): CORblock_Z(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (nonlin): ReLU(inplace=True)
#         (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         (output): Identity()
#       )
#       (decoder): Sequential(
#         (avgpool): AdaptiveAvgPool2d(output_size=1)
#         (flatten): Flatten()
#         (linear): Linear(in_features=512, out_features=1000, bias=True)
#         (output): Identity()
#       )
#     )
#   )
#   (pos_embed): PositionEmbeddingSine()
#   (decoder): TransformerDecoder(
#     (layers): ModuleList(
#       (0-3): 4 x TransformerDecoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#         )
#         (multihead_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#         )
#         (linear1): Linear(in_features=256, out_features=1024, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=1024, out_features=256, bias=True)
#         (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (norm3): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (dropout3): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (query_embed): Embedding(10, 256)
#   (class_head): Linear(in_features=256, out_features=71, bias=True)
#   (box_head): Sequential(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=4, bias=True)
#   )
# )

# %%
# run one dummy batch so the projection layer gets created
# this is needed before setting up the optimizer

images, _ = next(iter(train_loader))
images = torch.stack(images, dim=0).to(device)

with torch.no_grad():
    _ = model(images)

# %%
# set up optimizer
# use one learning rate for cornet-z and one for the transformer head

backbone_params = []
head_params = []

for name, p in model.named_parameters():
    if not p.requires_grad:
        continue

    if name.startswith("backbone."):
        backbone_params.append(p)
    else:
        head_params.append(p)

optimizer = torch.optim.AdamW(
    [
        {"params": backbone_params, "lr": config["backbone_lr"]},
        {"params": head_params, "lr": config["lr"]},
    ],
    weight_decay=config["weight_decay"],
)

start_epoch = 0
best_val = float("inf")

print("backbone params:", len(backbone_params))
print("head params:", len(head_params))
# Out:
# backbone params: 10
# head params: 81

# %%
# set up the loss
# this does matching, class loss, bbox loss, and giou loss

criterion = SetCriterion(
    num_classes=config["num_classes"],
    no_object_weight=config["no_object_weight"],
    cost_class=config["cost_class"],
    cost_bbox=config["cost_bbox"],
    cost_giou=config["cost_giou"],
    loss_bbox=config["loss_bbox"],
    loss_giou=config["loss_giou"],
).to(device)

# %%
# run training
# each epoch does one train pass, one validation pass, and then saves checkpoints

for epoch in range(start_epoch, config["epochs"]):
    print("\n" + "=" * 100)
    print(f"epoch {epoch}/{config['epochs'] - 1}")

    # train for one epoch
    train_stats = run_epoch(
        model=model,
        criterion=criterion,
        loader=train_loader,
        optimizer=optimizer,
        device=device,
        train=True,
        print_every=50,
    )
    # check validation loss after training
    val_stats = run_epoch(
        model=model,
        criterion=criterion,
        loader=val_loader,
        optimizer=optimizer,
        device=device,
        train=False,
        print_every=50,
    )

    print("train:", train_stats)
    print("val:  ", val_stats)
    # track the best validation loss so far
    is_best = val_stats["loss_total"] < best_val
    if is_best:
        best_val = val_stats["loss_total"]

    # save everything needed to restart training later
    ckpt = {
        "epoch": epoch,
        "best_val": best_val,
        "model": model.state_dict(),
        "optimizer": optimizer.state_dict(),
        "config": config,
        "train_stats": train_stats,
        "val_stats": val_stats,
    }

    latest_path = outdir / "latest.pth.tar"
    epoch_path = outdir / f"epoch_{epoch:03d}.pth.tar"
    # always save latest and this epoch
    torch.save(ckpt, latest_path)
    torch.save(ckpt, epoch_path)

    print(f"saved epoch checkpoint: {epoch_path}")

    # also save a separate copy if this is the best model so far
    if is_best:
        best_path = outdir / "best.pth.tar"
        torch.save(ckpt, best_path)
        print(f"saved best checkpoint: {best_path}, val loss = {best_val:.4f}")

print("done")
# Out:
# ====================================================================================================
# epoch 0/199
# train iter 50/2123 loss=5.0926 ce=3.3218 bbox=0.1194 giou=0.5868 time=6.6s
# train iter 100/2123 loss=4.6875 ce=3.1978 bbox=0.0922 giou=0.5142 time=6.1s
# train iter 150/2123 loss=4.5238 ce=3.0857 bbox=0.0878 giou=0.4996 time=5.5s
# train iter 200/2123 loss=4.4891 ce=3.0274 bbox=0.0906 giou=0.5042 time=6.1s
# train iter 250/2123 loss=4.4232 ce=2.9963 bbox=0.0865 giou=0.4971 time=5.9s
# train iter 300/2123 loss=4.3774 ce=2.9728 bbox=0.0839 giou=0.4925 time=6.2s
# train iter 350/2123 loss=4.3978 ce=2.9475 bbox=0.0894 giou=0.5016 time=5.8s
# train iter 400/2123 loss=4.2299 ce=2.8504 bbox=0.0844 giou=0.4788 time=5.9s
# train iter 450/2123 loss=4.3081 ce=2.9013 bbox=0.0864 giou=0.4874 time=6.3s
# train iter 500/2123 loss=4.2950 ce=2.8911 bbox=0.0837 giou=0.4926 time=5.8s
# train iter 550/2123 loss=4.2736 ce=2.8649 bbox=0.0852 giou=0.4913 time=6.1s
# train iter 600/2123 loss=4.2511 ce=2.8299 bbox=0.0856 giou=0.4966 time=5.8s
# train iter 650/2123 loss=4.2283 ce=2.7938 bbox=0.0860 giou=0.5023 time=6.2s
# train iter 700/2123 loss=4.2778 ce=2.8424 bbox=0.0870 giou=0.5003 time=6.0s
# train iter 750/2123 loss=4.1903 ce=2.7694 bbox=0.0855 giou=0.4966 time=6.0s
# train iter 800/2123 loss=4.1690 ce=2.7612 bbox=0.0855 giou=0.4902 time=6.0s
# train iter 850/2123 loss=4.1130 ce=2.7189 bbox=0.0852 giou=0.4841 time=6.1s
# train iter 900/2123 loss=4.1593 ce=2.7401 bbox=0.0857 giou=0.4952 time=6.0s
# train iter 950/2123 loss=4.1459 ce=2.7375 bbox=0.0846 giou=0.4926 time=6.1s
# train iter 1000/2123 loss=4.0348 ce=2.6593 bbox=0.0822 giou=0.4823 time=5.6s
# train iter 1050/2123 loss=4.0863 ce=2.6929 bbox=0.0837 giou=0.4875 time=6.2s
# train iter 1100/2123 loss=4.0826 ce=2.6880 bbox=0.0836 giou=0.4884 time=5.7s
# train iter 1150/2123 loss=4.0632 ce=2.6618 bbox=0.0851 giou=0.4880 time=6.1s
# train iter 1200/2123 loss=4.0348 ce=2.6575 bbox=0.0822 giou=0.4832 time=5.9s
# train iter 1250/2123 loss=3.9738 ce=2.6226 bbox=0.0811 giou=0.4728 time=5.7s
# train iter 1300/2123 loss=3.9285 ce=2.5674 bbox=0.0825 giou=0.4742 time=6.3s
# train iter 1350/2123 loss=4.0106 ce=2.6339 bbox=0.0818 giou=0.4839 time=5.7s
# train iter 1400/2123 loss=4.0529 ce=2.6607 bbox=0.0836 giou=0.4870 time=6.1s
# train iter 1450/2123 loss=3.9835 ce=2.6024 bbox=0.0817 giou=0.4863 time=5.8s
# train iter 1500/2123 loss=3.9686 ce=2.6038 bbox=0.0825 giou=0.4761 time=6.1s
# train iter 1550/2123 loss=4.0214 ce=2.6202 bbox=0.0839 giou=0.4909 time=6.0s
# train iter 1600/2123 loss=3.8863 ce=2.5461 bbox=0.0809 giou=0.4678 time=6.0s
# train iter 1650/2123 loss=3.9381 ce=2.5676 bbox=0.0817 giou=0.4811 time=5.7s
# train iter 1700/2123 loss=3.8872 ce=2.5421 bbox=0.0811 giou=0.4699 time=6.1s
# train iter 1750/2123 loss=3.8904 ce=2.5678 bbox=0.0794 giou=0.4628 time=6.0s
# train iter 1800/2123 loss=3.8980 ce=2.5331 bbox=0.0812 giou=0.4794 time=5.9s
# train iter 1850/2123 loss=3.8880 ce=2.5283 bbox=0.0823 giou=0.4742 time=6.0s
# train iter 1900/2123 loss=3.8689 ce=2.5324 bbox=0.0795 giou=0.4695 time=6.1s
# train iter 1950/2123 loss=3.8698 ce=2.5463 bbox=0.0796 giou=0.4626 time=5.5s
# train iter 2000/2123 loss=3.8319 ce=2.5013 bbox=0.0785 giou=0.4690 time=6.0s
# train iter 2050/2123 loss=3.8532 ce=2.5082 bbox=0.0801 giou=0.4723 time=6.0s
# train iter 2100/2123 loss=3.8317 ce=2.4863 bbox=0.0804 giou=0.4717 time=5.7s
# val iter 50/90 loss=3.9033 ce=2.5535 bbox=0.0807 giou=0.4731 time=3.6s
# train: {'loss_total': 4.127570486944687, 'loss_ce': 2.7298449549650283, 'loss_bbox': 0.08454131637535396, 'loss_giou': 0.48750947460047883}
# val:   {'loss_total': 3.9776437918345136, 'loss_ce': 2.619768020179537, 'loss_bbox': 0.0817446576224433, 'loss_giou': 0.4745762430959278}
# saved epoch checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/epoch_000.pth.tar
# saved best checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/best.pth.tar, val loss = 3.9776
#
# ====================================================================================================
# epoch 1/199
# train iter 50/2123 loss=4.0162 ce=2.6515 bbox=0.0821 giou=0.4771 time=2.9s
# train iter 100/2123 loss=3.8012 ce=2.4437 bbox=0.0805 giou=0.4774 time=2.5s
# train iter 150/2123 loss=3.7664 ce=2.4274 bbox=0.0794 giou=0.4711 time=2.3s
# train iter 200/2123 loss=3.7576 ce=2.4327 bbox=0.0784 giou=0.4664 time=2.6s
# train iter 250/2123 loss=3.7757 ce=2.4708 bbox=0.0776 giou=0.4585 time=2.6s
# train iter 300/2123 loss=3.7538 ce=2.3726 bbox=0.0828 giou=0.4836 time=2.4s
# train iter 350/2123 loss=3.7772 ce=2.4557 bbox=0.0786 giou=0.4641 time=2.5s
# train iter 400/2123 loss=3.7786 ce=2.4499 bbox=0.0790 giou=0.4669 time=2.6s
# train iter 450/2123 loss=3.7046 ce=2.3898 bbox=0.0789 giou=0.4601 time=2.6s
# train iter 500/2123 loss=3.6851 ce=2.3825 bbox=0.0777 giou=0.4572 time=2.5s
# train iter 550/2123 loss=3.7743 ce=2.4040 bbox=0.0816 giou=0.4811 time=2.5s
# train iter 600/2123 loss=3.7075 ce=2.3736 bbox=0.0794 giou=0.4683 time=2.4s
# train iter 650/2123 loss=3.8294 ce=2.4747 bbox=0.0805 giou=0.4760 time=2.5s
# train iter 700/2123 loss=3.8185 ce=2.4670 bbox=0.0809 giou=0.4735 time=2.5s
# train iter 750/2123 loss=3.6631 ce=2.3335 bbox=0.0792 giou=0.4668 time=2.4s
# train iter 800/2123 loss=3.6706 ce=2.3687 bbox=0.0775 giou=0.4571 time=2.5s
# train iter 850/2123 loss=3.7020 ce=2.3800 bbox=0.0783 giou=0.4653 time=2.7s
# train iter 900/2123 loss=3.6327 ce=2.3445 bbox=0.0764 giou=0.4531 time=2.5s
# train iter 950/2123 loss=3.7367 ce=2.4171 bbox=0.0782 giou=0.4642 time=2.6s
# train iter 1000/2123 loss=3.6677 ce=2.3306 bbox=0.0792 giou=0.4706 time=2.7s
# train iter 1050/2123 loss=3.6527 ce=2.3292 bbox=0.0787 giou=0.4650 time=2.5s
# train iter 1100/2123 loss=3.6559 ce=2.3330 bbox=0.0784 giou=0.4655 time=2.5s
# train iter 1150/2123 loss=3.6923 ce=2.3720 bbox=0.0774 giou=0.4666 time=2.4s
# train iter 1200/2123 loss=3.6404 ce=2.3505 bbox=0.0759 giou=0.4551 time=2.4s
# train iter 1250/2123 loss=3.6669 ce=2.3775 bbox=0.0757 giou=0.4554 time=2.4s
# train iter 1300/2123 loss=3.5646 ce=2.2773 bbox=0.0774 giou=0.4501 time=2.6s
# train iter 1350/2123 loss=3.5830 ce=2.2886 bbox=0.0766 giou=0.4556 time=2.5s
# train iter 1400/2123 loss=3.6180 ce=2.3251 bbox=0.0755 giou=0.4576 time=2.4s
# train iter 1450/2123 loss=3.6136 ce=2.3028 bbox=0.0770 giou=0.4629 time=2.4s
# train iter 1500/2123 loss=3.6423 ce=2.3281 bbox=0.0780 giou=0.4621 time=2.6s
# train iter 1550/2123 loss=3.6022 ce=2.3164 bbox=0.0758 giou=0.4534 time=2.8s
# train iter 1600/2123 loss=3.5941 ce=2.3021 bbox=0.0763 giou=0.4553 time=2.5s
# train iter 1650/2123 loss=3.6795 ce=2.3607 bbox=0.0778 giou=0.4650 time=2.5s
# train iter 1700/2123 loss=3.6050 ce=2.3124 bbox=0.0762 giou=0.4557 time=2.4s
# train iter 1750/2123 loss=3.5831 ce=2.2870 bbox=0.0768 giou=0.4560 time=2.6s
# train iter 1800/2123 loss=3.6172 ce=2.3333 bbox=0.0764 giou=0.4511 time=2.5s
# train iter 1850/2123 loss=3.5995 ce=2.3023 bbox=0.0764 giou=0.4577 time=2.5s
# train iter 1900/2123 loss=3.5137 ce=2.2423 bbox=0.0746 giou=0.4491 time=2.7s
# train iter 1950/2123 loss=3.5766 ce=2.2680 bbox=0.0771 giou=0.4615 time=2.7s
# train iter 2000/2123 loss=3.5927 ce=2.2918 bbox=0.0757 giou=0.4611 time=2.6s
# train iter 2050/2123 loss=3.5523 ce=2.2427 bbox=0.0771 giou=0.4621 time=2.4s
# train iter 2100/2123 loss=3.6218 ce=2.3001 bbox=0.0785 giou=0.4645 time=2.4s
# val iter 50/90 loss=3.4841 ce=2.2077 bbox=0.0748 giou=0.4512 time=1.8s
# train: {'loss_total': 3.6760943182447976, 'loss_ce': 2.3606285762798094, 'loss_bbox': 0.0779422505693339, 'loss_giou': 0.4628772439397398}
# val:   {'loss_total': 3.547369737095303, 'loss_ce': 2.2639598336484696, 'loss_bbox': 0.0753828904694981, 'loss_giou': 0.45324772397677104}
# saved epoch checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/epoch_001.pth.tar
# saved best checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/best.pth.tar, val loss = 3.5474
#
# ====================================================================================================
# epoch 2/199
# train iter 50/2123 loss=3.5189 ce=2.2456 bbox=0.0747 giou=0.4500 time=2.9s
# train iter 100/2123 loss=3.5247 ce=2.2319 bbox=0.0759 giou=0.4566 time=2.6s
# train iter 150/2123 loss=3.4686 ce=2.1693 bbox=0.0763 giou=0.4590 time=2.5s
# train iter 200/2123 loss=3.4582 ce=2.2019 bbox=0.0738 giou=0.4436 time=2.5s
# train iter 250/2123 loss=3.4585 ce=2.1982 bbox=0.0735 giou=0.4464 time=2.5s
# train iter 300/2123 loss=3.4428 ce=2.1660 bbox=0.0743 giou=0.4525 time=2.5s
# train iter 350/2123 loss=3.5212 ce=2.2439 bbox=0.0750 giou=0.4511 time=2.6s
# train iter 400/2123 loss=3.5095 ce=2.2059 bbox=0.0765 giou=0.4605 time=2.7s
# train iter 450/2123 loss=3.6017 ce=2.3041 bbox=0.0763 giou=0.4580 time=2.6s
# train iter 500/2123 loss=3.3820 ce=2.1567 bbox=0.0727 giou=0.4309 time=2.5s
# train iter 550/2123 loss=3.5162 ce=2.2248 bbox=0.0768 giou=0.4537 time=2.6s
# train iter 600/2123 loss=3.4986 ce=2.2050 bbox=0.0758 giou=0.4574 time=2.7s
# train iter 650/2123 loss=3.4750 ce=2.2181 bbox=0.0733 giou=0.4452 time=2.6s
# train iter 700/2123 loss=3.4826 ce=2.2557 bbox=0.0718 giou=0.4340 time=2.6s
# train iter 750/2123 loss=3.4710 ce=2.1875 bbox=0.0751 giou=0.4539 time=2.6s
# train iter 800/2123 loss=3.3264 ce=2.1076 bbox=0.0712 giou=0.4313 time=2.6s
# train iter 850/2123 loss=3.3657 ce=2.0986 bbox=0.0741 giou=0.4484 time=2.5s
# train iter 900/2123 loss=3.4747 ce=2.2223 bbox=0.0736 giou=0.4423 time=2.4s
# train iter 950/2123 loss=3.4572 ce=2.1822 bbox=0.0746 giou=0.4511 time=2.5s
# train iter 1000/2123 loss=3.4267 ce=2.1587 bbox=0.0745 giou=0.4478 time=2.5s
# train iter 1050/2123 loss=3.4081 ce=2.1434 bbox=0.0737 giou=0.4481 time=2.4s
# train iter 1100/2123 loss=3.4528 ce=2.2096 bbox=0.0730 giou=0.4390 time=2.5s
# train iter 1150/2123 loss=3.4268 ce=2.1638 bbox=0.0735 giou=0.4476 time=2.5s
# train iter 1200/2123 loss=3.4138 ce=2.1356 bbox=0.0751 giou=0.4514 time=2.5s
# train iter 1250/2123 loss=3.4439 ce=2.1756 bbox=0.0743 giou=0.4483 time=2.5s
# train iter 1300/2123 loss=3.3133 ce=2.0828 bbox=0.0708 giou=0.4382 time=2.6s
# train iter 1350/2123 loss=3.4306 ce=2.1732 bbox=0.0726 giou=0.4472 time=2.5s
# train iter 1400/2123 loss=3.3648 ce=2.1413 bbox=0.0712 giou=0.4337 time=2.6s
# train iter 1450/2123 loss=3.4110 ce=2.1540 bbox=0.0734 giou=0.4450 time=2.5s
# train iter 1500/2123 loss=3.3367 ce=2.1024 bbox=0.0723 giou=0.4365 time=2.6s
# train iter 1550/2123 loss=3.4433 ce=2.1634 bbox=0.0735 giou=0.4563 time=2.5s
# train iter 1600/2123 loss=3.3964 ce=2.1453 bbox=0.0741 giou=0.4403 time=2.3s
# train iter 1650/2123 loss=3.3482 ce=2.1185 bbox=0.0719 giou=0.4351 time=2.6s
# train iter 1700/2123 loss=3.3805 ce=2.1456 bbox=0.0720 giou=0.4375 time=2.4s
# train iter 1750/2123 loss=3.3773 ce=2.1225 bbox=0.0722 giou=0.4468 time=2.5s
# train iter 1800/2123 loss=3.3422 ce=2.0938 bbox=0.0732 giou=0.4412 time=2.5s
# train iter 1850/2123 loss=3.3911 ce=2.1340 bbox=0.0731 giou=0.4458 time=2.5s
# train iter 1900/2123 loss=3.2764 ce=2.0297 bbox=0.0718 giou=0.4438 time=2.5s
# train iter 1950/2123 loss=3.4122 ce=2.1629 bbox=0.0727 giou=0.4430 time=2.5s
# train iter 2000/2123 loss=3.3626 ce=2.1205 bbox=0.0726 giou=0.4395 time=2.6s
# train iter 2050/2123 loss=3.4093 ce=2.1410 bbox=0.0736 giou=0.4501 time=2.5s
# train iter 2100/2123 loss=3.3388 ce=2.0873 bbox=0.0737 giou=0.4416 time=2.5s
# val iter 50/90 loss=3.2101 ce=1.9817 bbox=0.0720 giou=0.4342 time=1.7s
# train: {'loss_total': 3.4250779283310635, 'loss_ce': 2.1644504231997836, 'loss_bbox': 0.07368909636379917, 'loss_giou': 0.44609101194567236}
# val:   {'loss_total': 3.3032130029466416, 'loss_ce': 2.0648598843150667, 'loss_bbox': 0.07255378783577018, 'loss_giou': 0.4377920945485433}
# saved epoch checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/epoch_002.pth.tar
# saved best checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/best.pth.tar, val loss = 3.3032
#
# ====================================================================================================
# epoch 3/199
# train iter 50/2123 loss=3.3939 ce=2.1353 bbox=0.0730 giou=0.4468 time=3.3s
# train iter 100/2123 loss=3.3120 ce=2.0798 bbox=0.0720 giou=0.4361 time=2.4s
# train iter 150/2123 loss=3.3077 ce=2.1011 bbox=0.0712 giou=0.4254 time=2.4s
# train iter 200/2123 loss=3.3167 ce=2.0775 bbox=0.0720 giou=0.4397 time=2.5s
# train iter 250/2123 loss=3.2839 ce=2.0469 bbox=0.0715 giou=0.4398 time=2.4s
# train iter 300/2123 loss=3.2282 ce=1.9875 bbox=0.0717 giou=0.4412 time=2.4s
# train iter 350/2123 loss=3.2586 ce=2.0113 bbox=0.0729 giou=0.4414 time=2.4s
# train iter 400/2123 loss=3.2652 ce=2.0321 bbox=0.0721 giou=0.4364 time=2.5s
# train iter 450/2123 loss=3.2665 ce=2.0658 bbox=0.0701 giou=0.4252 time=2.4s
# train iter 500/2123 loss=3.2622 ce=2.0495 bbox=0.0710 giou=0.4288 time=2.5s
# train iter 550/2123 loss=3.2588 ce=2.0359 bbox=0.0706 giou=0.4348 time=2.5s
# train iter 600/2123 loss=3.2383 ce=2.0217 bbox=0.0696 giou=0.4343 time=2.5s
# train iter 650/2123 loss=3.2783 ce=2.0399 bbox=0.0728 giou=0.4373 time=2.5s
# train iter 700/2123 loss=3.2485 ce=1.9979 bbox=0.0729 giou=0.4431 time=2.5s
# train iter 750/2123 loss=3.2514 ce=2.0259 bbox=0.0714 giou=0.4344 time=2.7s
# train iter 800/2123 loss=3.2672 ce=2.0736 bbox=0.0692 giou=0.4237 time=2.5s
# train iter 850/2123 loss=3.1818 ce=1.9504 bbox=0.0709 giou=0.4384 time=2.6s
# train iter 900/2123 loss=3.2680 ce=2.0338 bbox=0.0721 giou=0.4367 time=2.3s
# train iter 950/2123 loss=3.2401 ce=2.0130 bbox=0.0711 giou=0.4357 time=2.7s
# train iter 1000/2123 loss=3.1880 ce=1.9810 bbox=0.0696 giou=0.4294 time=2.5s
# train iter 1050/2123 loss=3.1880 ce=1.9678 bbox=0.0708 giou=0.4331 time=2.7s
# train iter 1100/2123 loss=3.2551 ce=2.0518 bbox=0.0699 giou=0.4269 time=2.5s
# train iter 1150/2123 loss=3.3002 ce=2.0754 bbox=0.0714 giou=0.4339 time=2.6s
# train iter 1200/2123 loss=3.2709 ce=2.0554 bbox=0.0697 giou=0.4333 time=2.7s
# train iter 1250/2123 loss=3.2179 ce=2.0121 bbox=0.0698 giou=0.4284 time=2.5s
# train iter 1300/2123 loss=3.2777 ce=2.0664 bbox=0.0698 giou=0.4310 time=2.5s
# train iter 1350/2123 loss=3.1864 ce=1.9898 bbox=0.0691 giou=0.4256 time=2.4s
# train iter 1400/2123 loss=3.1479 ce=1.9293 bbox=0.0710 giou=0.4318 time=2.7s
# train iter 1450/2123 loss=3.1963 ce=1.9955 bbox=0.0684 giou=0.4293 time=2.7s
# train iter 1500/2123 loss=3.1970 ce=1.9880 bbox=0.0700 giou=0.4293 time=2.6s
# train iter 1550/2123 loss=3.2710 ce=2.0210 bbox=0.0729 giou=0.4428 time=2.5s
# train iter 1600/2123 loss=3.3270 ce=2.1103 bbox=0.0700 giou=0.4334 time=2.5s
# train iter 1650/2123 loss=3.2856 ce=2.0676 bbox=0.0713 giou=0.4307 time=2.6s
# train iter 1700/2123 loss=3.2063 ce=1.9984 bbox=0.0694 giou=0.4304 time=2.6s
# train iter 1750/2123 loss=3.2795 ce=2.0450 bbox=0.0708 giou=0.4402 time=2.6s
# train iter 1800/2123 loss=3.2067 ce=2.0138 bbox=0.0687 giou=0.4246 time=2.5s
# train iter 1850/2123 loss=3.1638 ce=1.9571 bbox=0.0698 giou=0.4288 time=2.5s
# train iter 1900/2123 loss=3.2075 ce=1.9758 bbox=0.0711 giou=0.4381 time=2.5s
# train iter 1950/2123 loss=3.2404 ce=2.0116 bbox=0.0713 giou=0.4363 time=2.4s
# train iter 2000/2123 loss=3.2194 ce=1.9823 bbox=0.0706 giou=0.4420 time=2.6s
# train iter 2050/2123 loss=3.0951 ce=1.9300 bbox=0.0672 giou=0.4145 time=2.6s
# train iter 2100/2123 loss=3.1631 ce=1.9802 bbox=0.0686 giou=0.4201 time=2.6s
# val iter 50/90 loss=3.1095 ce=1.9161 bbox=0.0697 giou=0.4224 time=1.7s
# train: {'loss_total': 3.241362229417755, 'loss_ce': 2.022113746592755, 'loss_bbox': 0.07066644187376177, 'loss_giou': 0.4329581342802483}
# val:   {'loss_total': 3.200470773379008, 'loss_ce': 1.9873238292005326, 'loss_bbox': 0.07099727325969273, 'loss_giou': 0.4290802876154582}
# saved epoch checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/epoch_003.pth.tar
# saved best checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/best.pth.tar, val loss = 3.2005
#
# ====================================================================================================
# epoch 4/199
# train iter 50/2123 loss=3.1302 ce=1.9202 bbox=0.0696 giou=0.4310 time=3.3s
# train iter 100/2123 loss=3.0540 ce=1.8662 bbox=0.0686 giou=0.4223 time=2.7s
# train iter 150/2123 loss=3.1814 ce=1.9932 bbox=0.0689 giou=0.4218 time=2.6s
# train iter 200/2123 loss=3.1175 ce=1.9078 bbox=0.0700 giou=0.4299 time=2.4s
# train iter 250/2123 loss=3.1662 ce=1.9594 bbox=0.0688 giou=0.4314 time=2.6s
# train iter 300/2123 loss=3.1321 ce=1.9099 bbox=0.0705 giou=0.4349 time=2.5s
# train iter 350/2123 loss=3.1097 ce=1.8984 bbox=0.0697 giou=0.4314 time=2.8s
# train iter 400/2123 loss=3.0662 ce=1.8834 bbox=0.0681 giou=0.4211 time=2.6s
# train iter 450/2123 loss=3.0746 ce=1.8955 bbox=0.0679 giou=0.4199 time=2.6s
# train iter 500/2123 loss=3.1495 ce=1.9710 bbox=0.0678 giou=0.4198 time=2.7s
# train iter 550/2123 loss=3.0864 ce=1.9285 bbox=0.0664 giou=0.4128 time=2.5s
# train iter 600/2123 loss=3.0313 ce=1.8911 bbox=0.0653 giou=0.4069 time=2.6s
# train iter 650/2123 loss=3.0979 ce=1.9176 bbox=0.0684 giou=0.4192 time=2.6s
# train iter 700/2123 loss=3.1726 ce=1.9666 bbox=0.0697 giou=0.4288 time=2.5s
# train iter 750/2123 loss=3.0512 ce=1.8722 bbox=0.0679 giou=0.4199 time=2.6s
# train iter 800/2123 loss=3.1642 ce=1.9369 bbox=0.0705 giou=0.4375 time=2.6s
# train iter 850/2123 loss=3.1300 ce=1.9474 bbox=0.0679 giou=0.4216 time=2.7s
# train iter 900/2123 loss=3.1321 ce=1.9435 bbox=0.0682 giou=0.4237 time=2.7s
# train iter 950/2123 loss=3.0275 ce=1.8922 bbox=0.0652 giou=0.4047 time=2.8s
# train iter 1000/2123 loss=3.0937 ce=1.9137 bbox=0.0680 giou=0.4199 time=2.7s
# train iter 1050/2123 loss=3.0899 ce=1.9015 bbox=0.0678 giou=0.4247 time=2.5s
# train iter 1100/2123 loss=3.0904 ce=1.9001 bbox=0.0676 giou=0.4261 time=2.5s
# train iter 1150/2123 loss=3.1156 ce=1.9198 bbox=0.0681 giou=0.4276 time=2.5s
# train iter 1200/2123 loss=3.0273 ce=1.8617 bbox=0.0665 giou=0.4166 time=2.6s
# train iter 1250/2123 loss=3.0484 ce=1.8971 bbox=0.0660 giou=0.4106 time=2.5s
# train iter 1300/2123 loss=3.1187 ce=1.9506 bbox=0.0669 giou=0.4168 time=2.7s
# train iter 1350/2123 loss=3.0657 ce=1.9158 bbox=0.0658 giou=0.4104 time=2.6s
# train iter 1400/2123 loss=3.0156 ce=1.8572 bbox=0.0660 giou=0.4141 time=2.4s
# train iter 1450/2123 loss=3.0745 ce=1.9027 bbox=0.0673 giou=0.4177 time=2.6s
# train iter 1500/2123 loss=3.0940 ce=1.9122 bbox=0.0680 giou=0.4208 time=2.5s
# train iter 1550/2123 loss=3.1360 ce=1.9240 bbox=0.0696 giou=0.4320 time=2.4s
# train iter 1600/2123 loss=3.1065 ce=1.9318 bbox=0.0678 giou=0.4178 time=2.7s
# train iter 1650/2123 loss=3.1618 ce=1.9408 bbox=0.0697 giou=0.4364 time=2.6s
# train iter 1700/2123 loss=3.0303 ce=1.8913 bbox=0.0650 giou=0.4069 time=2.5s
# train iter 1750/2123 loss=3.0693 ce=1.8872 bbox=0.0688 giou=0.4192 time=2.7s
# train iter 1800/2123 loss=3.0752 ce=1.9177 bbox=0.0662 giou=0.4133 time=2.6s
# train iter 1850/2123 loss=3.0748 ce=1.8946 bbox=0.0669 giou=0.4228 time=2.6s
# train iter 1900/2123 loss=3.0672 ce=1.9130 bbox=0.0676 giou=0.4082 time=2.5s
# train iter 1950/2123 loss=3.0474 ce=1.8718 bbox=0.0673 giou=0.4196 time=2.6s
# train iter 2000/2123 loss=2.9923 ce=1.8261 bbox=0.0665 giou=0.4169 time=2.5s
# train iter 2050/2123 loss=3.0264 ce=1.8693 bbox=0.0663 giou=0.4129 time=2.5s
# train iter 2100/2123 loss=3.0229 ce=1.8660 bbox=0.0670 giou=0.4109 time=2.5s
# val iter 50/90 loss=3.0084 ce=1.8485 bbox=0.0657 giou=0.4156 time=1.7s
# train: {'loss_total': 3.08799449161039, 'loss_ce': 1.9080454641729383, 'loss_bbox': 0.06775061413470271, 'loss_giou': 0.42059797760286927}
# val:   {'loss_total': 3.0834085398250157, 'loss_ce': 1.9083571487002902, 'loss_bbox': 0.0664663119862477, 'loss_giou': 0.42135990195804174}
# saved epoch checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/epoch_004.pth.tar
# saved best checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/best.pth.tar, val loss = 3.0834
#
# ====================================================================================================
# epoch 5/199
# train iter 50/2123 loss=2.9679 ce=1.8121 bbox=0.0660 giou=0.4129 time=2.8s
# train iter 100/2123 loss=3.0041 ce=1.8348 bbox=0.0659 giou=0.4200 time=2.6s
# train iter 150/2123 loss=3.0261 ce=1.8608 bbox=0.0664 giou=0.4166 time=2.7s
# train iter 200/2123 loss=3.0258 ce=1.8719 bbox=0.0657 giou=0.4126 time=2.5s
# train iter 250/2123 loss=3.0366 ce=1.8766 bbox=0.0664 giou=0.4141 time=2.6s
# train iter 300/2123 loss=2.9442 ce=1.8258 bbox=0.0632 giou=0.4013 time=2.5s
# train iter 350/2123 loss=2.9757 ce=1.8360 bbox=0.0649 giou=0.4077 time=2.6s
# train iter 400/2123 loss=2.9988 ce=1.8538 bbox=0.0650 giou=0.4099 time=2.6s
# train iter 450/2123 loss=2.9633 ce=1.8328 bbox=0.0645 giou=0.4039 time=2.5s
# train iter 500/2123 loss=3.0297 ce=1.8925 bbox=0.0649 giou=0.4063 time=2.5s
# train iter 550/2123 loss=2.9996 ce=1.8380 bbox=0.0668 giou=0.4137 time=2.4s
# train iter 600/2123 loss=2.9547 ce=1.8169 bbox=0.0642 giou=0.4085 time=2.5s
# train iter 650/2123 loss=2.9494 ce=1.7859 bbox=0.0663 giou=0.4160 time=2.5s
# train iter 700/2123 loss=2.9331 ce=1.7781 bbox=0.0664 giou=0.4115 time=2.6s
# train iter 750/2123 loss=2.9789 ce=1.7733 bbox=0.0683 giou=0.4320 time=2.9s
# train iter 800/2123 loss=2.9695 ce=1.8071 bbox=0.0663 giou=0.4156 time=2.9s
# train iter 850/2123 loss=2.9580 ce=1.8066 bbox=0.0667 giou=0.4088 time=2.5s
# train iter 900/2123 loss=3.0677 ce=1.8831 bbox=0.0669 giou=0.4250 time=2.5s
# train iter 950/2123 loss=3.0063 ce=1.8400 bbox=0.0666 giou=0.4166 time=2.5s
# train iter 1000/2123 loss=2.9760 ce=1.8325 bbox=0.0652 giou=0.4088 time=2.6s
# train iter 1050/2123 loss=2.9210 ce=1.8008 bbox=0.0632 giou=0.4021 time=2.5s
# train iter 1100/2123 loss=2.9621 ce=1.8427 bbox=0.0630 giou=0.4022 time=2.5s
# train iter 1150/2123 loss=2.9063 ce=1.7539 bbox=0.0657 giou=0.4120 time=2.5s
# train iter 1200/2123 loss=2.9512 ce=1.7975 bbox=0.0661 giou=0.4116 time=2.4s
# train iter 1250/2123 loss=2.9876 ce=1.8397 bbox=0.0654 giou=0.4104 time=2.6s
# train iter 1300/2123 loss=2.9831 ce=1.8344 bbox=0.0656 giou=0.4103 time=2.4s
# train iter 1350/2123 loss=2.9745 ce=1.8287 bbox=0.0647 giou=0.4112 time=2.5s
# train iter 1400/2123 loss=2.9184 ce=1.7807 bbox=0.0650 giou=0.4063 time=2.7s
# train iter 1450/2123 loss=3.0124 ce=1.8676 bbox=0.0652 giou=0.4095 time=2.7s
# train iter 1500/2123 loss=2.9296 ce=1.7538 bbox=0.0671 giou=0.4201 time=2.7s
# train iter 1550/2123 loss=2.9083 ce=1.7923 bbox=0.0635 giou=0.3993 time=2.6s
# train iter 1600/2123 loss=2.9755 ce=1.8240 bbox=0.0657 giou=0.4114 time=2.6s
# train iter 1650/2123 loss=2.9602 ce=1.8266 bbox=0.0643 giou=0.4059 time=2.6s
# train iter 1700/2123 loss=2.9398 ce=1.7951 bbox=0.0653 giou=0.4091 time=2.6s
# train iter 1750/2123 loss=2.8773 ce=1.7582 bbox=0.0637 giou=0.4003 time=2.7s
# train iter 1800/2123 loss=2.9776 ce=1.8562 bbox=0.0639 giou=0.4010 time=2.5s
# train iter 1850/2123 loss=2.9367 ce=1.8054 bbox=0.0651 giou=0.4029 time=2.6s
# train iter 1900/2123 loss=3.0393 ce=1.8750 bbox=0.0668 giou=0.4151 time=2.5s
# train iter 1950/2123 loss=2.9955 ce=1.8586 bbox=0.0650 giou=0.4061 time=2.5s
# train iter 2000/2123 loss=2.9737 ce=1.8410 bbox=0.0645 giou=0.4050 time=2.4s
# train iter 2050/2123 loss=2.9122 ce=1.7883 bbox=0.0641 giou=0.4018 time=2.5s
# train iter 2100/2123 loss=2.8664 ce=1.7567 bbox=0.0634 giou=0.3964 time=2.5s
# val iter 50/90 loss=2.9132 ce=1.7910 bbox=0.0642 giou=0.4007 time=1.6s
# train: {'loss_total': 2.969487742551138, 'loss_ce': 1.8237596409982295, 'loss_bbox': 0.06528479497295418, 'loss_giou': 0.40965206288696177}
# val:   {'loss_total': 2.9669894033008153, 'loss_ce': 1.8274267276128133, 'loss_bbox': 0.06517207601832019, 'loss_giou': 0.4068511525789897}
# saved epoch checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/epoch_005.pth.tar
# saved best checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/best.pth.tar, val loss = 2.9670
#
# ====================================================================================================
# epoch 6/199
# train iter 50/2123 loss=2.8886 ce=1.7610 bbox=0.0639 giou=0.4041 time=3.0s
# train iter 100/2123 loss=2.8715 ce=1.7628 bbox=0.0636 giou=0.3954 time=2.6s
# train iter 150/2123 loss=2.8511 ce=1.7472 bbox=0.0625 giou=0.3957 time=2.6s
# train iter 200/2123 loss=2.8374 ce=1.7246 bbox=0.0631 giou=0.3987 time=2.5s
# train iter 250/2123 loss=2.8439 ce=1.7409 bbox=0.0616 giou=0.3976 time=2.4s
# train iter 300/2123 loss=2.8430 ce=1.7502 bbox=0.0623 giou=0.3907 time=2.4s
# train iter 350/2123 loss=2.8025 ce=1.6846 bbox=0.0628 giou=0.4019 time=2.4s
# train iter 400/2123 loss=3.0092 ce=1.8660 bbox=0.0650 giou=0.4092 time=2.6s
# train iter 450/2123 loss=2.8974 ce=1.7581 bbox=0.0646 giou=0.4082 time=2.7s
# train iter 500/2123 loss=2.8680 ce=1.7521 bbox=0.0636 giou=0.3990 time=2.4s
# train iter 550/2123 loss=2.8884 ce=1.7536 bbox=0.0647 giou=0.4058 time=2.6s
# train iter 600/2123 loss=2.9341 ce=1.8256 bbox=0.0635 giou=0.3954 time=2.5s
# train iter 650/2123 loss=2.8346 ce=1.7312 bbox=0.0626 giou=0.3951 time=2.5s
# train iter 700/2123 loss=2.9010 ce=1.7770 bbox=0.0635 giou=0.4033 time=2.5s
# train iter 750/2123 loss=2.9822 ce=1.8397 bbox=0.0651 giou=0.4085 time=2.5s
# train iter 800/2123 loss=2.9052 ce=1.7771 bbox=0.0642 giou=0.4036 time=2.5s
# train iter 850/2123 loss=2.9200 ce=1.7844 bbox=0.0640 giou=0.4077 time=2.5s
# train iter 900/2123 loss=2.9614 ce=1.8281 bbox=0.0638 giou=0.4072 time=2.7s
# train iter 950/2123 loss=2.8124 ce=1.6977 bbox=0.0632 giou=0.3993 time=2.8s
# train iter 1000/2123 loss=2.9632 ce=1.8292 bbox=0.0640 giou=0.4069 time=2.6s
# train iter 1050/2123 loss=2.8747 ce=1.7725 bbox=0.0624 giou=0.3952 time=2.7s
# train iter 1100/2123 loss=2.8150 ce=1.7460 bbox=0.0602 giou=0.3840 time=2.6s
# train iter 1150/2123 loss=2.8707 ce=1.7704 bbox=0.0620 giou=0.3952 time=2.6s
# train iter 1200/2123 loss=2.8582 ce=1.7504 bbox=0.0625 giou=0.3977 time=2.6s
# train iter 1250/2123 loss=2.8239 ce=1.7109 bbox=0.0630 giou=0.3991 time=2.7s
# train iter 1300/2123 loss=2.8666 ce=1.7508 bbox=0.0620 giou=0.4028 time=2.6s
# train iter 1350/2123 loss=2.8359 ce=1.7156 bbox=0.0629 giou=0.4031 time=2.4s
# train iter 1400/2123 loss=2.8217 ce=1.7099 bbox=0.0621 giou=0.4006 time=2.5s
# train iter 1450/2123 loss=2.8073 ce=1.6856 bbox=0.0628 giou=0.4037 time=2.6s
# train iter 1500/2123 loss=2.7489 ce=1.6664 bbox=0.0613 giou=0.3879 time=2.5s
# train iter 1550/2123 loss=2.8143 ce=1.7033 bbox=0.0629 giou=0.3981 time=2.5s
# train iter 1600/2123 loss=2.7797 ce=1.6594 bbox=0.0631 giou=0.4025 time=2.7s
# train iter 1650/2123 loss=2.8454 ce=1.7056 bbox=0.0638 giou=0.4105 time=2.6s
# train iter 1700/2123 loss=2.8655 ce=1.7386 bbox=0.0637 giou=0.4041 time=2.4s
# train iter 1750/2123 loss=2.8545 ce=1.7556 bbox=0.0622 giou=0.3938 time=2.4s
# train iter 1800/2123 loss=2.8743 ce=1.7476 bbox=0.0639 giou=0.4037 time=2.5s
# train iter 1850/2123 loss=2.7648 ce=1.6640 bbox=0.0624 giou=0.3944 time=2.6s
# train iter 1900/2123 loss=2.8510 ce=1.7609 bbox=0.0615 giou=0.3914 time=2.8s
# train iter 1950/2123 loss=2.8920 ce=1.7617 bbox=0.0641 giou=0.4048 time=2.6s
# train iter 2000/2123 loss=2.8482 ce=1.7328 bbox=0.0635 giou=0.3990 time=2.6s
# train iter 2050/2123 loss=2.8255 ce=1.7225 bbox=0.0623 giou=0.3959 time=2.6s
# train iter 2100/2123 loss=2.8648 ce=1.7558 bbox=0.0631 giou=0.3968 time=2.7s
# val iter 50/90 loss=2.7404 ce=1.6780 bbox=0.0599 giou=0.3816 time=1.8s
# train: {'loss_total': 2.862879033589554, 'loss_ce': 1.748340944720505, 'loss_bbox': 0.06304565867302948, 'loss_giou': 0.39965489861878706}
# val:   {'loss_total': 2.8572508388095432, 'loss_ce': 1.7595253772205777, 'loss_bbox': 0.06191303734150198, 'loss_giou': 0.3940801352262497}
# saved epoch checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/epoch_006.pth.tar
# saved best checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/best.pth.tar, val loss = 2.8573
#
# ====================================================================================================
# epoch 7/199
# train iter 50/2123 loss=2.8200 ce=1.7295 bbox=0.0618 giou=0.3908 time=3.0s
# train iter 100/2123 loss=2.8540 ce=1.7310 bbox=0.0638 giou=0.4020 time=2.8s
# train iter 150/2123 loss=2.7324 ce=1.6446 bbox=0.0622 giou=0.3883 time=2.7s
# train iter 200/2123 loss=2.8197 ce=1.7188 bbox=0.0622 giou=0.3949 time=2.7s
# train iter 250/2123 loss=2.7654 ce=1.6683 bbox=0.0612 giou=0.3955 time=2.6s
# train iter 300/2123 loss=2.7493 ce=1.6981 bbox=0.0596 giou=0.3767 time=2.8s
# train iter 350/2123 loss=2.7385 ce=1.6509 bbox=0.0612 giou=0.3908 time=2.8s
# train iter 400/2123 loss=2.7259 ce=1.6482 bbox=0.0606 giou=0.3875 time=2.7s
# train iter 450/2123 loss=2.7642 ce=1.6895 bbox=0.0603 giou=0.3867 time=2.7s
# train iter 500/2123 loss=2.7389 ce=1.6592 bbox=0.0613 giou=0.3867 time=2.5s
# train iter 550/2123 loss=2.7044 ce=1.6290 bbox=0.0604 giou=0.3867 time=2.5s
# train iter 600/2123 loss=2.7677 ce=1.6704 bbox=0.0623 giou=0.3930 time=2.6s
# train iter 650/2123 loss=2.7460 ce=1.6487 bbox=0.0615 giou=0.3950 time=2.7s
# train iter 700/2123 loss=2.7731 ce=1.7048 bbox=0.0601 giou=0.3840 time=2.5s
# train iter 750/2123 loss=2.7329 ce=1.6621 bbox=0.0602 giou=0.3850 time=2.6s
# train iter 800/2123 loss=2.7690 ce=1.7030 bbox=0.0608 giou=0.3810 time=2.6s
# train iter 850/2123 loss=2.7636 ce=1.6679 bbox=0.0622 giou=0.3924 time=2.6s
# train iter 900/2123 loss=2.7415 ce=1.6381 bbox=0.0620 giou=0.3968 time=2.5s
# train iter 950/2123 loss=2.8062 ce=1.7061 bbox=0.0612 giou=0.3969 time=2.4s
# train iter 1000/2123 loss=2.7316 ce=1.6183 bbox=0.0621 giou=0.4013 time=2.4s
# train iter 1050/2123 loss=2.7188 ce=1.6663 bbox=0.0590 giou=0.3787 time=2.6s
# train iter 1100/2123 loss=2.7316 ce=1.6518 bbox=0.0605 giou=0.3886 time=2.5s
# train iter 1150/2123 loss=2.7906 ce=1.6968 bbox=0.0610 giou=0.3944 time=2.6s
# train iter 1200/2123 loss=2.7394 ce=1.6861 bbox=0.0590 giou=0.3791 time=2.6s
# train iter 1250/2123 loss=2.8636 ce=1.7668 bbox=0.0615 giou=0.3947 time=2.4s
# train iter 1300/2123 loss=2.7123 ce=1.6298 bbox=0.0606 giou=0.3899 time=2.5s
# train iter 1350/2123 loss=2.7797 ce=1.6836 bbox=0.0613 giou=0.3948 time=2.4s
# train iter 1400/2123 loss=2.7444 ce=1.6534 bbox=0.0612 giou=0.3924 time=2.6s
# train iter 1450/2123 loss=2.6979 ce=1.6439 bbox=0.0592 giou=0.3791 time=2.4s
# train iter 1500/2123 loss=2.8105 ce=1.7164 bbox=0.0610 giou=0.3945 time=2.5s
# train iter 1550/2123 loss=2.8077 ce=1.7217 bbox=0.0618 giou=0.3884 time=2.7s
# train iter 1600/2123 loss=2.7462 ce=1.6541 bbox=0.0612 giou=0.3930 time=2.7s
# train iter 1650/2123 loss=2.7282 ce=1.6332 bbox=0.0617 giou=0.3931 time=2.7s
# train iter 1700/2123 loss=2.7286 ce=1.6449 bbox=0.0614 giou=0.3884 time=2.5s
# train iter 1750/2123 loss=2.7157 ce=1.6496 bbox=0.0603 giou=0.3822 time=2.6s
# train iter 1800/2123 loss=2.7789 ce=1.6631 bbox=0.0626 giou=0.4014 time=2.4s
# train iter 1850/2123 loss=2.8050 ce=1.6988 bbox=0.0617 giou=0.3988 time=2.6s
# train iter 1900/2123 loss=2.7904 ce=1.6897 bbox=0.0617 giou=0.3961 time=2.5s
# train iter 1950/2123 loss=2.8636 ce=1.7649 bbox=0.0616 giou=0.3955 time=2.4s
# train iter 2000/2123 loss=2.7564 ce=1.6768 bbox=0.0607 giou=0.3881 time=2.5s
# train iter 2050/2123 loss=2.7378 ce=1.6395 bbox=0.0613 giou=0.3959 time=2.6s
# train iter 2100/2123 loss=2.7582 ce=1.6714 bbox=0.0607 giou=0.3917 time=2.5s
# val iter 50/90 loss=2.7204 ce=1.6340 bbox=0.0623 giou=0.3874 time=1.8s
# train: {'loss_total': 2.7633644164984257, 'loss_ce': 1.6762169744965045, 'loss_bbox': 0.061151763167209466, 'loss_giou': 0.3906943138427348}
# val:   {'loss_total': 2.812456203831567, 'loss_ce': 1.6995574169688754, 'loss_bbox': 0.06356817943354448, 'loss_giou': 0.39752894408173034}
# saved epoch checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/epoch_007.pth.tar
# saved best checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/best.pth.tar, val loss = 2.8125
#
# ====================================================================================================
# epoch 8/199
# train iter 50/2123 loss=2.7447 ce=1.6514 bbox=0.0610 giou=0.3941 time=2.8s
# train iter 100/2123 loss=2.6921 ce=1.6330 bbox=0.0589 giou=0.3823 time=2.4s
# train iter 150/2123 loss=2.6917 ce=1.6243 bbox=0.0593 giou=0.3854 time=2.5s
# train iter 200/2123 loss=2.5675 ce=1.5329 bbox=0.0579 giou=0.3725 time=2.4s
# train iter 250/2123 loss=2.6855 ce=1.6043 bbox=0.0608 giou=0.3885 time=2.4s
# train iter 300/2123 loss=2.6121 ce=1.5548 bbox=0.0593 giou=0.3803 time=2.5s
# train iter 350/2123 loss=2.6621 ce=1.5898 bbox=0.0592 giou=0.3880 time=2.5s
# train iter 400/2123 loss=2.7275 ce=1.6602 bbox=0.0598 giou=0.3840 time=2.5s
# train iter 450/2123 loss=2.6964 ce=1.6370 bbox=0.0589 giou=0.3824 time=2.5s
# train iter 500/2123 loss=2.7152 ce=1.6197 bbox=0.0610 giou=0.3954 time=2.4s
# train iter 550/2123 loss=2.6241 ce=1.5810 bbox=0.0588 giou=0.3744 time=2.5s
# train iter 600/2123 loss=2.6359 ce=1.5615 bbox=0.0610 giou=0.3848 time=2.4s
# train iter 650/2123 loss=2.6887 ce=1.6222 bbox=0.0599 giou=0.3835 time=2.6s
# train iter 700/2123 loss=2.6849 ce=1.6334 bbox=0.0595 giou=0.3771 time=2.7s
# train iter 750/2123 loss=2.6955 ce=1.6281 bbox=0.0599 giou=0.3838 time=2.7s
# train iter 800/2123 loss=2.6967 ce=1.6173 bbox=0.0605 giou=0.3884 time=2.5s
# train iter 850/2123 loss=2.6701 ce=1.5989 bbox=0.0607 giou=0.3839 time=2.5s
# train iter 900/2123 loss=2.7483 ce=1.6480 bbox=0.0613 giou=0.3970 time=2.5s
# train iter 950/2123 loss=2.6274 ce=1.5793 bbox=0.0587 giou=0.3773 time=2.6s
# train iter 1000/2123 loss=2.6986 ce=1.6196 bbox=0.0598 giou=0.3900 time=2.6s
# train iter 1050/2123 loss=2.6096 ce=1.5828 bbox=0.0576 giou=0.3694 time=2.6s
# train iter 1100/2123 loss=2.6418 ce=1.5687 bbox=0.0600 giou=0.3864 time=2.6s
# train iter 1150/2123 loss=2.6496 ce=1.5851 bbox=0.0602 giou=0.3816 time=2.6s
# train iter 1200/2123 loss=2.6248 ce=1.5748 bbox=0.0586 giou=0.3786 time=2.5s
# train iter 1250/2123 loss=2.6643 ce=1.6196 bbox=0.0584 giou=0.3764 time=2.5s
# train iter 1300/2123 loss=2.6854 ce=1.6395 bbox=0.0584 giou=0.3770 time=2.5s
# train iter 1350/2123 loss=2.7505 ce=1.6593 bbox=0.0607 giou=0.3938 time=2.5s
# train iter 1400/2123 loss=2.6648 ce=1.6028 bbox=0.0599 giou=0.3812 time=2.5s
# train iter 1450/2123 loss=2.6947 ce=1.6383 bbox=0.0588 giou=0.3813 time=2.4s
# train iter 1500/2123 loss=2.6644 ce=1.5884 bbox=0.0595 giou=0.3892 time=2.3s
# train iter 1550/2123 loss=2.7276 ce=1.6545 bbox=0.0604 giou=0.3855 time=2.5s
# train iter 1600/2123 loss=2.6862 ce=1.6502 bbox=0.0587 giou=0.3714 time=2.6s
# train iter 1650/2123 loss=2.6453 ce=1.5638 bbox=0.0603 giou=0.3901 time=2.5s
# train iter 1700/2123 loss=2.6954 ce=1.6230 bbox=0.0605 giou=0.3850 time=2.6s
# train iter 1750/2123 loss=2.6627 ce=1.6019 bbox=0.0593 giou=0.3822 time=2.5s
# train iter 1800/2123 loss=2.6829 ce=1.6157 bbox=0.0600 giou=0.3837 time=2.4s
# train iter 1850/2123 loss=2.5836 ce=1.5236 bbox=0.0599 giou=0.3803 time=2.7s
# train iter 1900/2123 loss=2.6738 ce=1.6247 bbox=0.0587 giou=0.3779 time=2.5s
# train iter 1950/2123 loss=2.6725 ce=1.6069 bbox=0.0599 giou=0.3831 time=2.4s
# train iter 2000/2123 loss=2.6243 ce=1.5801 bbox=0.0584 giou=0.3762 time=2.4s
# train iter 2050/2123 loss=2.7499 ce=1.6532 bbox=0.0609 giou=0.3961 time=2.5s
# train iter 2100/2123 loss=2.5946 ce=1.5438 bbox=0.0588 giou=0.3784 time=2.6s
# val iter 50/90 loss=2.7069 ce=1.6558 bbox=0.0594 giou=0.3770 time=1.8s
# train: {'loss_total': 2.6712989574662367, 'loss_ce': 1.6071308407365743, 'loss_bbox': 0.05959597404026727, 'loss_giou': 0.3830941227798579}
# val:   {'loss_total': 2.7681010868814258, 'loss_ce': 1.6898741225401561, 'loss_bbox': 0.06085657373898559, 'loss_giou': 0.386972051858902}
# saved epoch checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/epoch_008.pth.tar
# saved best checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/best.pth.tar, val loss = 2.7681
#
# ====================================================================================================
# epoch 9/199
# train iter 50/2123 loss=2.6356 ce=1.5833 bbox=0.0590 giou=0.3785 time=2.9s
# train iter 100/2123 loss=2.5890 ce=1.5564 bbox=0.0576 giou=0.3723 time=2.5s
# train iter 150/2123 loss=2.6152 ce=1.5723 bbox=0.0585 giou=0.3753 time=2.5s
# train iter 200/2123 loss=2.5526 ce=1.5143 bbox=0.0572 giou=0.3762 time=2.4s
# train iter 250/2123 loss=2.5863 ce=1.5525 bbox=0.0576 giou=0.3730 time=2.5s
# train iter 300/2123 loss=2.6319 ce=1.5936 bbox=0.0582 giou=0.3736 time=2.6s
# train iter 350/2123 loss=2.6426 ce=1.5905 bbox=0.0585 giou=0.3798 time=2.6s
# train iter 400/2123 loss=2.6002 ce=1.5570 bbox=0.0580 giou=0.3767 time=2.5s
# train iter 450/2123 loss=2.5535 ce=1.5022 bbox=0.0588 giou=0.3786 time=2.5s
# train iter 500/2123 loss=2.5402 ce=1.5064 bbox=0.0580 giou=0.3719 time=2.4s
# train iter 550/2123 loss=2.4960 ce=1.4718 bbox=0.0570 giou=0.3697 time=2.5s
# train iter 600/2123 loss=2.5688 ce=1.5298 bbox=0.0578 giou=0.3750 time=2.5s
# train iter 650/2123 loss=2.6132 ce=1.5464 bbox=0.0592 giou=0.3854 time=2.4s
# train iter 700/2123 loss=2.5502 ce=1.5271 bbox=0.0569 giou=0.3693 time=2.5s
# train iter 750/2123 loss=2.5822 ce=1.5369 bbox=0.0580 giou=0.3776 time=2.5s
# train iter 800/2123 loss=2.7133 ce=1.6504 bbox=0.0594 giou=0.3828 time=2.5s
# train iter 850/2123 loss=2.5911 ce=1.5578 bbox=0.0576 giou=0.3727 time=2.5s
# train iter 900/2123 loss=2.5966 ce=1.5457 bbox=0.0585 giou=0.3792 time=2.5s
# train iter 950/2123 loss=2.5697 ce=1.5293 bbox=0.0582 giou=0.3747 time=2.5s
# train iter 1000/2123 loss=2.5872 ce=1.5439 bbox=0.0575 giou=0.3778 time=2.4s
# train iter 1050/2123 loss=2.5916 ce=1.5582 bbox=0.0573 giou=0.3733 time=2.3s
# train iter 1100/2123 loss=2.5731 ce=1.5125 bbox=0.0596 giou=0.3813 time=2.5s
# train iter 1150/2123 loss=2.5925 ce=1.5514 bbox=0.0584 giou=0.3746 time=2.5s
# train iter 1200/2123 loss=2.5519 ce=1.5159 bbox=0.0575 giou=0.3742 time=2.5s
# train iter 1250/2123 loss=2.4995 ce=1.4727 bbox=0.0571 giou=0.3707 time=2.6s
# train iter 1300/2123 loss=2.5788 ce=1.5294 bbox=0.0580 giou=0.3796 time=2.7s
# train iter 1350/2123 loss=2.6568 ce=1.6021 bbox=0.0591 giou=0.3797 time=2.8s
# train iter 1400/2123 loss=2.6336 ce=1.5798 bbox=0.0592 giou=0.3788 time=2.9s
# train iter 1450/2123 loss=2.6435 ce=1.5526 bbox=0.0611 giou=0.3927 time=2.6s
# train iter 1500/2123 loss=2.6542 ce=1.5948 bbox=0.0587 giou=0.3829 time=2.5s
# train iter 1550/2123 loss=2.5415 ce=1.5095 bbox=0.0579 giou=0.3712 time=2.5s
# train iter 1600/2123 loss=2.5684 ce=1.5331 bbox=0.0578 giou=0.3731 time=2.5s
# train iter 1650/2123 loss=2.6017 ce=1.5377 bbox=0.0590 giou=0.3846 time=2.5s
# train iter 1700/2123 loss=2.5569 ce=1.5079 bbox=0.0578 giou=0.3800 time=2.6s
# train iter 1750/2123 loss=2.5027 ce=1.4808 bbox=0.0567 giou=0.3692 time=2.6s
# train iter 1800/2123 loss=2.5857 ce=1.5325 bbox=0.0587 giou=0.3798 time=2.5s
# train iter 1850/2123 loss=2.5513 ce=1.5271 bbox=0.0580 giou=0.3672 time=2.4s
# train iter 1900/2123 loss=2.6127 ce=1.5684 bbox=0.0581 giou=0.3768 time=2.5s
# train iter 1950/2123 loss=2.6781 ce=1.6212 bbox=0.0590 giou=0.3809 time=2.3s
# train iter 2000/2123 loss=2.6088 ce=1.5596 bbox=0.0585 giou=0.3782 time=2.3s
# train iter 2050/2123 loss=2.5312 ce=1.5077 bbox=0.0576 giou=0.3677 time=2.6s
# train iter 2100/2123 loss=2.5542 ce=1.5300 bbox=0.0569 giou=0.3698 time=2.6s
# val iter 50/90 loss=2.6050 ce=1.5818 bbox=0.0572 giou=0.3686 time=1.8s
# train: {'loss_total': 2.588299083080822, 'loss_ce': 1.5444796003938226, 'loss_bbox': 0.05820154968966755, 'loss_giou': 0.3764058675860887}
# val:   {'loss_total': 2.6844455824957953, 'loss_ce': 1.6312151239977943, 'loss_bbox': 0.05889300335612562, 'loss_giou': 0.37938271909952165}
# saved epoch checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/epoch_009.pth.tar
# saved best checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/best.pth.tar, val loss = 2.6844
#
# ====================================================================================================
# epoch 10/199
# train iter 50/2123 loss=2.5410 ce=1.5043 bbox=0.0575 giou=0.3747 time=2.8s
# train iter 100/2123 loss=2.4843 ce=1.4473 bbox=0.0578 giou=0.3741 time=2.5s
# train iter 150/2123 loss=2.3895 ce=1.3859 bbox=0.0549 giou=0.3645 time=2.4s
# train iter 200/2123 loss=2.4557 ce=1.4409 bbox=0.0561 giou=0.3673 time=2.4s
# train iter 250/2123 loss=2.5599 ce=1.5050 bbox=0.0578 giou=0.3829 time=2.5s
# train iter 300/2123 loss=2.4895 ce=1.4797 bbox=0.0556 giou=0.3658 time=2.4s
# train iter 350/2123 loss=2.4411 ce=1.4422 bbox=0.0551 giou=0.3617 time=2.5s
# train iter 400/2123 loss=2.4695 ce=1.4428 bbox=0.0568 giou=0.3713 time=2.4s
# train iter 450/2123 loss=2.4631 ce=1.4581 bbox=0.0549 giou=0.3652 time=2.5s
# train iter 500/2123 loss=2.4840 ce=1.4924 bbox=0.0552 giou=0.3578 time=2.5s
# train iter 550/2123 loss=2.4885 ce=1.4522 bbox=0.0579 giou=0.3733 time=2.3s
# train iter 600/2123 loss=2.5373 ce=1.5281 bbox=0.0565 giou=0.3635 time=2.4s
# train iter 650/2123 loss=2.4762 ce=1.4584 bbox=0.0562 giou=0.3684 time=2.5s
# train iter 700/2123 loss=2.5031 ce=1.4798 bbox=0.0564 giou=0.3707 time=2.5s
# train iter 750/2123 loss=2.4993 ce=1.4697 bbox=0.0570 giou=0.3722 time=2.5s
# train iter 800/2123 loss=2.5312 ce=1.4945 bbox=0.0571 giou=0.3756 time=2.5s
# train iter 850/2123 loss=2.5528 ce=1.5070 bbox=0.0580 giou=0.3779 time=2.6s
# train iter 900/2123 loss=2.5637 ce=1.5177 bbox=0.0581 giou=0.3777 time=2.4s
# train iter 950/2123 loss=2.4803 ce=1.4626 bbox=0.0567 giou=0.3672 time=2.6s
# train iter 1000/2123 loss=2.5710 ce=1.5587 bbox=0.0568 giou=0.3640 time=2.5s
# train iter 1050/2123 loss=2.4733 ce=1.4527 bbox=0.0567 giou=0.3686 time=2.5s
# train iter 1100/2123 loss=2.4163 ce=1.4243 bbox=0.0541 giou=0.3608 time=2.5s
# train iter 1150/2123 loss=2.5253 ce=1.5110 bbox=0.0565 giou=0.3659 time=2.5s
# train iter 1200/2123 loss=2.5735 ce=1.5294 bbox=0.0578 giou=0.3777 time=2.5s
# train iter 1250/2123 loss=2.4998 ce=1.4883 bbox=0.0564 giou=0.3647 time=2.5s
# train iter 1300/2123 loss=2.5306 ce=1.5141 bbox=0.0563 giou=0.3676 time=2.5s
# train iter 1350/2123 loss=2.4989 ce=1.4677 bbox=0.0574 giou=0.3721 time=2.6s
# train iter 1400/2123 loss=2.5772 ce=1.5264 bbox=0.0580 giou=0.3805 time=2.5s
# train iter 1450/2123 loss=2.4551 ce=1.4314 bbox=0.0570 giou=0.3693 time=2.5s
# train iter 1500/2123 loss=2.5550 ce=1.5246 bbox=0.0570 giou=0.3726 time=2.6s
# train iter 1550/2123 loss=2.5013 ce=1.4847 bbox=0.0562 giou=0.3679 time=2.6s
# train iter 1600/2123 loss=2.4291 ce=1.4222 bbox=0.0566 giou=0.3619 time=2.4s
# train iter 1650/2123 loss=2.4599 ce=1.4396 bbox=0.0563 giou=0.3695 time=2.5s
# train iter 1700/2123 loss=2.5165 ce=1.5134 bbox=0.0555 giou=0.3628 time=2.5s
# train iter 1750/2123 loss=2.4875 ce=1.4901 bbox=0.0552 giou=0.3607 time=2.5s
# train iter 1800/2123 loss=2.5143 ce=1.4790 bbox=0.0576 giou=0.3736 time=2.8s
# train iter 1850/2123 loss=2.4920 ce=1.4878 bbox=0.0560 giou=0.3621 time=2.9s
# train iter 1900/2123 loss=2.5037 ce=1.5195 bbox=0.0556 giou=0.3530 time=2.7s
# train iter 1950/2123 loss=2.5501 ce=1.5312 bbox=0.0564 giou=0.3685 time=2.3s
# train iter 2000/2123 loss=2.5570 ce=1.5510 bbox=0.0555 giou=0.3642 time=2.6s
# train iter 2050/2123 loss=2.5347 ce=1.5209 bbox=0.0565 giou=0.3656 time=2.5s
# train iter 2100/2123 loss=2.5173 ce=1.5076 bbox=0.0565 giou=0.3637 time=2.5s
# val iter 50/90 loss=2.6689 ce=1.6376 bbox=0.0577 giou=0.3715 time=1.5s
# train: {'loss_total': 2.5042810639962236, 'loss_ce': 1.4844609279987444, 'loss_bbox': 0.05654780662676045, 'loss_giou': 0.3685405514134139}
# val:   {'loss_total': 2.7225576056374443, 'loss_ce': 1.6695388164785174, 'loss_bbox': 0.05888207318882147, 'loss_giou': 0.3793042153120041}
# saved epoch checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/epoch_010.pth.tar
#
# ====================================================================================================
# epoch 11/199
# train iter 50/2123 loss=2.3607 ce=1.3528 bbox=0.0554 giou=0.3656 time=3.0s
# train iter 100/2123 loss=2.2979 ce=1.3250 bbox=0.0528 giou=0.3545 time=2.4s
# train iter 150/2123 loss=2.3775 ce=1.3896 bbox=0.0546 giou=0.3575 time=2.3s
# train iter 200/2123 loss=2.3513 ce=1.3445 bbox=0.0556 giou=0.3644 time=2.4s
# train iter 250/2123 loss=2.4193 ce=1.4365 bbox=0.0545 giou=0.3553 time=2.4s
# train iter 300/2123 loss=2.3974 ce=1.4347 bbox=0.0529 giou=0.3491 time=2.4s
# train iter 350/2123 loss=2.3737 ce=1.3929 bbox=0.0541 giou=0.3551 time=2.5s
# train iter 400/2123 loss=2.4324 ce=1.4274 bbox=0.0556 giou=0.3636 time=2.4s
# train iter 450/2123 loss=2.4359 ce=1.4330 bbox=0.0551 giou=0.3637 time=2.5s
# train iter 500/2123 loss=2.4094 ce=1.4046 bbox=0.0552 giou=0.3645 time=2.4s
# train iter 550/2123 loss=2.4677 ce=1.4426 bbox=0.0573 giou=0.3693 time=2.5s
# train iter 600/2123 loss=2.3510 ce=1.3844 bbox=0.0534 giou=0.3498 time=2.6s
# train iter 650/2123 loss=2.4059 ce=1.4106 bbox=0.0545 giou=0.3615 time=2.8s
# train iter 700/2123 loss=2.4520 ce=1.4415 bbox=0.0555 giou=0.3665 time=2.6s
# train iter 750/2123 loss=2.4486 ce=1.4499 bbox=0.0555 giou=0.3607 time=2.5s
# train iter 800/2123 loss=2.4380 ce=1.4428 bbox=0.0553 giou=0.3595 time=2.5s
# train iter 850/2123 loss=2.3441 ce=1.3545 bbox=0.0541 giou=0.3595 time=2.6s
# train iter 900/2123 loss=2.5098 ce=1.4687 bbox=0.0572 giou=0.3776 time=2.4s
# train iter 950/2123 loss=2.4218 ce=1.4230 bbox=0.0552 giou=0.3614 time=2.5s
# train iter 1000/2123 loss=2.4757 ce=1.4542 bbox=0.0565 giou=0.3696 time=2.5s
# train iter 1050/2123 loss=2.3730 ce=1.4016 bbox=0.0537 giou=0.3516 time=2.5s
# train iter 1100/2123 loss=2.4730 ce=1.4581 bbox=0.0565 giou=0.3663 time=2.6s
# train iter 1150/2123 loss=2.3891 ce=1.4170 bbox=0.0535 giou=0.3523 time=2.5s
# train iter 1200/2123 loss=2.3985 ce=1.4042 bbox=0.0551 giou=0.3593 time=2.5s
# train iter 1250/2123 loss=2.4497 ce=1.4486 bbox=0.0558 giou=0.3610 time=2.5s
# train iter 1300/2123 loss=2.3280 ce=1.3569 bbox=0.0535 giou=0.3518 time=2.6s
# train iter 1350/2123 loss=2.4538 ce=1.4436 bbox=0.0559 giou=0.3653 time=2.6s
# train iter 1400/2123 loss=2.4177 ce=1.4178 bbox=0.0551 giou=0.3621 time=2.4s
# train iter 1450/2123 loss=2.4828 ce=1.4555 bbox=0.0576 giou=0.3697 time=2.4s
# train iter 1500/2123 loss=2.4718 ce=1.4810 bbox=0.0548 giou=0.3584 time=2.5s
# train iter 1550/2123 loss=2.4360 ce=1.4120 bbox=0.0565 giou=0.3707 time=2.4s
# train iter 1600/2123 loss=2.4776 ce=1.4626 bbox=0.0561 giou=0.3673 time=2.4s
# train iter 1650/2123 loss=2.4888 ce=1.4584 bbox=0.0568 giou=0.3733 time=2.4s
# train iter 1700/2123 loss=2.4588 ce=1.4609 bbox=0.0549 giou=0.3617 time=2.5s
# train iter 1750/2123 loss=2.3696 ce=1.3707 bbox=0.0549 giou=0.3622 time=2.5s
# train iter 1800/2123 loss=2.4155 ce=1.4276 bbox=0.0553 giou=0.3556 time=2.5s
# train iter 1850/2123 loss=2.4448 ce=1.4361 bbox=0.0556 giou=0.3654 time=2.4s
# train iter 1900/2123 loss=2.3894 ce=1.4086 bbox=0.0540 giou=0.3554 time=2.6s
# train iter 1950/2123 loss=2.4517 ce=1.4513 bbox=0.0548 giou=0.3633 time=2.7s
# train iter 2000/2123 loss=2.3833 ce=1.3876 bbox=0.0543 giou=0.3622 time=2.4s
# train iter 2050/2123 loss=2.4210 ce=1.4135 bbox=0.0554 giou=0.3652 time=2.4s
# train iter 2100/2123 loss=2.4228 ce=1.4197 bbox=0.0552 giou=0.3636 time=2.4s
# val iter 50/90 loss=2.5304 ce=1.5247 bbox=0.0562 giou=0.3623 time=1.6s
# train: {'loss_total': 2.4172767378842557, 'loss_ce': 1.41827730867473, 'loss_bbox': 0.05511933344043879, 'loss_giou': 0.36170138147744263}
# val:   {'loss_total': 2.645345691839854, 'loss_ce': 1.5984104447894627, 'loss_bbox': 0.05845144498679373, 'loss_giou': 0.3773390067948235}
# saved epoch checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/epoch_011.pth.tar
# saved best checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/best.pth.tar, val loss = 2.6453
#
# ====================================================================================================
# epoch 12/199
# train iter 50/2123 loss=2.2897 ce=1.3053 bbox=0.0550 giou=0.3547 time=3.1s
# train iter 100/2123 loss=2.3248 ce=1.3485 bbox=0.0536 giou=0.3540 time=2.6s
# train iter 150/2123 loss=2.2798 ce=1.3079 bbox=0.0540 giou=0.3511 time=2.6s
# train iter 200/2123 loss=2.3071 ce=1.3382 bbox=0.0536 giou=0.3504 time=2.5s
# train iter 250/2123 loss=2.2918 ce=1.3356 bbox=0.0523 giou=0.3474 time=2.5s
# train iter 300/2123 loss=2.3332 ce=1.3610 bbox=0.0534 giou=0.3526 time=2.5s
# ...
# train iter 2000/2123 loss=0.4539 ce=0.0580 bbox=0.0189 giou=0.1506 time=2.4s
# train iter 2050/2123 loss=0.4507 ce=0.0557 bbox=0.0188 giou=0.1506 time=2.4s
# train iter 2100/2123 loss=0.4437 ce=0.0556 bbox=0.0186 giou=0.1476 time=2.5s
# val iter 50/90 loss=4.8758 ce=3.9446 bbox=0.0509 giou=0.3383 time=1.6s
# train: {'loss_total': 0.4443893085672111, 'loss_ce': 0.05424302374133406, 'loss_bbox': 0.018464063267910953, 'loss_giou': 0.14891298438825532}
# val:   {'loss_total': 5.1425102578269115, 'loss_ce': 4.174947990311517, 'loss_bbox': 0.05255924682650301, 'loss_giou': 0.35238301273849276}
# saved epoch checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/epoch_195.pth.tar
#
# ====================================================================================================
# epoch 196/199
# train iter 50/2123 loss=0.4349 ce=0.0584 bbox=0.0178 giou=0.1438 time=2.8s
# train iter 100/2123 loss=0.4318 ce=0.0563 bbox=0.0176 giou=0.1437 time=2.5s
# train iter 150/2123 loss=0.4292 ce=0.0480 bbox=0.0182 giou=0.1450 time=2.5s
# train iter 200/2123 loss=0.4375 ce=0.0510 bbox=0.0179 giou=0.1485 time=2.4s
# train iter 250/2123 loss=0.4312 ce=0.0540 bbox=0.0179 giou=0.1438 time=2.4s
# train iter 300/2123 loss=0.4396 ce=0.0543 bbox=0.0181 giou=0.1474 time=2.5s
# train iter 350/2123 loss=0.4331 ce=0.0496 bbox=0.0181 giou=0.1465 time=2.5s
# train iter 400/2123 loss=0.4396 ce=0.0554 bbox=0.0182 giou=0.1466 time=2.4s
# train iter 450/2123 loss=0.4649 ce=0.0667 bbox=0.0189 giou=0.1518 time=2.5s
# train iter 500/2123 loss=0.4600 ce=0.0654 bbox=0.0188 giou=0.1503 time=2.5s
# train iter 550/2123 loss=0.4360 ce=0.0497 bbox=0.0181 giou=0.1479 time=2.5s
# train iter 600/2123 loss=0.4434 ce=0.0496 bbox=0.0186 giou=0.1504 time=2.4s
# train iter 650/2123 loss=0.4588 ce=0.0565 bbox=0.0189 giou=0.1540 time=2.5s
# train iter 700/2123 loss=0.4438 ce=0.0534 bbox=0.0185 giou=0.1488 time=2.4s
# train iter 750/2123 loss=0.4420 ce=0.0557 bbox=0.0185 giou=0.1468 time=2.4s
# train iter 800/2123 loss=0.4551 ce=0.0618 bbox=0.0189 giou=0.1495 time=2.4s
# train iter 850/2123 loss=0.4574 ce=0.0644 bbox=0.0186 giou=0.1501 time=2.4s
# train iter 900/2123 loss=0.4508 ce=0.0618 bbox=0.0184 giou=0.1485 time=2.4s
# train iter 950/2123 loss=0.4485 ce=0.0620 bbox=0.0183 giou=0.1474 time=2.4s
# train iter 1000/2123 loss=0.4559 ce=0.0593 bbox=0.0188 giou=0.1512 time=2.4s
# train iter 1050/2123 loss=0.4487 ce=0.0542 bbox=0.0184 giou=0.1513 time=2.5s
# train iter 1100/2123 loss=0.4503 ce=0.0615 bbox=0.0186 giou=0.1479 time=2.5s
# train iter 1150/2123 loss=0.4585 ce=0.0585 bbox=0.0186 giou=0.1534 time=2.4s
# train iter 1200/2123 loss=0.4678 ce=0.0661 bbox=0.0189 giou=0.1536 time=2.4s
# train iter 1250/2123 loss=0.4643 ce=0.0623 bbox=0.0191 giou=0.1532 time=2.5s
# train iter 1300/2123 loss=0.4494 ce=0.0485 bbox=0.0191 giou=0.1526 time=2.4s
# train iter 1350/2123 loss=0.4493 ce=0.0513 bbox=0.0189 giou=0.1517 time=2.4s
# train iter 1400/2123 loss=0.4586 ce=0.0558 bbox=0.0188 giou=0.1544 time=2.2s
# train iter 1450/2123 loss=0.4437 ce=0.0532 bbox=0.0186 giou=0.1488 time=2.5s
# train iter 1500/2123 loss=0.4302 ce=0.0436 bbox=0.0184 giou=0.1473 time=2.7s
# train iter 1550/2123 loss=0.4594 ce=0.0596 bbox=0.0189 giou=0.1526 time=2.5s
# train iter 1600/2123 loss=0.4670 ce=0.0615 bbox=0.0193 giou=0.1546 time=2.3s
# train iter 1650/2123 loss=0.4412 ce=0.0544 bbox=0.0184 giou=0.1474 time=2.3s
# train iter 1700/2123 loss=0.4388 ce=0.0472 bbox=0.0183 giou=0.1501 time=2.4s
# train iter 1750/2123 loss=0.4524 ce=0.0504 bbox=0.0192 giou=0.1530 time=2.5s
# train iter 1800/2123 loss=0.4442 ce=0.0457 bbox=0.0188 giou=0.1522 time=2.4s
# train iter 1850/2123 loss=0.4520 ce=0.0558 bbox=0.0185 giou=0.1518 time=2.3s
# train iter 1900/2123 loss=0.4468 ce=0.0491 bbox=0.0188 giou=0.1518 time=2.3s
# train iter 1950/2123 loss=0.4557 ce=0.0583 bbox=0.0188 giou=0.1517 time=2.4s
# train iter 2000/2123 loss=0.4640 ce=0.0637 bbox=0.0190 giou=0.1527 time=2.4s
# train iter 2050/2123 loss=0.4416 ce=0.0505 bbox=0.0186 giou=0.1491 time=2.5s
# train iter 2100/2123 loss=0.4486 ce=0.0524 bbox=0.0189 giou=0.1508 time=2.5s
# val iter 50/90 loss=4.8155 ce=3.8720 bbox=0.0517 giou=0.3425 time=1.6s
# train: {'loss_total': 0.44855387687149667, 'loss_ce': 0.05554172702640772, 'loss_bbox': 0.018589463256899613, 'loss_giou': 0.15003241695467168}
# val:   {'loss_total': 5.1117445985476175, 'loss_ce': 4.147624493969811, 'loss_bbox': 0.05251440393428008, 'loss_giou': 0.350774052242438}
# saved epoch checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/epoch_196.pth.tar
#
# ====================================================================================================
# epoch 197/199
# train iter 50/2123 loss=0.4232 ce=0.0382 bbox=0.0182 giou=0.1470 time=2.9s
# train iter 100/2123 loss=0.4441 ce=0.0503 bbox=0.0184 giou=0.1509 time=2.5s
# train iter 150/2123 loss=0.4444 ce=0.0575 bbox=0.0182 giou=0.1480 time=2.4s
# train iter 200/2123 loss=0.4251 ce=0.0381 bbox=0.0181 giou=0.1483 time=2.6s
# train iter 250/2123 loss=0.4323 ce=0.0464 bbox=0.0183 giou=0.1473 time=2.6s
# train iter 300/2123 loss=0.4214 ce=0.0469 bbox=0.0176 giou=0.1434 time=2.5s
# train iter 350/2123 loss=0.4288 ce=0.0466 bbox=0.0178 giou=0.1465 time=2.4s
# train iter 400/2123 loss=0.4248 ce=0.0465 bbox=0.0182 giou=0.1437 time=2.5s
# train iter 450/2123 loss=0.4311 ce=0.0456 bbox=0.0182 giou=0.1472 time=2.4s
# train iter 500/2123 loss=0.4384 ce=0.0420 bbox=0.0187 giou=0.1515 time=2.5s
# train iter 550/2123 loss=0.4424 ce=0.0563 bbox=0.0181 giou=0.1478 time=2.3s
# train iter 600/2123 loss=0.4494 ce=0.0517 bbox=0.0186 giou=0.1523 time=2.5s
# train iter 650/2123 loss=0.4313 ce=0.0463 bbox=0.0182 giou=0.1470 time=2.4s
# train iter 700/2123 loss=0.4326 ce=0.0503 bbox=0.0181 giou=0.1458 time=2.2s
# train iter 750/2123 loss=0.4349 ce=0.0427 bbox=0.0184 giou=0.1501 time=2.3s
# train iter 800/2123 loss=0.4147 ce=0.0441 bbox=0.0177 giou=0.1412 time=2.5s
# train iter 850/2123 loss=0.4187 ce=0.0441 bbox=0.0176 giou=0.1433 time=2.5s
# train iter 900/2123 loss=0.4459 ce=0.0660 bbox=0.0181 giou=0.1446 time=2.6s
# train iter 950/2123 loss=0.4499 ce=0.0537 bbox=0.0186 giou=0.1517 time=2.5s
# train iter 1000/2123 loss=0.4500 ce=0.0575 bbox=0.0187 giou=0.1496 time=2.4s
# train iter 1050/2123 loss=0.4502 ce=0.0542 bbox=0.0190 giou=0.1505 time=2.3s
# train iter 1100/2123 loss=0.4454 ce=0.0534 bbox=0.0187 giou=0.1493 time=2.5s
# train iter 1150/2123 loss=0.4192 ce=0.0447 bbox=0.0178 giou=0.1429 time=2.4s
# train iter 1200/2123 loss=0.4478 ce=0.0462 bbox=0.0190 giou=0.1533 time=2.4s
# train iter 1250/2123 loss=0.4427 ce=0.0447 bbox=0.0188 giou=0.1519 time=2.6s
# train iter 1300/2123 loss=0.4421 ce=0.0502 bbox=0.0186 giou=0.1494 time=2.4s
# train iter 1350/2123 loss=0.4529 ce=0.0537 bbox=0.0190 giou=0.1522 time=2.4s
# train iter 1400/2123 loss=0.4633 ce=0.0587 bbox=0.0189 giou=0.1551 time=2.4s
# train iter 1450/2123 loss=0.4310 ce=0.0440 bbox=0.0185 giou=0.1473 time=2.6s
# train iter 1500/2123 loss=0.4352 ce=0.0555 bbox=0.0180 giou=0.1448 time=2.5s
# train iter 1550/2123 loss=0.4390 ce=0.0451 bbox=0.0185 giou=0.1507 time=2.5s
# train iter 1600/2123 loss=0.4557 ce=0.0540 bbox=0.0188 giou=0.1538 time=2.4s
# train iter 1650/2123 loss=0.4447 ce=0.0575 bbox=0.0183 giou=0.1479 time=2.4s
# train iter 1700/2123 loss=0.4575 ce=0.0562 bbox=0.0188 giou=0.1537 time=2.3s
# train iter 1750/2123 loss=0.4501 ce=0.0596 bbox=0.0184 giou=0.1491 time=2.5s
# train iter 1800/2123 loss=0.4602 ce=0.0593 bbox=0.0189 giou=0.1532 time=2.4s
# train iter 1850/2123 loss=0.4500 ce=0.0651 bbox=0.0185 giou=0.1463 time=2.4s
# train iter 1900/2123 loss=0.4501 ce=0.0577 bbox=0.0186 giou=0.1496 time=2.4s
# train iter 1950/2123 loss=0.4603 ce=0.0637 bbox=0.0186 giou=0.1517 time=2.3s
# train iter 2000/2123 loss=0.4487 ce=0.0618 bbox=0.0185 giou=0.1472 time=2.4s
# train iter 2050/2123 loss=0.4686 ce=0.0700 bbox=0.0189 giou=0.1522 time=2.4s
# train iter 2100/2123 loss=0.4719 ce=0.0755 bbox=0.0190 giou=0.1506 time=2.6s
# val iter 50/90 loss=4.7960 ce=3.8695 bbox=0.0507 giou=0.3366 time=1.7s
# train: {'loss_total': 0.4421922746296486, 'loss_ce': 0.05247087707305244, 'loss_bbox': 0.018423940110784964, 'loss_giou': 0.14880084838091737}
# val:   {'loss_total': 5.087781357765198, 'loss_ce': 4.126675641536712, 'loss_bbox': 0.052246396595405205, 'loss_giou': 0.34993686758809617}
# saved epoch checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/epoch_197.pth.tar
#
# ====================================================================================================
# epoch 198/199
# train iter 50/2123 loss=0.4767 ce=0.0690 bbox=0.0194 giou=0.1554 time=2.8s
# train iter 100/2123 loss=0.4549 ce=0.0612 bbox=0.0188 giou=0.1500 time=2.4s
# train iter 150/2123 loss=0.4364 ce=0.0473 bbox=0.0183 giou=0.1489 time=2.5s
# train iter 200/2123 loss=0.4334 ce=0.0514 bbox=0.0180 giou=0.1459 time=2.4s
# train iter 250/2123 loss=0.4303 ce=0.0494 bbox=0.0179 giou=0.1455 time=2.3s
# train iter 300/2123 loss=0.4223 ce=0.0462 bbox=0.0178 giou=0.1434 time=2.4s
# train iter 350/2123 loss=0.4436 ce=0.0563 bbox=0.0184 giou=0.1476 time=2.5s
# train iter 400/2123 loss=0.4381 ce=0.0536 bbox=0.0181 giou=0.1469 time=2.4s
# train iter 450/2123 loss=0.4267 ce=0.0487 bbox=0.0181 giou=0.1438 time=2.4s
# train iter 500/2123 loss=0.4300 ce=0.0504 bbox=0.0179 giou=0.1450 time=2.3s
# train iter 550/2123 loss=0.4372 ce=0.0527 bbox=0.0181 giou=0.1471 time=2.2s
# train iter 600/2123 loss=0.4529 ce=0.0589 bbox=0.0185 giou=0.1507 time=2.2s
# train iter 650/2123 loss=0.4573 ce=0.0593 bbox=0.0190 giou=0.1515 time=2.6s
# train iter 700/2123 loss=0.4114 ce=0.0464 bbox=0.0175 giou=0.1388 time=2.3s
# train iter 750/2123 loss=0.4414 ce=0.0574 bbox=0.0181 giou=0.1467 time=2.5s
# train iter 800/2123 loss=0.4429 ce=0.0574 bbox=0.0183 giou=0.1470 time=2.6s
# train iter 850/2123 loss=0.4437 ce=0.0585 bbox=0.0180 giou=0.1477 time=2.6s
# train iter 900/2123 loss=0.4561 ce=0.0621 bbox=0.0184 giou=0.1509 time=2.4s
# train iter 950/2123 loss=0.4326 ce=0.0488 bbox=0.0183 giou=0.1461 time=2.5s
# train iter 1000/2123 loss=0.4441 ce=0.0533 bbox=0.0184 giou=0.1494 time=2.4s
# train iter 1050/2123 loss=0.4582 ce=0.0581 bbox=0.0189 giou=0.1528 time=2.4s
# train iter 1100/2123 loss=0.4510 ce=0.0681 bbox=0.0182 giou=0.1458 time=2.5s
# train iter 1150/2123 loss=0.4373 ce=0.0561 bbox=0.0180 giou=0.1457 time=2.6s
# train iter 1200/2123 loss=0.4412 ce=0.0516 bbox=0.0183 giou=0.1490 time=2.5s
# train iter 1250/2123 loss=0.4618 ce=0.0638 bbox=0.0189 giou=0.1518 time=2.7s
# train iter 1300/2123 loss=0.4586 ce=0.0614 bbox=0.0189 giou=0.1514 time=2.6s
# train iter 1350/2123 loss=0.4481 ce=0.0545 bbox=0.0188 giou=0.1499 time=2.5s
# train iter 1400/2123 loss=0.4387 ce=0.0517 bbox=0.0180 giou=0.1485 time=2.5s
# train iter 1450/2123 loss=0.4697 ce=0.0777 bbox=0.0189 giou=0.1486 time=2.5s
# train iter 1500/2123 loss=0.4365 ce=0.0547 bbox=0.0182 giou=0.1455 time=2.5s
# train iter 1550/2123 loss=0.4493 ce=0.0541 bbox=0.0185 giou=0.1514 time=2.5s
# train iter 1600/2123 loss=0.4353 ce=0.0536 bbox=0.0181 giou=0.1455 time=2.6s
# train iter 1650/2123 loss=0.4635 ce=0.0720 bbox=0.0185 giou=0.1496 time=2.3s
# train iter 1700/2123 loss=0.4245 ce=0.0463 bbox=0.0181 giou=0.1439 time=2.8s
# train iter 1750/2123 loss=0.4474 ce=0.0561 bbox=0.0185 giou=0.1494 time=2.7s
# train iter 1800/2123 loss=0.4517 ce=0.0555 bbox=0.0189 giou=0.1508 time=2.6s
# train iter 1850/2123 loss=0.4683 ce=0.0630 bbox=0.0193 giou=0.1545 time=2.5s
# train iter 1900/2123 loss=0.4681 ce=0.0660 bbox=0.0191 giou=0.1534 time=2.5s
# train iter 1950/2123 loss=0.4423 ce=0.0545 bbox=0.0185 giou=0.1477 time=2.6s
# train iter 2000/2123 loss=0.4804 ce=0.0796 bbox=0.0191 giou=0.1527 time=2.5s
# train iter 2050/2123 loss=0.4514 ce=0.0520 bbox=0.0188 giou=0.1527 time=2.4s
# train iter 2100/2123 loss=0.4488 ce=0.0500 bbox=0.0188 giou=0.1523 time=2.5s
# val iter 50/90 loss=4.8542 ce=3.9065 bbox=0.0517 giou=0.3446 time=1.7s
# train: {'loss_total': 0.446427299582728, 'loss_ce': 0.05692870956994733, 'loss_bbox': 0.01844727993494025, 'loss_giou': 0.14863109507203606}
# val:   {'loss_total': 5.103060430950588, 'loss_ce': 4.132030182414585, 'loss_bbox': 0.05266136299404833, 'loss_giou': 0.3538617168863614}
# saved epoch checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/epoch_198.pth.tar
#
# ====================================================================================================
# epoch 199/199
# train iter 50/2123 loss=0.4648 ce=0.0759 bbox=0.0184 giou=0.1485 time=2.9s
# train iter 100/2123 loss=0.4535 ce=0.0598 bbox=0.0186 giou=0.1504 time=2.4s
# train iter 150/2123 loss=0.4452 ce=0.0536 bbox=0.0186 giou=0.1492 time=2.4s
# train iter 200/2123 loss=0.4256 ce=0.0390 bbox=0.0183 giou=0.1476 time=2.3s
# train iter 250/2123 loss=0.4152 ce=0.0442 bbox=0.0175 giou=0.1418 time=2.3s
# train iter 300/2123 loss=0.4377 ce=0.0476 bbox=0.0187 giou=0.1482 time=2.5s
# train iter 350/2123 loss=0.4703 ce=0.0693 bbox=0.0190 giou=0.1531 time=2.6s
# train iter 400/2123 loss=0.4339 ce=0.0502 bbox=0.0182 giou=0.1464 time=2.7s
# train iter 450/2123 loss=0.4399 ce=0.0508 bbox=0.0184 giou=0.1485 time=2.7s
# train iter 500/2123 loss=0.4385 ce=0.0556 bbox=0.0180 giou=0.1465 time=2.5s
# train iter 550/2123 loss=0.4460 ce=0.0552 bbox=0.0185 giou=0.1491 time=2.4s
# train iter 600/2123 loss=0.4293 ce=0.0462 bbox=0.0181 giou=0.1464 time=2.4s
# train iter 650/2123 loss=0.4213 ce=0.0492 bbox=0.0177 giou=0.1418 time=2.4s
# train iter 700/2123 loss=0.4201 ce=0.0504 bbox=0.0175 giou=0.1411 time=2.5s
# train iter 750/2123 loss=0.4596 ce=0.0536 bbox=0.0191 giou=0.1553 time=2.3s
# train iter 800/2123 loss=0.4421 ce=0.0488 bbox=0.0186 giou=0.1502 time=2.4s
# train iter 850/2123 loss=0.4476 ce=0.0545 bbox=0.0186 giou=0.1500 time=2.5s
# train iter 900/2123 loss=0.4413 ce=0.0507 bbox=0.0185 giou=0.1490 time=2.6s
# train iter 950/2123 loss=0.4383 ce=0.0422 bbox=0.0186 giou=0.1514 time=2.5s
# train iter 1000/2123 loss=0.4317 ce=0.0465 bbox=0.0180 giou=0.1475 time=2.4s
# train iter 1050/2123 loss=0.4208 ce=0.0464 bbox=0.0176 giou=0.1432 time=2.6s
# train iter 1100/2123 loss=0.4339 ce=0.0535 bbox=0.0180 giou=0.1452 time=2.6s
# train iter 1150/2123 loss=0.4464 ce=0.0609 bbox=0.0183 giou=0.1470 time=2.4s
# train iter 1200/2123 loss=0.4345 ce=0.0504 bbox=0.0181 giou=0.1467 time=2.5s
# train iter 1250/2123 loss=0.4557 ce=0.0631 bbox=0.0182 giou=0.1508 time=2.4s
# train iter 1300/2123 loss=0.4504 ce=0.0623 bbox=0.0184 giou=0.1480 time=2.4s
# train iter 1350/2123 loss=0.4380 ce=0.0660 bbox=0.0175 giou=0.1422 time=2.5s
# train iter 1400/2123 loss=0.4521 ce=0.0557 bbox=0.0185 giou=0.1520 time=2.4s
# train iter 1450/2123 loss=0.4734 ce=0.0675 bbox=0.0193 giou=0.1547 time=2.4s
# train iter 1500/2123 loss=0.4682 ce=0.0756 bbox=0.0187 giou=0.1496 time=2.5s
# train iter 1550/2123 loss=0.4600 ce=0.0743 bbox=0.0182 giou=0.1473 time=2.4s
# train iter 1600/2123 loss=0.4373 ce=0.0563 bbox=0.0181 giou=0.1451 time=2.5s
# train iter 1650/2123 loss=0.4408 ce=0.0518 bbox=0.0186 giou=0.1479 time=2.5s
# train iter 1700/2123 loss=0.4395 ce=0.0522 bbox=0.0184 giou=0.1476 time=2.5s
# train iter 1750/2123 loss=0.4341 ce=0.0635 bbox=0.0179 giou=0.1404 time=2.5s
# train iter 1800/2123 loss=0.4625 ce=0.0642 bbox=0.0189 giou=0.1520 time=2.4s
# train iter 1850/2123 loss=0.4321 ce=0.0445 bbox=0.0186 giou=0.1473 time=2.5s
# train iter 1900/2123 loss=0.4433 ce=0.0510 bbox=0.0185 giou=0.1498 time=2.4s
# train iter 1950/2123 loss=0.4549 ce=0.0580 bbox=0.0187 giou=0.1516 time=2.5s
# train iter 2000/2123 loss=0.4411 ce=0.0552 bbox=0.0184 giou=0.1469 time=2.5s
# train iter 2050/2123 loss=0.4459 ce=0.0500 bbox=0.0187 giou=0.1512 time=2.4s
# train iter 2100/2123 loss=0.4347 ce=0.0502 bbox=0.0183 giou=0.1464 time=2.4s
# val iter 50/90 loss=4.7955 ce=3.8591 bbox=0.0510 giou=0.3407 time=1.7s
# train: {'loss_total': 0.44308634588755474, 'loss_ce': 0.05519892000652467, 'loss_bbox': 0.018366771088180484, 'loss_giou': 0.1480267851653382}
# val:   {'loss_total': 5.056197330686781, 'loss_ce': 4.086807885434893, 'loss_bbox': 0.05249437780843841, 'loss_giou': 0.35345878087812}
# saved epoch checkpoint: /zpool/vladlab/data_drive/geogaze_data/cornet_coco_bboxes/cornetz/identification_critical_v2/epoch_199.pth.tar
# done
