# %%
import os, re, math, random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, Subset

import torchvision.transforms as T

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", DEVICE)
# Out:
# Device: cuda

# %%
# DATA PATHS
PAIRS_DIR  = Path("/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs")

MASK_SIDE = "L"   # "L" or "R"
if MASK_SIDE == "L":
    MASKS_DIR = Path("/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks")
else:
    MASKS_DIR = Path("/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/right_masks")


OUTPUT_DIR = Path("/zpool/vladlab/data_drive/geogaze_data/cornetS_openimages/geogaze_task/corents_identification_v5")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# CORNET REPO + CHECKPOINT
CORN_NET_REPO = Path("/zpool/vladlab/active_drive/omaltz/git_repos/CORnet")  # your local clone

CKPT_PATH = Path("/zpool/vladlab/data_drive/geogaze_data/cornetS_openimages/training_v5_images/weights_identification/best_checkpoint.pth.tar")

# TRAINING CONFIG
PAIR_MIDS = ["bc_gc"]     # list, e.g. ["bc_gc", "bc_bs"]
IMG_SIZE = 224
MODEL_TAG = f"cornetIDEN_mask{MASK_SIDE}_{'-'.join(PAIR_MIDS)}"
RUN_DIR = OUTPUT_DIR / MODEL_TAG
RUN_DIR.mkdir(parents=True, exist_ok=True)



SEED = 1
EPOCHS = 500
BATCH_SIZE = 32
NUM_WORKERS = 8

VAL_SPLIT = 0.2
LR = 0.01
MOMENTUM = 0.9
WEIGHT_DECAY = 1e-4
STEP_SIZE = 10

THRESHOLD = 0.2
POS_WEIGHT = 25   

USE_AMP = (DEVICE.type == "cuda")

print("MASK_SIDE:", MASK_SIDE)
print("PAIR_MIDS:", PAIR_MIDS)
print("CKPT_PATH:", CKPT_PATH)
# Out:
# MASK_SIDE: L
# PAIR_MIDS: ['bc_gc']
# CKPT_PATH: /zpool/vladlab/data_drive/geogaze_data/cornetS_openimages/training_v5_images/weights_identification/best_checkpoint.pth.tar

# %%
def set_seed(s):
    random.seed(s)
    np.random.seed(s)
    torch.manual_seed(s)
    torch.cuda.manual_seed_all(s)

set_seed(SEED)

# %% [markdown]
# Finds all pair and mask stimulus eligable for the head training stimulus

# %%
allowed_mids = [m.strip() for m in PAIR_MIDS if m.strip()]
mid_union = "|".join(re.escape(m) for m in allowed_mids)
PAIR_RE = re.compile(rf"^pair_({mid_union})_(\d+)\.png$")

def mask_path(side, mid, id_):
    p = MASKS_DIR / f"mask{side}_{mid}_{id_}.png"
    return p if p.is_file() else None

def collect_items(side):
    items, skipped = [], 0
    for fn in os.listdir(PAIRS_DIR):
        m = PAIR_RE.match(fn)
        if not m:
            continue
        mid, id_ = m.group(1), m.group(2)
        img_p = PAIRS_DIR / fn
        msk_p = mask_path(side, mid, id_)
        if msk_p is None:
            skipped += 1
            continue
        items.append((img_p, msk_p, mid, id_))
    items.sort(key=lambda x: (x[2], int(x[3])))
    if skipped:
        print(f"[WARN] Skipped {skipped} image(s) with no matching mask{side}.")
    print(f"[INFO] Found {len(items)} (image, mask{side}) pairs across MIDs: {allowed_mids}")
    return items

all_items = collect_items(MASK_SIDE)
assert len(all_items) > 0, "No (image, mask) pairs found."
print("Example item:", all_items[0])
# Out:
# [INFO] Found 500 (image, maskL) pairs across MIDs: ['bc_gc']
# Example item: (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0001.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0001.png'), 'bc_gc', '0001')

# %% [markdown]
# Sets ImageNet transforms (resize, tensor, normalize) for train and validation images
# Defines how mask images are loaded and converted into binary tensors `(1, H, W)`
# Implements a custom Dataset that returns `(image, mask, id)` for each sample
# splits the data into train and validation sets using a fixed random seed
# Creates PyTorch DataLoader for batching and shuffling
# SANITY Check to verify shapes and mask values

# %%
# ImageNet normalization (matches typical CORnet training; your training notebook used this)
train_tfms = T.Compose([
    T.Resize((IMG_SIZE, IMG_SIZE)),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225]),
])

val_tfms = T.Compose([
    T.Resize((IMG_SIZE, IMG_SIZE)),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225]),
])

# Convert a mask image into a binary tensor (1 = object, 0 = background)
# Assumes the object is encoded as black (pixel value 0)
def load_mask_binary(path: Path):
    """
    Returns mask as float tensor shape (1,H,W) with values in {0,1}.

    IMPORTANT:
    This version matches your earlier segmentation script:
      foreground = 1 where pixel == 0 (black)
    If your masks have foreground in white (255), switch to: (m > 0)
    """
    m = np.asarray(Image.open(path).convert("L"), dtype=np.uint8)
    m = (m == 0).astype(np.float32)   # <-- flip if your mask encoding differs
    return torch.from_numpy(m).unsqueeze(0)

# PyTorch Dataset for paired stimulus images and segmentation masks.
# For each item, this dataset loads a stimulus image and its corresponding
# binary mask, applies ImageNet transforms to the image, converts the
# mask into a (1, H, W) tensor, and returns both along with a unique identifier
# string (mid_id). This dataset is used to feed image–mask pairs into the
# training and validation DataLoaders.
class PairMaskDataset(Dataset):
    # Initialize the dataset with a list of (image_path, mask_path, mid, id) items
    # and the image transforms to apply
    def __init__(self, items, tfms):
        self.items = items
        self.tfms = tfms
    
    # Return the total number of image–mask pairs in the dataset
    def __len__(self):
        return len(self.items)
    
    # Load and return one sample:transformed RGB image tensor, binary mask tensor, identifier string (mid_id)
    def __getitem__(self, i):
        img_p, msk_p, mid, id_ = self.items[i]
        img = Image.open(img_p).convert("RGB")
        x = self.tfms(img)  # (3,224,224)
        y = load_mask_binary(msk_p)  # (1,224,224)
        return x, y, f"{mid}_{id_}"

# Split train/val at random defined by seed 
rng = random.Random(SEED)
shuf = all_items[:]
rng.shuffle(shuf)
n_val = max(1, int(len(shuf) * VAL_SPLIT))
val_items = shuf[:n_val]
trn_items = shuf[n_val:]

print(f"[INFO] Train: {len(trn_items)} | Val: {len(val_items)}")

trainloader = DataLoader(PairMaskDataset(trn_items, train_tfms),
                         batch_size=BATCH_SIZE, shuffle=True,
                         num_workers=NUM_WORKERS, pin_memory=True)

valloader = DataLoader(PairMaskDataset(val_items, val_tfms),
                       batch_size=BATCH_SIZE, shuffle=False,
                       num_workers=NUM_WORKERS, pin_memory=True)

# Sanity check batch
xb, yb, ids = next(iter(trainloader))
print("x:", xb.shape, xb.dtype)
print("y:", yb.shape, yb.dtype, "unique:", torch.unique(yb))
print("ids[0]:", ids[0])
# Out:
# [INFO] Train: 400 | Val: 100
# x: torch.Size([32, 3, 224, 224]) torch.float32
# y: torch.Size([32, 1, 224, 224]) torch.float32 unique: tensor([0., 1.])
# ids[0]: bc_gc_0409

# %%
#getting standard cornet z from gitrepos local clone 

import sys
sys.path.insert(0, str(CORN_NET_REPO))

import cornet
print("Imported cornet from:", cornet.__file__)
# Out:
# Imported cornet from: /zpool/vladlab/active_drive/omaltz/git_repos/CORnet/cornet/__init__.py

# %%
## LOADING CORNET and REPLACING last classifier layer with the object identification length 80 classifier layer
## build a CORnet-Z model, swap its LAST Linear layer to have 80 or 440 for openimage outputs,
## then load a checkpoint into it and put it in eval mode.

def replace_last_linear(model: nn.Module, out_features: int):
    """
    Find the LAST nn.Linear layer anywhere inside model by walking through all submodules,
    replace it with a new nn.Linear that has the same input size but out_features outputs,
    and return:
      - the updated model
      - the input feature size of the replaced layer (in_features)
      - the full module name of the replaced layer (so we know what got swapped)
    """
    # Track the *most recent Linear layer we see as we iterate
    # After the loop, this will represent the "last" Linear encountered
    last_name, last_linear = None, None
    # Walk through every module in the model including nested ones,
    # keeping the name + module object whenever we see an nn.Linear.
    for name, module in model.named_modules():
        if isinstance(module, nn.Linear):
            last_name, last_linear = name, module

    # If we never found any Linear layer, we can't replace it.
    if last_linear is None:
        raise RuntimeError("No nn.Linear found in model.")
    
    # We need to locate the parent object that contains this layer so we can replace it.
    parent = model
    parts = last_name.split(".")

    # Walk down the attribute chain to get the parent module.
    for p in parts[:-1]:
        parent = getattr(parent, p)

    # Replace the last Linear layer with a new Linear layer with same number of input features as the old layer new number of output features = out_features (80 classes)    
    setattr(parent, parts[-1], nn.Linear(last_linear.in_features, out_features))
    return model, last_linear.in_features, last_name

# Build CORnet-Z so  pretrained=False means start from random initialization (no ImageNet weights)
corn = cornet.cornet_s(pretrained=False)

# run the function that replaces the last linearlayer so the model outputs 80 numbers per image
corn, in_features, last_name = replace_last_linear(corn, out_features=433)
print(f"Replaced {last_name} with Linear({in_features} -> not 80 amymore now 440,433)")

corn = corn.to(DEVICE)

# Load checkpoint
##map_location is something to makes sure weights load onto gpu correctly.
ckpt = torch.load(CKPT_PATH, map_location=DEVICE)

if isinstance(ckpt, dict) and "model_state" in ckpt:
    state = ckpt["model_state"]
elif isinstance(ckpt, dict) and "state_dict" in ckpt:
    state = ckpt["state_dict"]
else:
    state = ckpt

missing, unexpected = corn.load_state_dict(state, strict=False)
# Report what happened during loading
print("Loaded ckpt:", CKPT_PATH)
print("Missing keys:", len(missing)) # parameters the model expected but checkpoint didn't have
print("Unexpected keys:", len(unexpected)) #parameters in checkpoint that don't exist in the model

#turns off 
corn.eval()

####OKAY AT THIS POINT WE HAVE THE CORNETZ IDENTIFATION MODEL LOADED WITH ITS CHECKPOINTS
# Out:
# Replaced module.decoder.linear with Linear(512 -> not 80 amymore now 440,433)
# Loaded ckpt: /zpool/vladlab/data_drive/geogaze_data/cornetS_openimages/training_v5_images/weights_identification/best_checkpoint.pth.tar
# Missing keys: 0
# Unexpected keys: 0
# DataParallel(
#   (module): Sequential(
#     (V1): Sequential(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nonlin1): ReLU(inplace=True)
#       (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nonlin2): ReLU(inplace=True)
#       (output): Identity()
#     )
#     (V2): CORblock_S(
#       (conv_input): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (skip): Conv2d(128, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (norm_skip): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (nonlin1): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (nonlin2): ReLU(inplace=True)
#       (conv3): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (nonlin3): ReLU(inplace=True)
#       (output): Identity()
#       (norm1_0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2_0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3_0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm1_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3_1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (V4): CORblock_S(
#       (conv_input): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (skip): Conv2d(256, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (norm_skip): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (nonlin1): ReLU(inplace=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (nonlin2): ReLU(inplace=True)
#       (conv3): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (nonlin3): ReLU(inplace=True)
#       (output): Identity()
#       (norm1_0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2_0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3_0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm1_1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2_1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm1_2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2_2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm1_3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2_3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3_3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (IT): CORblock_S(
#       (conv_input): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (skip): Conv2d(512, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (norm_skip): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (nonlin1): ReLU(inplace=True)
#       (conv2): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (nonlin2): ReLU(inplace=True)
#       (conv3): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (nonlin3): ReLU(inplace=True)
#       (output): Identity()
#       (norm1_0): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2_0): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3_0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm1_1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2_1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (decoder): Sequential(
#       (avgpool): AdaptiveAvgPool2d(output_size=1)
#       (flatten): Flatten()
#       (linear): Linear(in_features=512, out_features=433, bias=True)
#       (output): Identity()
#     )
#   )
# )

# %%
print(corn)
# Out:
# DataParallel(
#   (module): Sequential(
#     (V1): Sequential(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nonlin1): ReLU(inplace=True)
#       (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (nonlin2): ReLU(inplace=True)
#       (output): Identity()
#     )
#     (V2): CORblock_S(
#       (conv_input): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (skip): Conv2d(128, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (norm_skip): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (nonlin1): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (nonlin2): ReLU(inplace=True)
#       (conv3): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (nonlin3): ReLU(inplace=True)
#       (output): Identity()
#       (norm1_0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2_0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3_0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm1_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3_1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (V4): CORblock_S(
#       (conv_input): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (skip): Conv2d(256, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (norm_skip): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (nonlin1): ReLU(inplace=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (nonlin2): ReLU(inplace=True)
#       (conv3): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (nonlin3): ReLU(inplace=True)
#       (output): Identity()
#       (norm1_0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2_0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3_0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm1_1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2_1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm1_2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2_2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm1_3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2_3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3_3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (IT): CORblock_S(
#       (conv_input): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (skip): Conv2d(512, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (norm_skip): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (nonlin1): ReLU(inplace=True)
#       (conv2): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (nonlin2): ReLU(inplace=True)
#       (conv3): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (nonlin3): ReLU(inplace=True)
#       (output): Identity()
#       (norm1_0): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2_0): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3_0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm1_1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2_1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (decoder): Sequential(
#       (avgpool): AdaptiveAvgPool2d(output_size=1)
#       (flatten): Flatten()
#       (linear): Linear(in_features=512, out_features=433, bias=True)
#       (output): Identity()
#     )
#   )
# )

# %%
#####BEGINING OF REPLACING THE LENGTH 80 or 440 or 433 CLASSIFERI HEAD WITH TASK HEAD

# Unwrap DataParallel (get the real CORnet model)
base = corn.module if isinstance(corn, nn.DataParallel) else corn
base = base.to(DEVICE)

# %%
# Remove the classifier by deleting the last child
#    This drops: global avg pool + flatten + linear classifier
#    What remains is the CORnet visual encoder (V1 → V2 → V4 → IT)

#  Converts the model’s top top top modules into a list called children like trees 
#  Drops the last child module, which contains the pooling and linear classifier
#  Wraps the remaining modules into a new `nn.Sequential` called `encoder`
#  Moves the encoder to the correct device and sets it to evaluation mode
children = list(base.children())
encoder = nn.Sequential(*children[:-1]).to(DEVICE)
encoder.eval()
# Out:
# Sequential(
#   (0): Sequential(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (nonlin1): ReLU(inplace=True)
#     (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (nonlin2): ReLU(inplace=True)
#     (output): Identity()
#   )
#   (1): CORblock_S(
#     (conv_input): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (skip): Conv2d(128, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (norm_skip): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (nonlin1): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (nonlin2): ReLU(inplace=True)
#     (conv3): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (nonlin3): ReLU(inplace=True)
#     (output): Identity()
#     (norm1_0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm2_0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm3_0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm1_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm2_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm3_1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (2): CORblock_S(
#     (conv_input): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (skip): Conv2d(256, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (norm_skip): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv1): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (nonlin1): ReLU(inplace=True)
#     (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (nonlin2): ReLU(inplace=True)
#     (conv3): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (nonlin3): ReLU(inplace=True)
#     (output): Identity()
#     (norm1_0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm2_0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm3_0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm1_1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm2_1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm3_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm1_2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm2_2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm3_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm1_3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm2_3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm3_3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (3): CORblock_S(
#     (conv_input): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (skip): Conv2d(512, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (norm_skip): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv1): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (nonlin1): ReLU(inplace=True)
#     (conv2): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (nonlin2): ReLU(inplace=True)
#     (conv3): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (nonlin3): ReLU(inplace=True)
#     (output): Identity()
#     (norm1_0): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm2_0): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm3_0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm1_1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm2_1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (norm3_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )

# %%
#show me the child that was removed 
print("Removed last child:")
print(children[-1])
# Out:
# Removed last child:
# Sequential(
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (flatten): Flatten()
#   (linear): Linear(in_features=512, out_features=433, bias=True)
#   (output): Identity()
# )

# %%
# mask head
# It takes the feature map produced by CORnet
# Uses a 1×1 convolution basically it looks at one pixel at a time and looks at all feature channels at that location with once channe; being one ouput information [0 oe 1] (but will really be using the prediction map)
# The output is a raw mask score map

# this head looks at last layer features annd predicts where object is on image.
class mask_head(nn.Module):
    #inchann is the nuber of channeels in the feautre map, will be 512 coning out of IT
    def __init__(self, in_ch: int):
        #this objects is a subclass of (meaning kind of) nn.Module, so I am initailizing the parent classs
        super().__init__()
        #for every location takes in 512-dimention vector and outputs one channel (one number)
        ##at each space conv2d computes a weighted sun
        self.proj = nn.Conv2d(in_ch, 1, kernel_size=1)
        ##Conv2d builds a weight tensor with shape [1, 512, 1, 1], bias tensor with shape[1], 
        ## if the input is [B, 512, H, W], so at every (h,w) there is a 512 vector, so our output is = suming the vector with wrights aand bias for each space
    def forward(self, feats: torch.Tensor) -> torch.Tensor:
        #feats is the tesor of 
        #doing the math from nn.conv  to get one mask logit per pixel
        logits = self.proj(feats)  # [B, 1, H', W']
        #interloap function upsamples into  into size 224x 224 to match masks again using bilinear interpolation (standard according to shat, align corners is standard according to chat) 
        logits = F.interpolate(logits, size=(224, 224), mode="bilinear", align_corners= False)
        return logits

# %%
#See how many features are the output of the encoder so make them the number of features that nee to be the input for the mask head

with torch.no_grad():
    dummy = torch.zeros(1, 3, 224, 224, device=DEVICE)
    feats = encoder(dummy)
    in_ch = feats.shape[1]

print("Encoder feature shape:", feats.shape)

head = mask_head(in_ch).to(DEVICE)
# Out:
# Encoder feature shape: torch.Size([1, 512, 7, 7])

# %%
# 5) Literally puting the mask head on the encoder in one model. 
# cornetmaskmodel has two parts: the CORnet encoder (extracts visual features), the mask head turns features into a pixel-level mask

class CORnetMaskModel(nn.Module):
    def __init__(self, encoder: nn.Module, head: nn.Module):
        super().__init__()
        self.encoder = encoder
        self.head = head
#forward function does the thing but the head is not trained yet you are defining the class of the thing you are making 
#    the image is passed through the encoder to get feature maps
#    the feature maps are passed through the mask head to produce mask logits
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        feats = self.encoder(x)      # [B, C, H', W']
        logits = self.head(feats)    # [B, 1, 224, 224]
        return logits

model = CORnetMaskModel(encoder, head).to(DEVICE)

# %%
# Freeze encoder so there is no training, train only the head
#Disables gradient updates for all encoder parameters 
for p in model.encoder.parameters():
    p.requires_grad = False
#Enables gradient updates for all mask head parameters
for p in model.head.parameters():
    p.requires_grad = True

# %%
# Report parameter counts FOR SANITY Trainable feaures should be input size of head
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
total = sum(p.numel() for p in model.parameters())
print(f"Trainable params: {trainable:,} / {total:,}")
# Out:
# Trainable params: 513 / 52,904,129

# %%
#forward pass shape for sanity to check that putint int two dummy images gets out two mask with one number of channels (0,1) of size 224 x 224
with torch.no_grad():
    x = torch.zeros(2, 3, 224, 224, device=DEVICE)
    y = model(x)
    print("Output mask logits shape:", y.shape)
# Out:
# Output mask logits shape: torch.Size([2, 1, 224, 224])

# %%
# Resizes images to 224×224 which they already are but safety step 
# Converts RGB images to tensors
# Normalizes them using ImageNet statistics as the cornet docs say 
img_tf = T.Compose([
    T.Resize((IMG_SIZE, IMG_SIZE)),   # safe even if already 224x224
    T.ToTensor(),                     # [0,1], shape [3,H,W]
    T.Normalize(mean=[0.485, 0.456, 0.406],
                std =[0.229, 0.224, 0.225]),
])

# - Mask preprocessing
#   Loads mask images as grayscale
#   Resizes them with nearest-neighbor interpolation
#  Converts them into **binary masks** where black pixels = object (1) and white pixels = background (0)
#   Outputs masks in shape `[1, 224, 224]`
def load_mask_as_binary_1chw(mask_path):
    m = Image.open(mask_path).convert("L")     # grayscale 0..255
    m = m.resize((IMG_SIZE, IMG_SIZE), resample=Image.NEAREST)
    m = np.array(m, dtype=np.uint8)           # [H,W], 0..255
    m = (m < 128).astype(np.float32)          # black->1, white->0
    m = torch.from_numpy(m).unsqueeze(0)      # [1,H,W]
    return m

# 2) Dataset
# loads one image–mask pair at a time
# Returns a normalized image tensor and its corresponding binary mask
# Uses the list of valid `(image, mask)` pairs collected earlier
class PairMaskDataset(Dataset):
    """
    Returns:
      image: FloatTensor [3,224,224] (normalized)
      mask:  FloatTensor [1,224,224] (0/1, where 1 = object)
    """
    def __init__(self, items, img_transform):
        self.items = items
        self.img_transform = img_transform

    def __len__(self):
        return len(self.items)

    def __getitem__(self, idx):
        img_path, mask_path, mid, id_ = self.items[idx]

        # Load RGB image
        img = Image.open(img_path).convert("RGB")
        img = self.img_transform(img)

        # Load + binarize mask (black = 1, white = 0)
        mask = load_mask_as_binary_1chw(mask_path)

        return img, mask

dataset = PairMaskDataset(all_items, img_tf)

#  Deterministically shuffles the dataset using `SEED the slits the data into training and validation subsets based on `VAL_SPLIT`
#  prints dataset sizes for verification and should be 500 total 400 train 100 validation 
n = len(dataset)
idxs = list(range(n))
random.Random(SEED).shuffle(idxs)

n_val = int(round(n * VAL_SPLIT))
val_idxs = idxs[:n_val]
train_idxs = idxs[n_val:]

train_ds = Subset(dataset, train_idxs)
val_ds   = Subset(dataset, val_idxs)

print(f"Total: {n} , Train: {len(train_ds)}, Val: {len(val_ds)}")

# DataLoaders
train_loader = DataLoader(
    train_ds,
    batch_size=BATCH_SIZE,
    shuffle=True,             # shuffle each epoch
    num_workers=NUM_WORKERS,
    pin_memory=(DEVICE.type == "cuda"),
)

val_loader = DataLoader(
    val_ds,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=(DEVICE.type == "cuda"),
)
print(all_items)
# Out:
# Total: 500 , Train: 400, Val: 100
# [(PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0001.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0001.png'), 'bc_gc', '0001'), (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0013.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0013.png'), 'bc_gc', '0013'), (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0025.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0025.png'), 'bc_gc', '0025'), (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0037.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0037.png'), 'bc_gc', '0037'), (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0049.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0049.png'), 'bc_gc', '0049'), (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0061.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0061.png'), 'bc_gc', '0061'), (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0073.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0073.png'), 'bc_gc', '0073'), (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0085.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0085.png'), 'bc_gc', '0085'), (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0097.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0097.png'), 'bc_gc', '0097'), (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0109.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0109.png'), 'bc_gc', '0109'), (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0121.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0121.png'), 'bc_gc', '0121'), (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0133.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0133.png'), 'bc_gc', '0133'), (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0145.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0145.png'), 'bc_gc', '0145'), (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0157.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0157.png'), 'bc_gc', '0157'), (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0169.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0169.png'), 'bc_gc', '0169'), (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0181.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0181.png'), 'bc_gc', '0181'), (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0193.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0193.png'), 'bc_gc', '0193'), (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0205.png'), PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/left_masks/maskL_bc_gc_0205.png'), 'bc_gc', '0205'), (PosixPath('/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/pairs/pair_bc_gc_0217.png ...

# %%
# Model outputs LOGITS (not probabilities)
# Masks are 0/1 with shape [B, 1, 224, 224]
# BCEWithLogitsLoss applies sigmoid internally
criterion = nn.BCEWithLogitsLoss()
#defines loss function and is a typical loss function for binary segmentation. Each pixel is binarily separatied in object or nonobject (be we are using pred mask anyway)

# %%
# Only train the head parameters
# applied the parameters defined above to learning as in cornet docs
#   learning rate (step size for updates) and suggested for fast training 
#   momentum helps stabilize and accelerate learning
#   weight decay is regularization to reduce overfitting
optimizer = torch.optim.SGD(
    model.head.parameters(),
    lr=LR,
    momentum=MOMENTUM,
    weight_decay=WEIGHT_DECAY,
)

# %%
# TRAINING LOOP of mask head 
# set best val loss to random to infinity to save best maskhead model
best_val_loss = float("inf")


for epoch in range(EPOCHS):

    # TRAINING PHASE

    #Sets the model to training mode (is only the head becuase we froze the encoder)
    model.train()           
    train_loss = 0.0

    #Iterates over batches from train_loader
    for imgs, masks in train_loader:
        #moves images and masks to the correct device that is gpu should be 
        imgs = imgs.to(DEVICE)      # [B,3,224,224] 
        masks = masks.to(DEVICE)    # [B,1,224,224]

        # Clear old gradients becuase pytorch adds graients by default 
        optimizer.zero_grad()

        # pun a forward pass to predict object mask logits 
        logits = model(imgs)        # [B,1,224,224]

        # computes loss function 
        loss = criterion(logits, masks)

        # backpropogates 
        loss.backward()

        # updates ONLY THE MASK HEAD WEIGHTS BECUASE YOU FROZE THE ENCODER 
        optimizer.step()

        # Averages training loss across all batches to get average loss per batch
        train_loss += loss.item()

    train_loss /= len(train_loader)

    # VALIDATION PHASE that has no learning 
    #Sets the model to evaluation mode 
    model.eval()
    val_loss = 0.0

    #Disables gradient upadting becuase you are not updating any graident 
    with torch.no_grad():
        #Runs the model on validation load to look at all valudation data 
        for imgs, masks in val_loader:
            imgs = imgs.to(DEVICE)
            masks = masks.to(DEVICE)

            logits = model(imgs)
            loss = criterion(logits, masks)

            #Computes and averages validation loss
            val_loss += loss.item()

    val_loss /= len(val_loader)

    #if the valudation loss is better than the best vlaidation loss then save the model head 
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.head.state_dict(), RUN_DIR / "mask_head_best.pt")


    # PRINT PROGRESS
    print(
        f"Epoch [{epoch+1}/{EPOCHS}] | "
        f"Train Loss: {train_loss:.4f} | "
        f"Val Loss: {val_loss:.4f}"
    )
# Out:
# Epoch [1/500] | Train Loss: 0.1433 | Val Loss: 0.1493
# Epoch [2/500] | Train Loss: 0.1150 | Val Loss: 0.1173
# Epoch [3/500] | Train Loss: 0.0878 | Val Loss: 0.0724
# Epoch [4/500] | Train Loss: 0.0516 | Val Loss: 0.0516
# Epoch [5/500] | Train Loss: 0.0457 | Val Loss: 0.0455
# Epoch [6/500] | Train Loss: 0.0429 | Val Loss: 0.0431
# Epoch [7/500] | Train Loss: 0.0411 | Val Loss: 0.0419
# Epoch [8/500] | Train Loss: 0.0404 | Val Loss: 0.0408
# Epoch [9/500] | Train Loss: 0.0395 | Val Loss: 0.0398
# Epoch [10/500] | Train Loss: 0.0385 | Val Loss: 0.0389
# Epoch [11/500] | Train Loss: 0.0377 | Val Loss: 0.0380
# Epoch [12/500] | Train Loss: 0.0370 | Val Loss: 0.0373
# Epoch [13/500] | Train Loss: 0.0363 | Val Loss: 0.0366
# Epoch [14/500] | Train Loss: 0.0358 | Val Loss: 0.0358
# Epoch [15/500] | Train Loss: 0.0351 | Val Loss: 0.0352
# Epoch [16/500] | Train Loss: 0.0345 | Val Loss: 0.0345
# Epoch [17/500] | Train Loss: 0.0339 | Val Loss: 0.0340
# Epoch [18/500] | Train Loss: 0.0334 | Val Loss: 0.0334
# Epoch [19/500] | Train Loss: 0.0330 | Val Loss: 0.0329
# Epoch [20/500] | Train Loss: 0.0326 | Val Loss: 0.0324
# Epoch [21/500] | Train Loss: 0.0321 | Val Loss: 0.0320
# Epoch [22/500] | Train Loss: 0.0318 | Val Loss: 0.0316
# Epoch [23/500] | Train Loss: 0.0314 | Val Loss: 0.0313
# Epoch [24/500] | Train Loss: 0.0310 | Val Loss: 0.0309
# Epoch [25/500] | Train Loss: 0.0306 | Val Loss: 0.0305
# Epoch [26/500] | Train Loss: 0.0303 | Val Loss: 0.0302
# Epoch [27/500] | Train Loss: 0.0300 | Val Loss: 0.0299
# Epoch [28/500] | Train Loss: 0.0299 | Val Loss: 0.0296
# Epoch [29/500] | Train Loss: 0.0295 | Val Loss: 0.0293
# Epoch [30/500] | Train Loss: 0.0293 | Val Loss: 0.0291
# Epoch [31/500] | Train Loss: 0.0290 | Val Loss: 0.0288
# Epoch [32/500] | Train Loss: 0.0288 | Val Loss: 0.0286
# Epoch [33/500] | Train Loss: 0.0285 | Val Loss: 0.0285
# Epoch [34/500] | Train Loss: 0.0284 | Val Loss: 0.0282
# Epoch [35/500] | Train Loss: 0.0281 | Val Loss: 0.0280
# Epoch [36/500] | Train Loss: 0.0279 | Val Loss: 0.0278
# Epoch [37/500] | Train Loss: 0.0278 | Val Loss: 0.0276
# Epoch [38/500] | Train Loss: 0.0276 | Val Loss: 0.0274
# Epoch [39/500] | Train Loss: 0.0275 | Val Loss: 0.0273
# Epoch [40/500] | Train Loss: 0.0274 | Val Loss: 0.0271
# Epoch [41/500] | Train Loss: 0.0271 | Val Loss: 0.0270
# Epoch [42/500] | Train Loss: 0.0269 | Val Loss: 0.0269
# Epoch [43/500] | Train Loss: 0.0267 | Val Loss: 0.0267
# Epoch [44/500] | Train Loss: 0.0266 | Val Loss: 0.0266
# Epoch [45/500] | Train Loss: 0.0266 | Val Loss: 0.0265
# Epoch [46/500] | Train Loss: 0.0265 | Val Loss: 0.0263
# Epoch [47/500] | Train Loss: 0.0263 | Val Loss: 0.0262
# Epoch [48/500] | Train Loss: 0.0262 | Val Loss: 0.0261
# Epoch [49/500] | Train Loss: 0.0261 | Val Loss: 0.0260
# Epoch [50/500] | Train Loss: 0.0258 | Val Loss: 0.0259
# Epoch [51/500] | Train Loss: 0.0257 | Val Loss: 0.0258
# Epoch [52/500] | Train Loss: 0.0257 | Val Loss: 0.0257
# Epoch [53/500] | Train Loss: 0.0256 | Val Loss: 0.0256
# Epoch [54/500] | Train Loss: 0.0254 | Val Loss: 0.0255
# Epoch [55/500] | Train Loss: 0.0254 | Val Loss: 0.0254
# Epoch [56/500] | Train Loss: 0.0253 | Val Loss: 0.0253
# Epoch [57/500] | Train Loss: 0.0253 | Val Loss: 0.0252
# Epoch [58/500] | Train Loss: 0.0251 | Val Loss: 0.0252
# Epoch [59/500] | Train Loss: 0.0250 | Val Loss: 0.0251
# Epoch [60/500] | Train Loss: 0.0249 | Val Loss: 0.0250
# Epoch [61/500] | Train Loss: 0.0248 | Val Loss: 0.0249
# Epoch [62/500] | Train Loss: 0.0248 | Val Loss: 0.0249
# Epoch [63/500] | Train Loss: 0.0248 | Val Loss: 0.0248
# Epoch [64/500] | Train Loss: 0.0246 | Val Loss: 0.0247
# Epoch [65/500] | Train Loss: 0.0246 | Val Loss: 0.0246
# Epoch [66/500] | Train Loss: 0.0245 | Val Loss: 0.0246
# Epoch [67/500] | Train Loss: 0.0245 | Val Loss: 0.0245
# Epoch [68/500] | Train Loss: 0.0244 | Val Loss: 0.0244
# Epoch [69/500] | Train Loss: 0.0242 | Val Loss: 0.0244
# Epoch [70/500] | Train Loss: 0.0242 | Val Loss: 0.0243
# Epoch [71/500] | Train Loss: 0.0241 | Val Loss: 0.0243
# Epoch [72/500] | Train Loss: 0.0240 | Val Loss: 0.0242
# Epoch [73/500] | Train Loss: 0.0241 | Val Loss: 0.0242
# Epoch [74/500] | Train Loss: 0.0238 | Val Loss: 0.0241
# Epoch [75/500] | Train Loss: 0.0239 | Val Loss: 0.0241
# Epoch [76/500] | Train Loss: 0.0238 | Val Loss: 0.0240
# Epoch [77/500] | Train Loss: 0.0237 | Val Loss: 0.0240
# Epoch [78/500] | Train Loss: 0.0237 | Val Loss: 0.0239
# Epoch [79/500] | Train Loss: 0.0236 | Val Loss: 0.0239
# Epoch [80/500] | Train Loss: 0.0236 | Val Loss: 0.0238
# Epoch [81/500] | Train Loss: 0.0235 | Val Loss: 0.0238
# Epoch [82/500] | Train Loss: 0.0235 | Val Loss: 0.0237
# Epoch [83/500] | Train Loss: 0.0234 | Val Loss: 0.0237
# Epoch [84/500] | Train Loss: 0.0233 | Val Loss: 0.0236
# Epoch [85/500] | Train Loss: 0.0234 | Val Loss: 0.0236
# Epoch [86/500] | Train Loss: 0.0233 | Val Loss: 0.0235
# Epoch [87/500] | Train Loss: 0.0233 | Val Loss: 0.0235
# Epoch [88/500] | Train Loss: 0.0233 | Val Loss: 0.0235
# Epoch [89/500] | Train Loss: 0.0231 | Val Loss: 0.0234
# Epoch [90/500] | Train Loss: 0.0231 | Val Loss: 0.0234
# Epoch [91/500] | Train Loss: 0.0231 | Val Loss: 0.0233
# Epoch [92/500] | Train Loss: 0.0230 | Val Loss: 0.0233
# Epoch [93/500] | Train Loss: 0.0231 | Val Loss: 0.0233
# Epoch [94/500] | Train Loss: 0.0230 | Val Loss: 0.0232
# Epoch [95/500] | Train Loss: 0.0229 | Val Loss: 0.0232
# Epoch [96/500] | Train Loss: 0.0229 | Val Loss: 0.0232
# Epoch [97/500] | Train Loss: 0.0228 | Val Loss: 0.0231
# Epoch [98/500] | Train Loss: 0.0227 | Val Loss: 0.0231
# Epoch [99/500] | Train Loss: 0.0229 | Val Loss: 0.0231
# Epoch [100/500] | Train Loss: 0.0228 | Val Loss: 0.0231
# Epoch [101/500] | Train Loss: 0.0226 | Val Loss: 0.0230
# Epoch [102/500] | Train Loss: 0.0226 | Val Loss: 0.0230
# Epoch [103/500] | Train Loss: 0.0226 | Val Loss: 0.0229
# Epoch [104/500] | Train Loss: 0.0227 | Val Loss: 0.0229
# Epoch [105/500] | Train Loss: 0.0226 | Val Loss: 0.0229
# Epoch [106/500] | Train Loss: 0.0224 | Val Loss: 0.0228
# Epoch [107/500] | Train Loss: 0.0225 | Val Loss: 0.0228
# Epoch [108/500] | Train Loss: 0.0225 | Val Loss: 0.0228
# Epoch [109/500] | Train Loss: 0.0224 | Val Loss: 0.0228
# Epoch [110/500] | Train Loss: 0.0224 | Val Loss: 0.0227
# Epoch [111/500] | Train Loss: 0.0224 | Val Loss: 0.0227
# Epoch [112/500] | Train Loss: 0.0223 | Val Loss: 0.0227
# Epoch [113/500] | Train Loss: 0.0222 | Val Loss: 0.0227
# Epoch [114/500] | Train Loss: 0.0222 | Val Loss: 0.0226
# Epoch [115/500] | Train Loss: 0.0223 | Val Loss: 0.0226
# Epoch [116/500] | Train Loss: 0.0223 | Val Loss: 0.0226
# Epoch [117/500] | Train Loss: 0.0221 | Val Loss: 0.0226
# Epoch [118/500] | Train Loss: 0.0221 | Val Loss: 0.0225
# Epoch [119/500] | Train Loss: 0.0221 | Val Loss: 0.0225
# Epoch [120/500] | Train Loss: 0.0220 | Val Loss: 0.0225
# Epoch [121/500] | Train Loss: 0.0221 | Val Loss: 0.0225
# Epoch [122/500] | Train Loss: 0.0220 | Val Loss: 0.0224
# Epoch [123/500] | Train Loss: 0.0219 | Val Loss: 0.0224
# Epoch [124/500] | Train Loss: 0.0219 | Val Loss: 0.0224
# Epoch [125/500] | Train Loss: 0.0219 | Val Loss: 0.0224
# Epoch [126/500] | Train Loss: 0.0218 | Val Loss: 0.0223
# Epoch [127/500] | Train Loss: 0.0219 | Val Loss: 0.0223
# Epoch [128/500] | Train Loss: 0.0218 | Val Loss: 0.0223
# Epoch [129/500] | Train Loss: 0.0218 | Val Loss: 0.0223
# Epoch [130/500] | Train Loss: 0.0218 | Val Loss: 0.0223
# Epoch [131/500] | Train Loss: 0.0217 | Val Loss: 0.0222
# Epoch [132/500] | Train Loss: 0.0218 | Val Loss: 0.0222
# Epoch [133/500] | Train Loss: 0.0217 | Val Loss: 0.0222
# Epoch [134/500] | Train Loss: 0.0217 | Val Loss: 0.0222
# Epoch [135/500] | Train Loss: 0.0216 | Val Loss: 0.0222
# Epoch [136/500] | Train Loss: 0.0218 | Val Loss: 0.0221
# Epoch [137/500] | Train Loss: 0.0216 | Val Loss: 0.0221
# Epoch [138/500] | Train Loss: 0.0216 | Val Loss: 0.0221
# Epoch [139/500] | Train Loss: 0.0215 | Val Loss: 0.0221
# Epoch [140/500] | Train Loss: 0.0215 | Val Loss: 0.0221
# Epoch [141/500] | Train Loss: 0.0216 | Val Loss: 0.0220
# Epoch [142/500] | Train Loss: 0.0216 | Val Loss: 0.0220
# Epoch [143/500] | Train Loss: 0.0217 | Val Loss: 0.0220
# Epoch [144/500] | Train Loss: 0.0215 | Val Loss: 0.0220
# Epoch [145/500] | Train Loss: 0.0215 | Val Loss: 0.0220
# Epoch [146/500] | Train Loss: 0.0213 | Val Loss: 0.0219
# Epoch [147/500] | Train Loss: 0.0215 | Val Loss: 0.0219
# Epoch [148/500] | Train Loss: 0.0216 | Val Loss: 0.0219
# Epoch [149/500] | Train Loss: 0.0214 | Val Loss: 0.0219
# Epoch [150/500] | Train Loss: 0.0214 | Val Loss: 0.0219
# Epoch [151/500] | Train Loss: 0.0213 | Val Loss: 0.0219
# Epoch [152/500] | Train Loss: 0.0213 | Val Loss: 0.0218
# Epoch [153/500] | Train Loss: 0.0214 | Val Loss: 0.0218
# Epoch [154/500] | Train Loss: 0.0212 | Val Loss: 0.0218
# Epoch [155/500] | Train Loss: 0.0213 | Val Loss: 0.0218
# Epoch [156/500] | Train Loss: 0.0212 | Val Loss: 0.0218
# Epoch [157/500] | Train Loss: 0.0212 | Val Loss: 0.0218
# Epoch [158/500] | Train Loss: 0.0213 | Val Loss: 0.0218
# Epoch [159/500] | Train Loss: 0.0213 | Val Loss: 0.0218
# Epoch [160/500] | Train Loss: 0.0212 | Val Loss: 0.0217
# Epoch [161/500] | Train Loss: 0.0212 | Val Loss: 0.0217
# Epoch [162/500] | Train Loss: 0.0212 | Val Loss: 0.0217
# Epoch [163/500] | Train Loss: 0.0212 | Val Loss: 0.0217
# Epoch [164/500] | Train Loss: 0.0211 | Val Loss: 0.0217
# Epoch [165/500] | Train Loss: 0.0210 | Val Loss: 0.0217
# Epoch [166/500] | Train Loss: 0.0210 | Val Loss: 0.0216
# Epoch [167/500] | Train Loss: 0.0211 | Val Loss: 0.0216
# Epoch [168/500] | Train Loss: 0.0211 | Val Loss: 0.0216
# Epoch [169/500] | Train Loss: 0.0209 | Val Loss: 0.0216
# Epoch [170/500] | Train Loss: 0.0210 | Val Loss: 0.0216
# Epoch [171/500] | Train Loss: 0.0209 | Val Loss: 0.0216
# Epoch [172/500] | Train Loss: 0.0210 | Val Loss: 0.0216
# Epoch [173/500] | Train Loss: 0.0210 | Val Loss: 0.0216
# Epoch [174/500] | Train Loss: 0.0209 | Val Loss: 0.0215
# Epoch [175/500] | Train Loss: 0.0209 | Val Loss: 0.0215
# Epoch [176/500] | Train Loss: 0.0210 | Val Loss: 0.0215
# Epoch [177/500] | Train Loss: 0.0209 | Val Loss: 0.0215
# Epoch [178/500] | Train Loss: 0.0209 | Val Loss: 0.0215
# Epoch [179/500] | Train Loss: 0.0208 | Val Loss: 0.0215
# Epoch [180/500] | Train Loss: 0.0209 | Val Loss: 0.0215
# Epoch [181/500] | Train Loss: 0.0209 | Val Loss: 0.0214
# Epoch [182/500] | Train Loss: 0.0208 | Val Loss: 0.0214
# Epoch [183/500] | Train Loss: 0.0208 | Val Loss: 0.0214
# Epoch [184/500] | Train Loss: 0.0208 | Val Loss: 0.0214
# Epoch [185/500] | Train Loss: 0.0209 | Val Loss: 0.0214
# Epoch [186/500] | Train Loss: 0.0208 | Val Loss: 0.0214
# Epoch [187/500] | Train Loss: 0.0207 | Val Loss: 0.0214
# Epoch [188/500] | Train Loss: 0.0208 | Val Loss: 0.0214
# Epoch [189/500] | Train Loss: 0.0208 | Val Loss: 0.0213
# Epoch [190/500] | Train Loss: 0.0208 | Val Loss: 0.0213
# Epoch [191/500] | Train Loss: 0.0207 | Val Loss: 0.0213
# Epoch [192/500] | Train Loss: 0.0207 | Val Loss: 0.0213
# Epoch [193/500] | Train Loss: 0.0206 | Val Loss: 0.0213
# Epoch [194/500] | Train Loss: 0.0207 | Val Loss: 0.0213
# Epoch [195/500] | Train Loss: 0.0207 | Val Loss: 0.0213
# Epoch [196/500] | Train Loss: 0.0206 | Val Loss: 0.0213
# Epoch [197/500] | Train Loss: 0.0207 | Val Loss: 0.0213
# Epoch [198/500] | Train Loss: 0.0206 | Val Loss: 0.0212
# Epoch [199/500] | Train Loss: 0.0206 | Val Loss: 0.0213
# Epoch [200/500] | Train Loss: 0.0206 | Val Loss: 0.0212
# Epoch [201/500] | Train Loss: 0.0206 | Val Loss: 0.0212
# Epoch [202/500] | Train Loss: 0.0207 | Val Loss: 0.0212
# Epoch [203/500] | Train Loss: 0.0205 | Val Loss: 0.0212
# Epoch [204/500] | Train Loss: 0.0206 | Val Loss: 0.0212
# Epoch [205/500] | Train Loss: 0.0206 | Val Loss: 0.0212
# Epoch [206/500] | Train Loss: 0.0205 | Val Loss: 0.0212
# Epoch [207/500] | Train Loss: 0.0205 | Val Loss: 0.0212
# Epoch [208/500] | Train Loss: 0.0205 | Val Loss: 0.0211
# Epoch [209/500] | Train Loss: 0.0205 | Val Loss: 0.0211
# Epoch [210/500] | Train Loss: 0.0205 | Val Loss: 0.0211
# Epoch [211/500] | Train Loss: 0.0205 | Val Loss: 0.0211
# Epoch [212/500] | Train Loss: 0.0205 | Val Loss: 0.0211
# Epoch [213/500] | Train Loss: 0.0204 | Val Loss: 0.0211
# Epoch [214/500] | Train Loss: 0.0204 | Val Loss: 0.0211
# Epoch [215/500] | Train Loss: 0.0205 | Val Loss: 0.0211
# Epoch [216/500] | Train Loss: 0.0204 | Val Loss: 0.0211
# Epoch [217/500] | Train Loss: 0.0204 | Val Loss: 0.0211
# Epoch [218/500] | Train Loss: 0.0204 | Val Loss: 0.0210
# Epoch [219/500] | Train Loss: 0.0205 | Val Loss: 0.0210
# Epoch [220/500] | Train Loss: 0.0203 | Val Loss: 0.0210
# Epoch [221/500] | Train Loss: 0.0203 | Val Loss: 0.0210
# Epoch [222/500] | Train Loss: 0.0205 | Val Loss: 0.0210
# Epoch [223/500] | Train Loss: 0.0203 | Val Loss: 0.0210
# Epoch [224/500] | Train Loss: 0.0204 | Val Loss: 0.0210
# Epoch [225/500] | Train Loss: 0.0203 | Val Loss: 0.0210
# Epoch [226/500] | Train Loss: 0.0204 | Val Loss: 0.0210
# Epoch [227/500] | Train Loss: 0.0204 | Val Loss: 0.0210
# Epoch [228/500] | Train Loss: 0.0203 | Val Loss: 0.0210
# Epoch [229/500] | Train Loss: 0.0203 | Val Loss: 0.0209
# Epoch [230/500] | Train Loss: 0.0203 | Val Loss: 0.0209
# Epoch [231/500] | Train Loss: 0.0203 | Val Loss: 0.0209
# Epoch [232/500] | Train Loss: 0.0202 | Val Loss: 0.0209
# Epoch [233/500] | Train Loss: 0.0203 | Val Loss: 0.0209
# Epoch [234/500] | Train Loss: 0.0203 | Val Loss: 0.0209
# Epoch [235/500] | Train Loss: 0.0202 | Val Loss: 0.0209
# Epoch [236/500] | Train Loss: 0.0202 | Val Loss: 0.0209
# Epoch [237/500] | Train Loss: 0.0202 | Val Loss: 0.0209
# Epoch [238/500] | Train Loss: 0.0202 | Val Loss: 0.0209
# Epoch [239/500] | Train Loss: 0.0202 | Val Loss: 0.0209
# Epoch [240/500] | Train Loss: 0.0201 | Val Loss: 0.0208
# Epoch [241/500] | Train Loss: 0.0201 | Val Loss: 0.0208
# Epoch [242/500] | Train Loss: 0.0202 | Val Loss: 0.0208
# Epoch [243/500] | Train Loss: 0.0202 | Val Loss: 0.0208
# Epoch [244/500] | Train Loss: 0.0202 | Val Loss: 0.0208
# Epoch [245/500] | Train Loss: 0.0201 | Val Loss: 0.0208
# Epoch [246/500] | Train Loss: 0.0201 | Val Loss: 0.0208
# Epoch [247/500] | Train Loss: 0.0201 | Val Loss: 0.0208
# Epoch [248/500] | Train Loss: 0.0201 | Val Loss: 0.0208
# Epoch [249/500] | Train Loss: 0.0201 | Val Loss: 0.0208
# Epoch [250/500] | Train Loss: 0.0201 | Val Loss: 0.0208
# Epoch [251/500] | Train Loss: 0.0200 | Val Loss: 0.0208
# Epoch [252/500] | Train Loss: 0.0201 | Val Loss: 0.0208
# Epoch [253/500] | Train Loss: 0.0201 | Val Loss: 0.0208
# Epoch [254/500] | Train Loss: 0.0200 | Val Loss: 0.0207
# Epoch [255/500] | Train Loss: 0.0201 | Val Loss: 0.0207
# Epoch [256/500] | Train Loss: 0.0200 | Val Loss: 0.0207
# Epoch [257/500] | Train Loss: 0.0200 | Val Loss: 0.0207
# Epoch [258/500] | Train Loss: 0.0201 | Val Loss: 0.0207
# Epoch [259/500] | Train Loss: 0.0200 | Val Loss: 0.0207
# Epoch [260/500] | Train Loss: 0.0200 | Val Loss: 0.0207
# Epoch [261/500] | Train Loss: 0.0199 | Val Loss: 0.0207
# Epoch [262/500] | Train Loss: 0.0199 | Val Loss: 0.0207
# Epoch [263/500] | Train Loss: 0.0200 | Val Loss: 0.0207
# Epoch [264/500] | Train Loss: 0.0199 | Val Loss: 0.0207
# Epoch [265/500] | Train Loss: 0.0201 | Val Loss: 0.0207
# Epoch [266/500] | Train Loss: 0.0200 | Val Loss: 0.0206
# Epoch [267/500] | Train Loss: 0.0200 | Val Loss: 0.0207
# Epoch [268/500] | Train Loss: 0.0200 | Val Loss: 0.0206
# Epoch [269/500] | Train Loss: 0.0198 | Val Loss: 0.0206
# Epoch [270/500] | Train Loss: 0.0199 | Val Loss: 0.0206
# Epoch [271/500] | Train Loss: 0.0199 | Val Loss: 0.0206
# Epoch [272/500] | Train Loss: 0.0199 | Val Loss: 0.0206
# Epoch [273/500] | Train Loss: 0.0198 | Val Loss: 0.0206
# Epoch [274/500] | Train Loss: 0.0199 | Val Loss: 0.0206
# Epoch [275/500] | Train Loss: 0.0199 | Val Loss: 0.0206
# Epoch [276/500] | Train Loss: 0.0199 | Val Loss: 0.0206
# Epoch [277/500] | Train Loss: 0.0198 | Val Loss: 0.0206
# Epoch [278/500] | Train Loss: 0.0198 | Val Loss: 0.0206
# Epoch [279/500] | Train Loss: 0.0198 | Val Loss: 0.0206
# Epoch [280/500] | Train Loss: 0.0198 | Val Loss: 0.0206
# Epoch [281/500] | Train Loss: 0.0198 | Val Loss: 0.0206
# Epoch [282/500] | Train Loss: 0.0198 | Val Loss: 0.0206
# Epoch [283/500] | Train Loss: 0.0198 | Val Loss: 0.0206
# Epoch [284/500] | Train Loss: 0.0199 | Val Loss: 0.0206
# Epoch [285/500] | Train Loss: 0.0198 | Val Loss: 0.0205
# Epoch [286/500] | Train Loss: 0.0198 | Val Loss: 0.0205
# Epoch [287/500] | Train Loss: 0.0198 | Val Loss: 0.0205
# Epoch [288/500] | Train Loss: 0.0197 | Val Loss: 0.0205
# Epoch [289/500] | Train Loss: 0.0198 | Val Loss: 0.0205
# Epoch [290/500] | Train Loss: 0.0197 | Val Loss: 0.0205
# Epoch [291/500] | Train Loss: 0.0197 | Val Loss: 0.0205
# Epoch [292/500] | Train Loss: 0.0198 | Val Loss: 0.0205
# Epoch [293/500] | Train Loss: 0.0198 | Val Loss: 0.0205
# Epoch [294/500] | Train Loss: 0.0198 | Val Loss: 0.0205
# Epoch [295/500] | Train Loss: 0.0198 | Val Loss: 0.0205
# Epoch [296/500] | Train Loss: 0.0198 | Val Loss: 0.0205
# Epoch [297/500] | Train Loss: 0.0197 | Val Loss: 0.0205
# Epoch [298/500] | Train Loss: 0.0197 | Val Loss: 0.0205
# Epoch [299/500] | Train Loss: 0.0197 | Val Loss: 0.0204
# Epoch [300/500] | Train Loss: 0.0197 | Val Loss: 0.0204
# Epoch [301/500] | Train Loss: 0.0197 | Val Loss: 0.0204
# Epoch [302/500] | Train Loss: 0.0197 | Val Loss: 0.0204
# Epoch [303/500] | Train Loss: 0.0197 | Val Loss: 0.0204
# Epoch [304/500] | Train Loss: 0.0196 | Val Loss: 0.0204
# Epoch [305/500] | Train Loss: 0.0196 | Val Loss: 0.0204
# Epoch [306/500] | Train Loss: 0.0198 | Val Loss: 0.0204
# Epoch [307/500] | Train Loss: 0.0197 | Val Loss: 0.0204
# Epoch [308/500] | Train Loss: 0.0196 | Val Loss: 0.0204
# Epoch [309/500] | Train Loss: 0.0197 | Val Loss: 0.0204
# Epoch [310/500] | Train Loss: 0.0197 | Val Loss: 0.0204
# Epoch [311/500] | Train Loss: 0.0197 | Val Loss: 0.0204
# Epoch [312/500] | Train Loss: 0.0196 | Val Loss: 0.0204
# Epoch [313/500] | Train Loss: 0.0197 | Val Loss: 0.0204
# Epoch [314/500] | Train Loss: 0.0197 | Val Loss: 0.0204
# Epoch [315/500] | Train Loss: 0.0197 | Val Loss: 0.0204
# Epoch [316/500] | Train Loss: 0.0196 | Val Loss: 0.0204
# Epoch [317/500] | Train Loss: 0.0197 | Val Loss: 0.0204
# Epoch [318/500] | Train Loss: 0.0196 | Val Loss: 0.0204
# Epoch [319/500] | Train Loss: 0.0195 | Val Loss: 0.0203
# Epoch [320/500] | Train Loss: 0.0196 | Val Loss: 0.0203
# Epoch [321/500] | Train Loss: 0.0196 | Val Loss: 0.0203
# Epoch [322/500] | Train Loss: 0.0195 | Val Loss: 0.0203
# Epoch [323/500] | Train Loss: 0.0196 | Val Loss: 0.0203
# Epoch [324/500] | Train Loss: 0.0196 | Val Loss: 0.0203
# Epoch [325/500] | Train Loss: 0.0195 | Val Loss: 0.0203
# Epoch [326/500] | Train Loss: 0.0195 | Val Loss: 0.0203
# Epoch [327/500] | Train Loss: 0.0195 | Val Loss: 0.0203
# Epoch [328/500] | Train Loss: 0.0195 | Val Loss: 0.0203
# Epoch [329/500] | Train Loss: 0.0195 | Val Loss: 0.0203
# Epoch [330/500] | Train Loss: 0.0196 | Val Loss: 0.0203
# Epoch [331/500] | Train Loss: 0.0196 | Val Loss: 0.0203
# Epoch [332/500] | Train Loss: 0.0195 | Val Loss: 0.0203
# Epoch [333/500] | Train Loss: 0.0195 | Val Loss: 0.0203
# Epoch [334/500] | Train Loss: 0.0195 | Val Loss: 0.0203
# Epoch [335/500] | Train Loss: 0.0195 | Val Loss: 0.0203
# Epoch [336/500] | Train Loss: 0.0195 | Val Loss: 0.0202
# Epoch [337/500] | Train Loss: 0.0196 | Val Loss: 0.0203
# Epoch [338/500] | Train Loss: 0.0195 | Val Loss: 0.0202
# Epoch [339/500] | Train Loss: 0.0195 | Val Loss: 0.0203
# Epoch [340/500] | Train Loss: 0.0195 | Val Loss: 0.0202
# Epoch [341/500] | Train Loss: 0.0196 | Val Loss: 0.0202
# Epoch [342/500] | Train Loss: 0.0195 | Val Loss: 0.0202
# Epoch [343/500] | Train Loss: 0.0194 | Val Loss: 0.0202
# Epoch [344/500] | Train Loss: 0.0195 | Val Loss: 0.0202
# Epoch [345/500] | Train Loss: 0.0194 | Val Loss: 0.0202
# Epoch [346/500] | Train Loss: 0.0195 | Val Loss: 0.0202
# Epoch [347/500] | Train Loss: 0.0194 | Val Loss: 0.0202
# Epoch [348/500] | Train Loss: 0.0194 | Val Loss: 0.0202
# Epoch [349/500] | Train Loss: 0.0194 | Val Loss: 0.0202
# Epoch [350/500] | Train Loss: 0.0194 | Val Loss: 0.0202
# Epoch [351/500] | Train Loss: 0.0193 | Val Loss: 0.0202
# Epoch [352/500] | Train Loss: 0.0194 | Val Loss: 0.0202
# Epoch [353/500] | Train Loss: 0.0194 | Val Loss: 0.0202
# Epoch [354/500] | Train Loss: 0.0194 | Val Loss: 0.0202
# Epoch [355/500] | Train Loss: 0.0195 | Val Loss: 0.0202
# Epoch [356/500] | Train Loss: 0.0193 | Val Loss: 0.0202
# Epoch [357/500] | Train Loss: 0.0193 | Val Loss: 0.0202
# Epoch [358/500] | Train Loss: 0.0195 | Val Loss: 0.0202
# Epoch [359/500] | Train Loss: 0.0194 | Val Loss: 0.0201
# Epoch [360/500] | Train Loss: 0.0194 | Val Loss: 0.0202
# Epoch [361/500] | Train Loss: 0.0193 | Val Loss: 0.0201
# Epoch [362/500] | Train Loss: 0.0192 | Val Loss: 0.0201
# Epoch [363/500] | Train Loss: 0.0194 | Val Loss: 0.0202
# Epoch [364/500] | Train Loss: 0.0194 | Val Loss: 0.0201
# Epoch [365/500] | Train Loss: 0.0193 | Val Loss: 0.0201
# Epoch [366/500] | Train Loss: 0.0194 | Val Loss: 0.0201
# Epoch [367/500] | Train Loss: 0.0194 | Val Loss: 0.0201
# Epoch [368/500] | Train Loss: 0.0194 | Val Loss: 0.0201
# Epoch [369/500] | Train Loss: 0.0192 | Val Loss: 0.0201
# Epoch [370/500] | Train Loss: 0.0193 | Val Loss: 0.0201
# Epoch [371/500] | Train Loss: 0.0193 | Val Loss: 0.0201
# Epoch [372/500] | Train Loss: 0.0193 | Val Loss: 0.0201
# Epoch [373/500] | Train Loss: 0.0193 | Val Loss: 0.0201
# Epoch [374/500] | Train Loss: 0.0193 | Val Loss: 0.0201
# Epoch [375/500] | Train Loss: 0.0193 | Val Loss: 0.0201
# Epoch [376/500] | Train Loss: 0.0193 | Val Loss: 0.0201
# Epoch [377/500] | Train Loss: 0.0193 | Val Loss: 0.0201
# Epoch [378/500] | Train Loss: 0.0193 | Val Loss: 0.0201
# Epoch [379/500] | Train Loss: 0.0193 | Val Loss: 0.0201
# Epoch [380/500] | Train Loss: 0.0193 | Val Loss: 0.0201
# Epoch [381/500] | Train Loss: 0.0194 | Val Loss: 0.0201
# Epoch [382/500] | Train Loss: 0.0192 | Val Loss: 0.0200
# Epoch [383/500] | Train Loss: 0.0193 | Val Loss: 0.0200
# Epoch [384/500] | Train Loss: 0.0192 | Val Loss: 0.0200
# Epoch [385/500] | Train Loss: 0.0192 | Val Loss: 0.0200
# Epoch [386/500] | Train Loss: 0.0192 | Val Loss: 0.0200
# Epoch [387/500] | Train Loss: 0.0193 | Val Loss: 0.0200
# Epoch [388/500] | Train Loss: 0.0193 | Val Loss: 0.0200
# Epoch [389/500] | Train Loss: 0.0192 | Val Loss: 0.0200
# Epoch [390/500] | Train Loss: 0.0192 | Val Loss: 0.0200
# Epoch [391/500] | Train Loss: 0.0193 | Val Loss: 0.0200
# Epoch [392/500] | Train Loss: 0.0192 | Val Loss: 0.0200
# Epoch [393/500] | Train Loss: 0.0192 | Val Loss: 0.0200
# Epoch [394/500] | Train Loss: 0.0191 | Val Loss: 0.0200
# Epoch [395/500] | Train Loss: 0.0193 | Val Loss: 0.0200
# Epoch [396/500] | Train Loss: 0.0192 | Val Loss: 0.0200
# Epoch [397/500] | Train Loss: 0.0192 | Val Loss: 0.0200
# Epoch [398/500] | Train Loss: 0.0191 | Val Loss: 0.0200
# Epoch [399/500] | Train Loss: 0.0192 | Val Loss: 0.0200
# Epoch [400/500] | Train Loss: 0.0192 | Val Loss: 0.0200
# Epoch [401/500] | Train Loss: 0.0191 | Val Loss: 0.0200
# Epoch [402/500] | Train Loss: 0.0192 | Val Loss: 0.0200
# Epoch [403/500] | Train Loss: 0.0192 | Val Loss: 0.0200
# Epoch [404/500] | Train Loss: 0.0191 | Val Loss: 0.0200
# Epoch [405/500] | Train Loss: 0.0192 | Val Loss: 0.0200
# Epoch [406/500] | Train Loss: 0.0191 | Val Loss: 0.0200
# Epoch [407/500] | Train Loss: 0.0192 | Val Loss: 0.0200
# Epoch [408/500] | Train Loss: 0.0192 | Val Loss: 0.0199
# Epoch [409/500] | Train Loss: 0.0191 | Val Loss: 0.0200
# Epoch [410/500] | Train Loss: 0.0191 | Val Loss: 0.0200
# Epoch [411/500] | Train Loss: 0.0190 | Val Loss: 0.0199
# Epoch [412/500] | Train Loss: 0.0191 | Val Loss: 0.0199
# Epoch [413/500] | Train Loss: 0.0191 | Val Loss: 0.0199
# Epoch [414/500] | Train Loss: 0.0191 | Val Loss: 0.0199
# Epoch [415/500] | Train Loss: 0.0192 | Val Loss: 0.0199
# Epoch [416/500] | Train Loss: 0.0190 | Val Loss: 0.0199
# Epoch [417/500] | Train Loss: 0.0191 | Val Loss: 0.0199
# Epoch [418/500] | Train Loss: 0.0191 | Val Loss: 0.0199
# Epoch [419/500] | Train Loss: 0.0191 | Val Loss: 0.0199
# Epoch [420/500] | Train Loss: 0.0191 | Val Loss: 0.0199
# Epoch [421/500] | Train Loss: 0.0191 | Val Loss: 0.0199
# Epoch [422/500] | Train Loss: 0.0190 | Val Loss: 0.0199
# Epoch [423/500] | Train Loss: 0.0190 | Val Loss: 0.0199
# Epoch [424/500] | Train Loss: 0.0192 | Val Loss: 0.0199
# Epoch [425/500] | Train Loss: 0.0191 | Val Loss: 0.0199
# Epoch [426/500] | Train Loss: 0.0191 | Val Loss: 0.0199
# Epoch [427/500] | Train Loss: 0.0190 | Val Loss: 0.0199
# Epoch [428/500] | Train Loss: 0.0191 | Val Loss: 0.0199
# Epoch [429/500] | Train Loss: 0.0191 | Val Loss: 0.0199
# Epoch [430/500] | Train Loss: 0.0190 | Val Loss: 0.0199
# Epoch [431/500] | Train Loss: 0.0191 | Val Loss: 0.0199
# Epoch [432/500] | Train Loss: 0.0191 | Val Loss: 0.0199
# Epoch [433/500] | Train Loss: 0.0190 | Val Loss: 0.0199
# Epoch [434/500] | Train Loss: 0.0191 | Val Loss: 0.0199
# Epoch [435/500] | Train Loss: 0.0191 | Val Loss: 0.0198
# Epoch [436/500] | Train Loss: 0.0190 | Val Loss: 0.0199
# Epoch [437/500] | Train Loss: 0.0190 | Val Loss: 0.0198
# Epoch [438/500] | Train Loss: 0.0190 | Val Loss: 0.0199
# Epoch [439/500] | Train Loss: 0.0191 | Val Loss: 0.0198
# Epoch [440/500] | Train Loss: 0.0190 | Val Loss: 0.0198
# Epoch [441/500] | Train Loss: 0.0191 | Val Loss: 0.0198
# Epoch [442/500] | Train Loss: 0.0191 | Val Loss: 0.0198
# Epoch [443/500] | Train Loss: 0.0190 | Val Loss: 0.0198
# Epoch [444/500] | Train Loss: 0.0190 | Val Loss: 0.0198
# Epoch [445/500] | Train Loss: 0.0190 | Val Loss: 0.0198
# Epoch [446/500] | Train Loss: 0.0190 | Val Loss: 0.0198
# Epoch [447/500] | Train Loss: 0.0191 | Val Loss: 0.0198
# Epoch [448/500] | Train Loss: 0.0191 | Val Loss: 0.0198
# Epoch [449/500] | Train Loss: 0.0190 | Val Loss: 0.0198
# Epoch [450/500] | Train Loss: 0.0191 | Val Loss: 0.0198
# Epoch [451/500] | Train Loss: 0.0191 | Val Loss: 0.0198
# Epoch [452/500] | Train Loss: 0.0190 | Val Loss: 0.0198
# Epoch [453/500] | Train Loss: 0.0189 | Val Loss: 0.0198
# Epoch [454/500] | Train Loss: 0.0190 | Val Loss: 0.0198
# Epoch [455/500] | Train Loss: 0.0189 | Val Loss: 0.0198
# Epoch [456/500] | Train Loss: 0.0189 | Val Loss: 0.0198
# Epoch [457/500] | Train Loss: 0.0189 | Val Loss: 0.0198
# Epoch [458/500] | Train Loss: 0.0190 | Val Loss: 0.0198
# Epoch [459/500] | Train Loss: 0.0190 | Val Loss: 0.0198
# Epoch [460/500] | Train Loss: 0.0190 | Val Loss: 0.0198
# Epoch [461/500] | Train Loss: 0.0190 | Val Loss: 0.0198
# Epoch [462/500] | Train Loss: 0.0189 | Val Loss: 0.0198
# Epoch [463/500] | Train Loss: 0.0189 | Val Loss: 0.0198
# Epoch [464/500] | Train Loss: 0.0190 | Val Loss: 0.0198
# Epoch [465/500] | Train Loss: 0.0190 | Val Loss: 0.0198
# Epoch [466/500] | Train Loss: 0.0189 | Val Loss: 0.0198
# Epoch [467/500] | Train Loss: 0.0190 | Val Loss: 0.0198
# Epoch [468/500] | Train Loss: 0.0190 | Val Loss: 0.0198
# Epoch [469/500] | Train Loss: 0.0190 | Val Loss: 0.0198
# Epoch [470/500] | Train Loss: 0.0189 | Val Loss: 0.0197
# Epoch [471/500] | Train Loss: 0.0189 | Val Loss: 0.0197
# Epoch [472/500] | Train Loss: 0.0190 | Val Loss: 0.0197
# Epoch [473/500] | Train Loss: 0.0190 | Val Loss: 0.0197
# Epoch [474/500] | Train Loss: 0.0189 | Val Loss: 0.0197
# Epoch [475/500] | Train Loss: 0.0188 | Val Loss: 0.0197
# Epoch [476/500] | Train Loss: 0.0189 | Val Loss: 0.0197
# Epoch [477/500] | Train Loss: 0.0188 | Val Loss: 0.0197
# Epoch [478/500] | Train Loss: 0.0188 | Val Loss: 0.0197
# Epoch [479/500] | Train Loss: 0.0189 | Val Loss: 0.0197
# Epoch [480/500] | Train Loss: 0.0188 | Val Loss: 0.0197
# Epoch [481/500] | Train Loss: 0.0188 | Val Loss: 0.0197
# Epoch [482/500] | Train Loss: 0.0189 | Val Loss: 0.0197
# Epoch [483/500] | Train Loss: 0.0189 | Val Loss: 0.0197
# Epoch [484/500] | Train Loss: 0.0189 | Val Loss: 0.0197
# Epoch [485/500] | Train Loss: 0.0189 | Val Loss: 0.0197
# Epoch [486/500] | Train Loss: 0.0189 | Val Loss: 0.0197
# Epoch [487/500] | Train Loss: 0.0189 | Val Loss: 0.0197
# Epoch [488/500] | Train Loss: 0.0189 | Val Loss: 0.0197
# Epoch [489/500] | Train Loss: 0.0189 | Val Loss: 0.0197
# Epoch [490/500] | Train Loss: 0.0189 | Val Loss: 0.0197
# Epoch [491/500] | Train Loss: 0.0188 | Val Loss: 0.0197
# Epoch [492/500] | Train Loss: 0.0188 | Val Loss: 0.0197
# Epoch [493/500] | Train Loss: 0.0190 | Val Loss: 0.0197
# Epoch [494/500] | Train Loss: 0.0189 | Val Loss: 0.0197
# Epoch [495/500] | Train Loss: 0.0188 | Val Loss: 0.0197
# Epoch [496/500] | Train Loss: 0.0188 | Val Loss: 0.0197
# Epoch [497/500] | Train Loss: 0.0189 | Val Loss: 0.0197
# Epoch [498/500] | Train Loss: 0.0189 | Val Loss: 0.0197
# Epoch [499/500] | Train Loss: 0.0189 | Val Loss: 0.0197
# Epoch [500/500] | Train Loss: 0.0189 | Val Loss: 0.0197

# %%
#RUNS ONE PICTURE THROUGH CORNETZWITHMASKHEAD AND GIVES PREDICTION NPARRAY and mask for threshold(no longer using)
TEST_IMG_PATH = Path("/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/test_stimuli/test_pairs/test_gc_gs_UD.png")

# 2) Load + transform the image (use the SAME transform as training)
img_pil = Image.open(TEST_IMG_PATH).convert("RGB")
x = img_tf(img_pil).unsqueeze(0).to(DEVICE)   # [1,3,224,224]

#Put model in evaluation modemodel.eval()
# Run inference without tracking gradients
with torch.no_grad():
    # Forward pass: model outputs raw mask scores that are logits not probabilities
    logits = model(x)                          # [1,1,224,224]
    #Convert logits to probabilities in [0,1] using sigmoid becuase math for some reason --WHAT WE USE NOW NO MORE MASKS OLIVIA 
    probs  = torch.sigmoid(logits)             # [1,1,224,224] probabilities in [0,1]
    #Threshold probabilities to make a hard binary mask (0/1)
    pred   = (probs > THRESHOLD).float()       # [1,1,224,224] binary mask (0/1)

# Convert to numpy for plotting
# Convert the probability map and binary mask into 2D numpy arrays for plotting/saving but didnt work sp use pandas dataframe
prob_map = probs.squeeze().cpu().numpy()       # [224,224]
bin_mask = pred.squeeze().cpu().numpy()        # [224,224]

#undoo imagenet normalization to make it only between normal colors 
img_vis = x.squeeze(0).detach().cpu().clone()  # [3,224,224]
img_vis[0] = img_vis[0] * 0.229 + 0.485
img_vis[1] = img_vis[1] * 0.224 + 0.456
img_vis[2] = img_vis[2] * 0.225 + 0.406
img_vis = img_vis.permute(1, 2, 0).clamp(0, 1).numpy()  # [224,224,3]

# 5) Plot
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(img_vis)
plt.title("Input image")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(prob_map, cmap="gray")
plt.title("Predicted probability")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(bin_mask, cmap="gray")
plt.title(f"Binary mask (p > {THRESHOLD})")
plt.axis("off")

plt.tight_layout()
plt.show()

print(prob_map.shape)

df_pred= pd.DataFrame(prob_map)

print(df_pred)

df_pred.to_csv("output.csv", index=False)
# Out:
# (224, 224)
#           0         1         2         3         4         5         6    \
# 0    0.002136  0.002136  0.002136  0.002136  0.002136  0.002136  0.002136
# 1    0.002136  0.002136  0.002136  0.002136  0.002136  0.002136  0.002136
# 2    0.002136  0.002136  0.002136  0.002136  0.002136  0.002136  0.002136
# 3    0.002136  0.002136  0.002136  0.002136  0.002136  0.002136  0.002136
# 4    0.002136  0.002136  0.002136  0.002136  0.002136  0.002136  0.002136
# ..        ...       ...       ...       ...       ...       ...       ...
# 219  0.001201  0.001201  0.001201  0.001201  0.001201  0.001201  0.001201
# 220  0.001201  0.001201  0.001201  0.001201  0.001201  0.001201  0.001201
# 221  0.001201  0.001201  0.001201  0.001201  0.001201  0.001201  0.001201
# 222  0.001201  0.001201  0.001201  0.001201  0.001201  0.001201  0.001201
# 223  0.001201  0.001201  0.001201  0.001201  0.001201  0.001201  0.001201
#
#           7         8         9    ...       214       215       216  \
# 0    0.002136  0.002136  0.002136  ...  0.001348  0.001348  0.001348
# 1    0.002136  0.002136  0.002136  ...  0.001348  0.001348  0.001348
# 2    0.002136  0.002136  0.002136  ...  0.001348  0.001348  0.001348
# 3    0.002136  0.002136  0.002136  ...  0.001348  0.001348  0.001348
# 4    0.002136  0.002136  0.002136  ...  0.001348  0.001348  0.001348
# ..        ...       ...       ...  ...       ...       ...       ...
# 219  0.001201  0.001201  0.001201  ...  0.000040  0.000040  0.000040
# 220  0.001201  0.001201  0.001201  ...  0.000040  0.000040  0.000040
# 221  0.001201  0.001201  0.001201  ...  0.000040  0.000040  0.000040
# 222  0.001201  0.001201  0.001201  ...  0.000040  0.000040  0.000040
# 223  0.001201  0.001201  0.001201  ...  0.000040  0.000040  0.000040
#
#           217       218       219       220       221       222       223
# 0    0.001348  0.001348  0.001348  0.001348  0.001348  0.001348  0.001348
# 1    0.001348  0.001348  0.001348  0.001348  0.001348  0.001348  0.001348
# 2    0.001348  0.001348  0.001348  0.001348  0.001348  0.001348  0.001348
# 3    0.001348  0.001348  0.001348  0.001348  0.001348  0.001348  0.001348
# 4    0.001348  0.001348  0.001348  0.001348  0.001348  0.001348  0.001348
# ..        ...       ...       ...       ...       ...       ...       ...
# 219  0.000040  0.000040  0.000040  0.000040  0.000040  0.000040  0.000040
# 220  0.000040  0.000040  0.000040  0.000040  0.000040  0.000040  0.000040
# 221  0.000040  0.000040  0.000040  0.000040  0.000040  0.000040  0.000040
# 222  0.000040  0.000040  0.000040  0.000040  0.000040  0.000040  0.000040
# 223  0.000040  0.000040  0.000040  0.000040  0.000040  0.000040  0.000040
#
# [224 rows x 224 columns]

# %%
#FINDS MEAN MASK PREDICTION GIVEN A DATAFRAME FOR ONE PICTURE
# Load black/white image -> binary mask DataFrame
# Black object (0)   -> 1
# White background   -> 0
def load_mask_df(img_path: str | Path) -> pd.DataFrame:
    img_path = Path(img_path)

    # Load image as grayscale
    img = Image.open(img_path).convert("L")

    # Enforce size
    if img.size != (224, 224):
        raise ValueError(f"{img_path} has size {img.size}, expected (224, 224)")

    arr = np.array(img, dtype=np.uint8)

    # Threshold to binary: white=1, black=0
    bw = (arr > 127).astype(np.uint8)

    # INVERT so black object becomes 1
    mask = 1 - bw

    return pd.DataFrame(mask)


# Ensure x is valid
def prepare_x(x: pd.DataFrame | np.ndarray) -> np.ndarray:
    if isinstance(x, pd.DataFrame):
        x = x.to_numpy()

    if x.shape != (224, 224):
        raise ValueError(f"x has shape {x.shape}, expected (224, 224)")

    x = x.astype(np.float32)

    if x.min() < 0 or x.max() > 1:
        raise ValueError("x must contain values between 0 and 1")

    return x


# Compute masked mean
def masked_mean(x: np.ndarray, mask: np.ndarray, name: str) -> float:
    sel = mask == 1
    n = sel.sum()

    if n == 0:
        raise ValueError(f"{name} mask contains zero object pixels")

    return float(x[sel].mean())


# Main computation
def compute_target_vs_distractor_means(
    x: pd.DataFrame | np.ndarray,
    target_img: str | Path,
    distractor_img: str | Path,
) -> dict:

    x = prepare_x(x)

    target_mask = load_mask_df(target_img).to_numpy()
    distractor_mask = load_mask_df(distractor_img).to_numpy()

    return {
        "target_mean": masked_mean(x, target_mask, "target"),
        "distractor_mean": masked_mean(x, distractor_mask, "distractor"),
        "n_target_pixels": int(target_mask.sum()),
        "n_distractor_pixels": int(distractor_mask.sum()),
    }


if __name__ == "__main__":

    
    x = df_pred

    target_img = "/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/test_stimuli/test_acc_masks/test_down_c_mask.png"
    distractor_img = "/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/test_stimuli/test_acc_masks/test_up_s_mask.png"

    results = compute_target_vs_distractor_means(
        x=x,
        target_img=target_img,
        distractor_img=distractor_img,
    )

    print(results)
# Out:
# {'target_mean': 0.010481026954948902, 'distractor_mean': 0.08382780849933624, 'n_target_pixels': 489, 'n_distractor_pixels': 625}

# %%
print(RUN_DIR)
# Out:
# /zpool/vladlab/data_drive/geogaze_data/cornetS_openimages/geogaze_task/corents_identification_v5/cornetIDEN_maskL_bc_gc

# %%
###Run all test critical images in a folder through the model and save the pred_map as csvs 

TEST_IMG_DIR = Path("/zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/test_stimuli/identification/test_images")

PRED_MAP_FOLDER = TEST_IMG_DIR / MODEL_TAG

# File extensions to process
EXTS = (".png", ".jpg", ".jpeg", ".bmp", ".tif", ".tiff", ".webp")

# Assumes these already exist from your notebook:
#   model (your CORnet+maskhead model)
#   img_tf (the SAME transform as training)
#   DEVICE (e.g., "cuda" or "cpu")

# RUN BATCH INFERENCE
model.eval()

image_paths = [p for p in PRED_MAP_FOLDER.iterdir() if p.is_file() and p.suffix.lower() in EXTS]
print(f"Found {len(image_paths)} images in: {PRED_MAP_FOLDER}")

with torch.no_grad():
    for img_path in sorted(image_paths):
        # 1) Load image
        img_pil = Image.open(img_path).convert("RGB")

        # 2) Transform + add batch dim + move to device
        x = img_tf(img_pil).unsqueeze(0).to(DEVICE)  # [1,3,224,224]

        # 3) Forward pass
        logits = model(x)                 # [1,1,224,224]
        probs  = torch.sigmoid(logits)    # [1,1,224,224]

        # 4) Convert prob map to numpy (224x224)
        prob_map = probs.squeeze().detach().cpu().numpy()  # [224,224]

        # 5) Save as CSV named {image_name}_prob_map.csv
        out_name = f"{img_path.stem}_prob_map.csv"
        out_path = RUN_DIR / out_name

        df_prob = pd.DataFrame(prob_map)
        df_prob.to_csv(out_path, index=False)

        print(f"Saved: {out_path}")
# Out:
# Found 6 images in: /zpool/vladlab/data_drive/geogaze_data/decoder_stimulus/test_stimuli/identification/test_images/cornetIDEN_maskL_bc_gc
# Saved: /zpool/vladlab/data_drive/geogaze_data/cornetS_openimages/geogaze_task/corents_identification_v5/cornetIDEN_maskL_bc_gc/test_bc_bc_LR_prob_map.csv
# Saved: /zpool/vladlab/data_drive/geogaze_data/cornetS_openimages/geogaze_task/corents_identification_v5/cornetIDEN_maskL_bc_gc/test_bc_gc_LR_prob_map.csv
# Saved: /zpool/vladlab/data_drive/geogaze_data/cornetS_openimages/geogaze_task/corents_identification_v5/cornetIDEN_maskL_bc_gc/test_bc_gc_UD_prob_map.csv
# Saved: /zpool/vladlab/data_drive/geogaze_data/cornetS_openimages/geogaze_task/corents_identification_v5/cornetIDEN_maskL_bc_gc/test_gc_bc_LR_prob_map.csv
# Saved: /zpool/vladlab/data_drive/geogaze_data/cornetS_openimages/geogaze_task/corents_identification_v5/cornetIDEN_maskL_bc_gc/test_gc_bc_UD_prob_map.csv
# Saved: /zpool/vladlab/data_drive/geogaze_data/cornetS_openimages/geogaze_task/corents_identification_v5/cornetIDEN_maskL_bc_gc/test_gc_gc_LR_prob_map.csv
