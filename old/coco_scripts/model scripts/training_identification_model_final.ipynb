# %%
import json
import math
import random
from pathlib import Path
from collections import defaultdict, Counter

import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from PIL import Image
import matplotlib.pyplot as plt

# -------------------
# PATHS
# -------------------
TRAIN_JSON = Path("/zpool/vladlab/data_drive/stimulus_sets/geogaze_COCO_stim/coco_working/working_v3/instances_train_filtered3.json")
TRAIN_IMG_DIR = Path("/zpool/vladlab/data_drive/stimulus_sets/geogaze_COCO_stim/coco_working/working_v3/train_working3")  # contains 000000xxxxxx.jpg

# Optional (you said you'll use COCO val as test later; not used in training cells below)
# VAL_JSON = Path("")
# VAL_IMG_DIR = Path("")

# -------------------
# TRAINING SETTINGS
# -------------------
SEED = 123
VAL_FRACTION = 0.10       # validation sampled from TRAIN set
BATCH_SIZE = 64           # adjust to fit GPU memory
NUM_WORKERS = 4           # adjust for your system
EPOCHS = 200              # from-scratch: typically 50-100+
IMG_SIZE = 224
PRINT_EVERY = 100         # steps

# Optimizer / LR schedule (from-scratch baseline)
BASE_LR = 0.1             # good starting point for SGD with batch sizes ~64-256
MOMENTUM = 0.9
WEIGHT_DECAY = 1e-4
WARMUP_EPOCHS = 5         # linear warmup to BASE_LR
MIN_LR = 1e-5             # cosine floor

# # Optional: ignore crowd annotations when building labels
# IGNORE_ISCROWD = False

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", DEVICE)

# Reproducibility
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if DEVICE == "cuda":
    torch.cuda.manual_seed_all(SEED)
# Out:
# Device: cuda

# %%
import torchvision.transforms as T

train_tfms = T.Compose([
    T.RandomResizedCrop(IMG_SIZE, scale=(0.6, 1.0)),
    T.RandomHorizontalFlip(p=0.5),
    T.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.05),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225]),
])

eval_tfms = T.Compose([
    T.Resize((IMG_SIZE, IMG_SIZE)),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225]),
])

# %%
def load_coco(json_path: Path):
    with json_path.open("r") as f:
        return json.load(f)

train_coco = load_coco(TRAIN_JSON)

images = train_coco.get("images", [])
annotations = train_coco.get("annotations", [])
categories = train_coco.get("categories", [])

print("Train JSON loaded:")
print("  images:", len(images))
print("  annotations:", len(annotations))
print("  categories:", len(categories))
# Out:
# Train JSON loaded:
#   images: 33953
#   annotations: 60549
#   categories: 80

# %%
# Sort by category_id for a stable mapping
categories_sorted = sorted(categories, key=lambda c: c["id"])
cat_id_to_index = {c["id"]: i for i, c in enumerate(categories_sorted)}
index_to_cat = {i: c for i, c in enumerate(categories_sorted)}
index_to_name = {i: index_to_cat[i]["name"] for i in index_to_cat}

num_classes = len(categories_sorted)
print("num_classes:", num_classes)
print("First 10:", [(i, index_to_cat[i]["id"], index_to_name[i]) for i in range(min(10, num_classes))])

if num_classes != 80:
    print("[WARN] num_classes is not 80. Your edited JSON may have different categories.")
# Out:
# num_classes: 80
# First 10: [(0, 1, 'person'), (1, 2, 'bicycle'), (2, 3, 'car'), (3, 4, 'motorcycle'), (4, 5, 'airplane'), (5, 6, 'bus'), (6, 7, 'train'), (7, 8, 'truck'), (8, 9, 'boat'), (9, 10, 'traffic light')]

# %%
# image_id -> file_name
img_id_to_file = {im["id"]: im["file_name"] for im in images}

# image_id -> set of class indices present
img_id_to_catset = defaultdict(set)

missing_image_ids = 0
missing_category_ids = 0

for ann in annotations:


    img_id = ann["image_id"]
    cat_id = ann["category_id"]

    if img_id not in img_id_to_file:
        missing_image_ids += 1
        continue
    if cat_id not in cat_id_to_index:
        missing_category_ids += 1
        continue

    img_id_to_catset[img_id].add(cat_id_to_index[cat_id])

print("Missing image_id references in annotations:", missing_image_ids)
print("Missing category_id references in annotations:", missing_category_ids)

img_ids = [im["id"] for im in images]

labels_by_imgid = {}
for img_id in img_ids:
    y = np.zeros((num_classes,), dtype=np.float32)
    for idx in img_id_to_catset.get(img_id, set()):
        y[idx] = 1.0
    labels_by_imgid[img_id] = y

pos_counts = [int(labels_by_imgid[i].sum()) for i in img_ids]
print("Images with 0 labels:", sum(c == 0 for c in pos_counts))
print("Mean labels/image:", float(np.mean(pos_counts)))
print("Max labels/image:", int(np.max(pos_counts)))
# Out:
# Missing image_id references in annotations: 0
# Missing category_id references in annotations: 0
# Images with 0 labels: 0
# Mean labels/image: 1.4440844697081259
# Max labels/image: 5

# %%
all_ids = img_ids.copy()
random.shuffle(all_ids)

n_val = int(len(all_ids) * VAL_FRACTION)
val_ids = set(all_ids[:n_val])
train_ids = set(all_ids[n_val:])

print("Train IDs:", len(train_ids))
print("Val IDs:", len(val_ids))
print("Overlap:", len(train_ids & val_ids))
# Out:
# Train IDs: 30558
# Val IDs: 3395
# Overlap: 0

# %%
class CocoMultiLabelDataset(Dataset):
    def __init__(self, img_dir: Path, img_id_list, img_id_to_file, labels_by_imgid, transform=None):
        self.img_dir = Path(img_dir)
        self.img_ids = list(img_id_list)
        self.img_id_to_file = img_id_to_file
        self.labels_by_imgid = labels_by_imgid
        self.transform = transform

    def __len__(self):
        return len(self.img_ids)

    def __getitem__(self, idx):
        img_id = self.img_ids[idx]
        file_name = self.img_id_to_file[img_id]
        path = self.img_dir / file_name

        img = Image.open(path).convert("RGB")
        y = torch.from_numpy(self.labels_by_imgid[img_id])  # float32 multi-hot

        if self.transform is not None:
            img = self.transform(img)

        return img, y, img_id, file_name

train_ds = CocoMultiLabelDataset(
    img_dir=TRAIN_IMG_DIR,
    img_id_list=train_ids,
    img_id_to_file=img_id_to_file,
    labels_by_imgid=labels_by_imgid,
    transform=train_tfms
)

val_ds = CocoMultiLabelDataset(
    img_dir=TRAIN_IMG_DIR,
    img_id_list=val_ids,
    img_id_to_file=img_id_to_file,
    labels_by_imgid=labels_by_imgid,
    transform=eval_tfms
)

train_loader = DataLoader(
    train_ds, batch_size=BATCH_SIZE, shuffle=True,
    num_workers=NUM_WORKERS, pin_memory=(DEVICE=="cuda")
)
val_loader = DataLoader(
    val_ds, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=NUM_WORKERS, pin_memory=(DEVICE=="cuda")
)

print("Train batches:", len(train_loader))
print("Val batches:", len(val_loader))
# Out:
# Train batches: 478
# Val batches: 54

# %%
import sys

# ---- clone of CORnet ----
CORN_NET_REPO = Path("/zpool/vladlab/active_drive/omaltz/git_repos/CORnet")   
sys.path.insert(0, str(CORN_NET_REPO))

import cornet
print("Imported cornet from:", cornet.__file__)

def replace_last_linear(model: nn.Module, num_classes: int):
    last_name, last_linear = None, None
    for name, module in model.named_modules():
        if isinstance(module, nn.Linear):
            last_name, last_linear = name, module
    if last_linear is None:
        raise RuntimeError("No nn.Linear layer found in CORnet-Z.")
    parent = model
    parts = last_name.split(".")
    for p in parts[:-1]:
        parent = getattr(parent, p)
    setattr(parent, parts[-1], nn.Linear(last_linear.in_features, num_classes))
    print(f"Replaced final layer: {last_name} → {num_classes} outputs")
    return model

# CORnet-Z from scratch (no pretrained weights)
model = cornet.cornet_z(pretrained=False)
model = replace_last_linear(model, num_classes)
model = model.to(DEVICE)

print("CORnet-Z initialized from scratch.")
# Out:
# Imported cornet from: /zpool/vladlab/active_drive/omaltz/git_repos/CORnet/cornet/__init__.py
# Replaced final layer: module.decoder.linear → 80 outputs
# CORnet-Z initialized from scratch.

# %%
criterion = nn.BCEWithLogitsLoss()

optimizer = torch.optim.SGD(
    model.parameters(),
    lr=BASE_LR,
    momentum=MOMENTUM,
    weight_decay=WEIGHT_DECAY,
    nesterov=True
)

# We'll implement warmup + cosine manually per step
steps_per_epoch = len(train_loader)
total_steps = EPOCHS * steps_per_epoch
warmup_steps = WARMUP_EPOCHS * steps_per_epoch

def lr_at_step(global_step: int):
    # linear warmup to BASE_LR, then cosine down to MIN_LR
    if warmup_steps > 0 and global_step < warmup_steps:
        return BASE_LR * (global_step + 1) / warmup_steps
    # cosine phase
    progress = (global_step - warmup_steps) / max(1, (total_steps - warmup_steps))
    cosine = 0.5 * (1.0 + math.cos(math.pi * progress))
    return MIN_LR + (BASE_LR - MIN_LR) * cosine

def set_optimizer_lr(opt, lr):
    for pg in opt.param_groups:
        pg["lr"] = lr

# %%
imgs, labels, img_ids_batch, fnames = next(iter(train_loader))

print("Images shape:", imgs.shape)
print("Labels shape:", labels.shape)
print("Labels dtype:", labels.dtype)

unique_vals = torch.unique(labels)
print("Unique label values:", unique_vals.tolist())

pos_per_img = labels.sum(dim=1)
print("Positives per image (first 10):", pos_per_img[:10].tolist())
print("Images with >=1 positive:", int((pos_per_img > 0).sum()), "/", labels.size(0))

pos_per_class = labels.sum(dim=0)
topk = min(10, labels.shape[1])
top = torch.topk(pos_per_class, k=topk)
print(f"Top-{topk} classes by positives in this batch:")
for count, idx in zip(top.values.tolist(), top.indices.tolist()):
    print(f"  class {idx:02d} ({index_to_name[idx]}): {int(count)}")
# Out:
# Images shape: torch.Size([64, 3, 224, 224])
# Labels shape: torch.Size([64, 80])
# Labels dtype: torch.float32
# Unique label values: [0.0, 1.0]
# Positives per image (first 10): [1.0, 1.0, 1.0, 1.0, 2.0, 1.0, 3.0, 2.0, 1.0, 1.0]
# Images with >=1 positive: 64 / 64
# Top-10 classes by positives in this batch:
#   class 60 (dining table): 7
#   class 20 (elephant): 5
#   class 62 (tv): 5
#   class 61 (toilet): 5
#   class 56 (chair): 4
#   class 75 (vase): 4
#   class 15 (cat): 3
#   class 13 (bench): 3
#   class 23 (giraffe): 3
#   class 63 (laptop): 3

# %%
model.eval()
with torch.no_grad():
    x = imgs.to(DEVICE)
    y = labels.to(DEVICE)
    logits = model(x)
    if logits.ndim > 2:
        logits = logits.view(logits.shape[0], -1)

print("Logits shape:", logits.shape)
print("Expected shape:", y.shape)
print("Logits stats:",
      "min", float(logits.min()),
      "max", float(logits.max()),
      "mean", float(logits.mean()))
# Out:
# Logits shape: torch.Size([64, 80])
# Expected shape: torch.Size([64, 80])
# Logits stats: min -0.31883347034454346 max 0.3813466429710388 mean -0.001764744520187378

# %%
model.train()
optimizer.zero_grad(set_to_none=True)

logits = model(x)
if logits.ndim > 2:
    logits = logits.view(logits.shape[0], -1)

loss = criterion(logits, y)
print("Loss value:", float(loss))

loss.backward()

grads = [p.grad for p in model.parameters() if p.grad is not None]
print("Params with gradients:", len(grads))
print("First grad norm:", grads[0].norm().item() if grads else "NO GRADS")
# Out:
# Loss value: 0.6932470798492432
# Params with gradients: 10
# First grad norm: 0.03297942876815796

# %%
@torch.no_grad()
def micro_f1_from_logits(logits, targets, threshold=0.5):
    probs = torch.sigmoid(logits)
    preds = (probs >= threshold).float()

    tp = (preds * targets).sum().item()
    fp = (preds * (1 - targets)).sum().item()
    fn = ((1 - preds) * targets).sum().item()

    precision = tp / (tp + fp + 1e-12)
    recall = tp / (tp + fn + 1e-12)
    f1 = 2 * precision * recall / (precision + recall + 1e-12)
    return precision, recall, f1

def try_compute_map(y_true_np, y_prob_np):
    try:
        from sklearn.metrics import average_precision_score
        per_class_ap = []
        for c in range(y_true_np.shape[1]):
            if y_true_np[:, c].sum() == 0:
                per_class_ap.append(np.nan)
            else:
                per_class_ap.append(average_precision_score(y_true_np[:, c], y_prob_np[:, c]))
        return float(np.nanmean(per_class_ap)), per_class_ap
    except Exception:
        return None, None

# %%
GRAD_CLIP_NORM = 1.0  # set to None to disable

def run_train_epoch(model, loader, criterion, optimizer, start_global_step: int):
    model.train()
    losses = []
    all_probs = []
    all_targets = []

    global_step = start_global_step

    for step, (x, y, _, _) in enumerate(loader, start=1):
        x = x.to(DEVICE, non_blocking=True)
        y = y.to(DEVICE, non_blocking=True)

        # set LR for this step
        lr = lr_at_step(global_step)
        set_optimizer_lr(optimizer, lr)

        optimizer.zero_grad(set_to_none=True)

        logits = model(x)
        if logits.ndim > 2:
            logits = logits.view(logits.shape[0], -1)

        loss = criterion(logits, y)
        loss.backward()

        if GRAD_CLIP_NORM is not None:
            nn.utils.clip_grad_norm_(model.parameters(), GRAD_CLIP_NORM)

        optimizer.step()

        losses.append(loss.item())

        probs = torch.sigmoid(logits).detach().cpu()
        all_probs.append(probs)
        all_targets.append(y.detach().cpu())

        if step % PRINT_EVERY == 0:
            print(f"  step {step}/{len(loader)}  loss={np.mean(losses):.4f}  lr={lr:.6f}")

        global_step += 1

    all_probs = torch.cat(all_probs, dim=0)
    all_targets = torch.cat(all_targets, dim=0)

    p, r, f1 = micro_f1_from_logits(torch.logit(all_probs.clamp(1e-6, 1-1e-6)), all_targets, threshold=0.5)
    mAP, _ = try_compute_map(all_targets.numpy(), all_probs.numpy())
    return float(np.mean(losses)), p, r, f1, mAP, global_step


@torch.no_grad()
def run_eval_epoch(model, loader, criterion):
    model.eval()
    losses = []
    all_probs = []
    all_targets = []

    for x, y, _, _ in loader:
        x = x.to(DEVICE, non_blocking=True)
        y = y.to(DEVICE, non_blocking=True)

        logits = model(x)
        if logits.ndim > 2:
            logits = logits.view(logits.shape[0], -1)

        loss = criterion(logits, y)
        losses.append(loss.item())

        probs = torch.sigmoid(logits).cpu()
        all_probs.append(probs)
        all_targets.append(y.cpu())

    all_probs = torch.cat(all_probs, dim=0)
    all_targets = torch.cat(all_targets, dim=0)

    p, r, f1 = micro_f1_from_logits(torch.logit(all_probs.clamp(1e-6, 1-1e-6)), all_targets, threshold=0.5)
    mAP, _ = try_compute_map(all_targets.numpy(), all_probs.numpy())
    return float(np.mean(losses)), p, r, f1, mAP

# %%
from datetime import datetime

OUT_DIR = Path("./cornet_z_identification_model_big_200") / datetime.now().strftime("%Y%m%d_%H%M%S")
OUT_DIR.mkdir(parents=True, exist_ok=True)

BEST_PATH = OUT_DIR / "best.pt"
LAST_PATH = OUT_DIR / "last.pt"

best_val_loss = float("inf")
global_step = 0

print("Saving to:", OUT_DIR)

for epoch in range(1, EPOCHS + 1):
    print(f"\nEpoch {epoch}/{EPOCHS}")

    train_loss, train_p, train_r, train_f1, train_map, global_step = run_train_epoch(
        model, train_loader, criterion, optimizer, start_global_step=global_step
    )
    print(f"Train: loss={train_loss:.4f}  microP={train_p:.3f} microR={train_r:.3f} microF1={train_f1:.3f}"
          + (f"  mAP={train_map:.3f}" if train_map is not None else ""))

    val_loss, val_p, val_r, val_f1, val_map = run_eval_epoch(
        model, val_loader, criterion
    )
    print(f"Val:   loss={val_loss:.4f}  microP={val_p:.3f} microR={val_r:.3f} microF1={val_f1:.3f}"
          + (f"  mAP={val_map:.3f}" if val_map is not None else ""))

    # Save last
    torch.save({
        "epoch": epoch,
        "global_step": global_step,
        "model_state": model.state_dict(),
        "optimizer_state": optimizer.state_dict(),
        "cat_id_to_index": cat_id_to_index,
        "index_to_name": index_to_name,
        "config": {
            "SEED": SEED, "VAL_FRACTION": VAL_FRACTION, "BATCH_SIZE": BATCH_SIZE,
            "EPOCHS": EPOCHS, "IMG_SIZE": IMG_SIZE,
            "BASE_LR": BASE_LR, "MIN_LR": MIN_LR, "WARMUP_EPOCHS": WARMUP_EPOCHS,
            "MOMENTUM": MOMENTUM, "WEIGHT_DECAY": WEIGHT_DECAY,
        }
    }, LAST_PATH)

    # Save best
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save({
            "epoch": epoch,
            "global_step": global_step,
            "best_val_loss": best_val_loss,
            "model_state": model.state_dict(),
            "optimizer_state": optimizer.state_dict(),
            "cat_id_to_index": cat_id_to_index,
            "index_to_name": index_to_name
        }, BEST_PATH)
        print(f"  ✅ Saved best checkpoint: {BEST_PATH}")
# Out:
# Saving to: cornet_z_identification_model_big_200/20260116_110503
#
# Epoch 1/200
#   step 100/478  loss=0.5600  lr=0.004184
#   step 200/478  loss=0.3254  lr=0.008368
#   step 300/478  loss=0.2459  lr=0.012552
#   step 400/478  loss=0.2062  lr=0.016736
# Train: loss=0.1866  microP=0.015 microR=0.036 microF1=0.021
# Val:   loss=0.0870  microP=0.000 microR=0.000 microF1=0.000
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 2/200
#   step 100/478  loss=0.0873  lr=0.024184
#   step 200/478  loss=0.0869  lr=0.028368
#   step 300/478  loss=0.0864  lr=0.032552
#   step 400/478  loss=0.0860  lr=0.036736
# Train: loss=0.0859  microP=0.000 microR=0.000 microF1=0.000
# Val:   loss=0.0852  microP=0.000 microR=0.000 microF1=0.000
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 3/200
#   step 100/478  loss=0.0841  lr=0.044184
#   step 200/478  loss=0.0838  lr=0.048368
#   step 300/478  loss=0.0836  lr=0.052552
#   step 400/478  loss=0.0831  lr=0.056736
# Train: loss=0.0826  microP=0.349 microR=0.002 microF1=0.005
# Val:   loss=0.0812  microP=0.455 microR=0.003 microF1=0.006
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 4/200
#   step 100/478  loss=0.0799  lr=0.064184
#   step 200/478  loss=0.0795  lr=0.068368
#   step 300/478  loss=0.0790  lr=0.072552
#   step 400/478  loss=0.0785  lr=0.076736
# Train: loss=0.0783  microP=0.426 microR=0.006 microF1=0.011
# Val:   loss=0.0771  microP=0.519 microR=0.009 microF1=0.017
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 5/200
#   step 100/478  loss=0.0761  lr=0.084184
#   step 200/478  loss=0.0754  lr=0.088368
#   step 300/478  loss=0.0755  lr=0.092552
#   step 400/478  loss=0.0754  lr=0.096736
# Train: loss=0.0750  microP=0.541 microR=0.014 microF1=0.028
# Val:   loss=0.0752  microP=0.557 microR=0.018 microF1=0.035
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 6/200
#   step 100/478  loss=0.0737  lr=0.100000
#   step 200/478  loss=0.0740  lr=0.099999
#   step 300/478  loss=0.0736  lr=0.099997
#   step 400/478  loss=0.0734  lr=0.099995
# Train: loss=0.0731  microP=0.563 microR=0.019 microF1=0.037
# Val:   loss=0.0738  microP=0.678 microR=0.017 microF1=0.033
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 7/200
#   step 100/478  loss=0.0722  lr=0.099991
#   step 200/478  loss=0.0721  lr=0.099987
#   step 300/478  loss=0.0722  lr=0.099983
#   step 400/478  loss=0.0719  lr=0.099978
# Train: loss=0.0716  microP=0.606 microR=0.024 microF1=0.046
# Val:   loss=0.0719  microP=0.639 microR=0.027 microF1=0.052
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 8/200
#   step 100/478  loss=0.0710  lr=0.099968
#   step 200/478  loss=0.0706  lr=0.099962
#   step 300/478  loss=0.0704  lr=0.099955
#   step 400/478  loss=0.0703  lr=0.099948
# Train: loss=0.0702  microP=0.618 microR=0.033 microF1=0.063
# Val:   loss=0.0711  microP=0.594 microR=0.044 microF1=0.081
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 9/200
#   step 100/478  loss=0.0690  lr=0.099933
#   step 200/478  loss=0.0689  lr=0.099924
#   step 300/478  loss=0.0690  lr=0.099915
#   step 400/478  loss=0.0688  lr=0.099905
# Train: loss=0.0688  microP=0.642 microR=0.038 microF1=0.072
# Val:   loss=0.0694  microP=0.653 microR=0.047 microF1=0.088
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 10/200
#   step 100/478  loss=0.0680  lr=0.099885
#   step 200/478  loss=0.0679  lr=0.099874
#   step 300/478  loss=0.0678  lr=0.099861
#   step 400/478  loss=0.0677  lr=0.099848
# Train: loss=0.0676  microP=0.640 microR=0.046 microF1=0.085
# Val:   loss=0.0689  microP=0.654 microR=0.051 microF1=0.095
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 11/200
#   step 100/478  loss=0.0676  lr=0.099824
#   step 200/478  loss=0.0672  lr=0.099810
#   step 300/478  loss=0.0670  lr=0.099795
#   step 400/478  loss=0.0668  lr=0.099779
# Train: loss=0.0667  microP=0.644 microR=0.051 microF1=0.094
# Val:   loss=0.0677  microP=0.660 microR=0.069 microF1=0.124
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 12/200
#   step 100/478  loss=0.0657  lr=0.099750
#   step 200/478  loss=0.0656  lr=0.099733
#   step 300/478  loss=0.0658  lr=0.099715
#   step 400/478  loss=0.0658  lr=0.099697
# Train: loss=0.0658  microP=0.672 microR=0.060 microF1=0.110
# Val:   loss=0.0682  microP=0.658 microR=0.048 microF1=0.089
#
# Epoch 13/200
#   step 100/478  loss=0.0658  lr=0.099663
#   step 200/478  loss=0.0657  lr=0.099644
#   step 300/478  loss=0.0651  lr=0.099623
#   step 400/478  loss=0.0650  lr=0.099602
# Train: loss=0.0649  microP=0.683 microR=0.064 microF1=0.117
# Val:   loss=0.0660  microP=0.759 microR=0.054 microF1=0.101
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 14/200
#   step 100/478  loss=0.0639  lr=0.099564
#   step 200/478  loss=0.0641  lr=0.099541
#   step 300/478  loss=0.0644  lr=0.099518
#   step 400/478  loss=0.0643  lr=0.099494
# Train: loss=0.0642  microP=0.686 microR=0.071 microF1=0.129
# Val:   loss=0.0661  microP=0.556 microR=0.091 microF1=0.157
#
# Epoch 15/200
#   step 100/478  loss=0.0633  lr=0.099451
#   step 200/478  loss=0.0636  lr=0.099426
#   step 300/478  loss=0.0636  lr=0.099400
#   step 400/478  loss=0.0635  lr=0.099374
# Train: loss=0.0634  microP=0.690 microR=0.077 microF1=0.139
# Val:   loss=0.0652  microP=0.678 microR=0.088 microF1=0.155
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 16/200
#   step 100/478  loss=0.0627  lr=0.099326
#   step 200/478  loss=0.0629  lr=0.099298
#   step 300/478  loss=0.0628  lr=0.099269
#   step 400/478  loss=0.0628  lr=0.099240
# Train: loss=0.0628  microP=0.695 microR=0.082 microF1=0.147
# Val:   loss=0.0648  microP=0.594 microR=0.099 microF1=0.169
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 17/200
#   step 100/478  loss=0.0620  lr=0.099187
#   step 200/478  loss=0.0624  lr=0.099157
#   step 300/478  loss=0.0622  lr=0.099126
#   step 400/478  loss=0.0622  lr=0.099094
# Train: loss=0.0622  microP=0.704 microR=0.090 microF1=0.160
# Val:   loss=0.0646  microP=0.621 microR=0.091 microF1=0.159
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 18/200
#   step 100/478  loss=0.0627  lr=0.099036
#   step 200/478  loss=0.0621  lr=0.099003
#   step 300/478  loss=0.0622  lr=0.098969
#   step 400/478  loss=0.0619  lr=0.098935
# Train: loss=0.0616  microP=0.703 microR=0.094 microF1=0.166
# Val:   loss=0.0641  microP=0.715 microR=0.088 microF1=0.157
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 19/200
#   step 100/478  loss=0.0607  lr=0.098873
#   step 200/478  loss=0.0609  lr=0.098837
#   step 300/478  loss=0.0609  lr=0.098800
#   step 400/478  loss=0.0610  lr=0.098763
# Train: loss=0.0610  microP=0.702 microR=0.099 microF1=0.174
# Val:   loss=0.0626  microP=0.702 microR=0.090 microF1=0.160
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 20/200
#   step 100/478  loss=0.0605  lr=0.098696
#   step 200/478  loss=0.0607  lr=0.098658
#   step 300/478  loss=0.0607  lr=0.098619
#   step 400/478  loss=0.0606  lr=0.098579
# Train: loss=0.0606  microP=0.703 microR=0.105 microF1=0.183
# Val:   loss=0.0630  microP=0.723 microR=0.094 microF1=0.166
#
# Epoch 21/200
#   step 100/478  loss=0.0604  lr=0.098507
#   step 200/478  loss=0.0600  lr=0.098466
#   step 300/478  loss=0.0600  lr=0.098424
#   step 400/478  loss=0.0602  lr=0.098382
# Train: loss=0.0602  microP=0.713 microR=0.109 microF1=0.189
# Val:   loss=0.0619  microP=0.652 microR=0.120 microF1=0.203
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 22/200
#   step 100/478  loss=0.0604  lr=0.098305
#   step 200/478  loss=0.0598  lr=0.098262
#   step 300/478  loss=0.0597  lr=0.098217
#   step 400/478  loss=0.0596  lr=0.098172
# Train: loss=0.0597  microP=0.715 microR=0.115 microF1=0.198
# Val:   loss=0.0625  microP=0.671 microR=0.117 microF1=0.200
#
# Epoch 23/200
#   step 100/478  loss=0.0595  lr=0.098091
#   step 200/478  loss=0.0595  lr=0.098045
#   step 300/478  loss=0.0592  lr=0.097998
#   step 400/478  loss=0.0593  lr=0.097950
# Train: loss=0.0593  microP=0.714 microR=0.119 microF1=0.204
# Val:   loss=0.0611  microP=0.759 microR=0.099 microF1=0.175
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 24/200
#   step 100/478  loss=0.0585  lr=0.097865
#   step 200/478  loss=0.0593  lr=0.097816
#   step 300/478  loss=0.0591  lr=0.097766
#   step 400/478  loss=0.0589  lr=0.097716
# Train: loss=0.0588  microP=0.723 microR=0.125 microF1=0.213
# Val:   loss=0.0629  microP=0.610 microR=0.128 microF1=0.211
#
# Epoch 25/200
#   step 100/478  loss=0.0581  lr=0.097625
#   step 200/478  loss=0.0586  lr=0.097574
#   step 300/478  loss=0.0587  lr=0.097522
#   step 400/478  loss=0.0585  lr=0.097469
# Train: loss=0.0586  microP=0.714 microR=0.127 microF1=0.215
# Val:   loss=0.0603  microP=0.707 microR=0.121 microF1=0.207
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 26/200
#   step 100/478  loss=0.0580  lr=0.097374
#   step 200/478  loss=0.0578  lr=0.097320
#   step 300/478  loss=0.0580  lr=0.097265
#   step 400/478  loss=0.0581  lr=0.097210
# Train: loss=0.0581  microP=0.724 microR=0.133 microF1=0.225
# Val:   loss=0.0610  microP=0.656 microR=0.137 microF1=0.226
#
# Epoch 27/200
#   step 100/478  loss=0.0571  lr=0.097110
#   step 200/478  loss=0.0576  lr=0.097054
#   step 300/478  loss=0.0577  lr=0.096996
#   step 400/478  loss=0.0576  lr=0.096938
# Train: loss=0.0577  microP=0.723 microR=0.137 microF1=0.230
# Val:   loss=0.0598  microP=0.686 microR=0.144 microF1=0.238
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 28/200
#   step 100/478  loss=0.0576  lr=0.096834
#   step 200/478  loss=0.0574  lr=0.096775
#   step 300/478  loss=0.0572  lr=0.096715
#   step 400/478  loss=0.0572  lr=0.096655
# Train: loss=0.0573  microP=0.726 microR=0.141 microF1=0.236
# Val:   loss=0.0596  microP=0.720 microR=0.131 microF1=0.221
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 29/200
#   step 100/478  loss=0.0571  lr=0.096546
#   step 200/478  loss=0.0568  lr=0.096484
#   step 300/478  loss=0.0569  lr=0.096422
#   step 400/478  loss=0.0568  lr=0.096359
# Train: loss=0.0569  microP=0.726 microR=0.145 microF1=0.242
# Val:   loss=0.0598  microP=0.665 microR=0.117 microF1=0.199
#
# Epoch 30/200
#   step 100/478  loss=0.0572  lr=0.096246
#   step 200/478  loss=0.0568  lr=0.096182
#   step 300/478  loss=0.0567  lr=0.096117
#   step 400/478  loss=0.0565  lr=0.096051
# Train: loss=0.0565  microP=0.728 microR=0.150 microF1=0.249
# Val:   loss=0.0595  microP=0.696 microR=0.128 microF1=0.217
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 31/200
#   step 100/478  loss=0.0564  lr=0.095934
#   step 200/478  loss=0.0563  lr=0.095867
#   step 300/478  loss=0.0562  lr=0.095800
#   step 400/478  loss=0.0563  lr=0.095732
# Train: loss=0.0563  microP=0.728 microR=0.155 microF1=0.255
# Val:   loss=0.0598  microP=0.733 microR=0.127 microF1=0.216
#
# Epoch 32/200
#   step 100/478  loss=0.0562  lr=0.095610
#   step 200/478  loss=0.0561  lr=0.095540
#   step 300/478  loss=0.0562  lr=0.095470
#   step 400/478  loss=0.0561  lr=0.095400
# Train: loss=0.0560  microP=0.729 microR=0.155 microF1=0.256
# Val:   loss=0.0582  microP=0.721 microR=0.140 microF1=0.234
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 33/200
#   step 100/478  loss=0.0555  lr=0.095274
#   step 200/478  loss=0.0556  lr=0.095202
#   step 300/478  loss=0.0557  lr=0.095130
#   step 400/478  loss=0.0555  lr=0.095057
# Train: loss=0.0557  microP=0.728 microR=0.159 microF1=0.261
# Val:   loss=0.0594  microP=0.711 microR=0.138 microF1=0.231
#
# Epoch 34/200
#   step 100/478  loss=0.0555  lr=0.094926
#   step 200/478  loss=0.0554  lr=0.094852
#   step 300/478  loss=0.0553  lr=0.094777
#   step 400/478  loss=0.0555  lr=0.094702
# Train: loss=0.0553  microP=0.735 microR=0.164 microF1=0.268
# Val:   loss=0.0615  microP=0.727 microR=0.132 microF1=0.224
#
# Epoch 35/200
#   step 100/478  loss=0.0547  lr=0.094567
#   step 200/478  loss=0.0547  lr=0.094490
#   step 300/478  loss=0.0549  lr=0.094413
#   step 400/478  loss=0.0550  lr=0.094335
# Train: loss=0.0551  microP=0.732 microR=0.169 microF1=0.274
# Val:   loss=0.0588  microP=0.657 microR=0.158 microF1=0.255
#
# Epoch 36/200
#   step 100/478  loss=0.0548  lr=0.094196
#   step 200/478  loss=0.0552  lr=0.094117
#   step 300/478  loss=0.0549  lr=0.094037
#   step 400/478  loss=0.0549  lr=0.093957
# Train: loss=0.0548  microP=0.734 microR=0.169 microF1=0.275
# Val:   loss=0.0587  microP=0.761 microR=0.127 microF1=0.218
#
# Epoch 37/200
#   step 100/478  loss=0.0544  lr=0.093813
#   step 200/478  loss=0.0545  lr=0.093732
#   step 300/478  loss=0.0545  lr=0.093650
#   step 400/478  loss=0.0544  lr=0.093567
# Train: loss=0.0544  microP=0.738 microR=0.176 microF1=0.285
# Val:   loss=0.0580  microP=0.681 microR=0.163 microF1=0.263
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 38/200
#   step 100/478  loss=0.0545  lr=0.093419
#   step 200/478  loss=0.0543  lr=0.093336
#   step 300/478  loss=0.0545  lr=0.093251
#   step 400/478  loss=0.0545  lr=0.093167
# Train: loss=0.0543  microP=0.733 microR=0.177 microF1=0.285
# Val:   loss=0.0577  microP=0.723 microR=0.162 microF1=0.265
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 39/200
#   step 100/478  loss=0.0546  lr=0.093014
#   step 200/478  loss=0.0539  lr=0.092928
#   step 300/478  loss=0.0541  lr=0.092842
#   step 400/478  loss=0.0542  lr=0.092754
# Train: loss=0.0541  microP=0.733 microR=0.179 microF1=0.287
# Val:   loss=0.0570  microP=0.714 microR=0.163 microF1=0.265
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 40/200
#   step 100/478  loss=0.0532  lr=0.092598
#   step 200/478  loss=0.0538  lr=0.092510
#   step 300/478  loss=0.0538  lr=0.092421
#   step 400/478  loss=0.0538  lr=0.092331
# Train: loss=0.0538  microP=0.739 microR=0.183 microF1=0.293
# Val:   loss=0.0568  microP=0.694 microR=0.178 microF1=0.283
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 41/200
#   step 100/478  loss=0.0530  lr=0.092171
#   step 200/478  loss=0.0532  lr=0.092080
#   step 300/478  loss=0.0534  lr=0.091989
#   step 400/478  loss=0.0534  lr=0.091897
# Train: loss=0.0535  microP=0.739 microR=0.187 microF1=0.298
# Val:   loss=0.0570  microP=0.684 microR=0.191 microF1=0.299
#
# Epoch 42/200
#   step 100/478  loss=0.0531  lr=0.091733
#   step 200/478  loss=0.0532  lr=0.091640
#   step 300/478  loss=0.0533  lr=0.091546
#   step 400/478  loss=0.0532  lr=0.091452
# Train: loss=0.0533  microP=0.736 microR=0.187 microF1=0.298
# Val:   loss=0.0566  microP=0.689 microR=0.177 microF1=0.281
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 43/200
#   step 100/478  loss=0.0523  lr=0.091284
#   step 200/478  loss=0.0525  lr=0.091188
#   step 300/478  loss=0.0528  lr=0.091093
#   step 400/478  loss=0.0530  lr=0.090996
# Train: loss=0.0531  microP=0.741 microR=0.192 microF1=0.305
# Val:   loss=0.0573  microP=0.606 microR=0.215 microF1=0.318
#
# Epoch 44/200
#   step 100/478  loss=0.0531  lr=0.090824
#   step 200/478  loss=0.0528  lr=0.090726
#   step 300/478  loss=0.0528  lr=0.090628
#   step 400/478  loss=0.0528  lr=0.090530
# Train: loss=0.0528  microP=0.742 microR=0.196 microF1=0.310
# Val:   loss=0.0563  microP=0.690 microR=0.197 microF1=0.306
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 45/200
#   step 100/478  loss=0.0520  lr=0.090354
#   step 200/478  loss=0.0526  lr=0.090254
#   step 300/478  loss=0.0526  lr=0.090154
#   step 400/478  loss=0.0524  lr=0.090053
# Train: loss=0.0526  microP=0.743 microR=0.201 microF1=0.316
# Val:   loss=0.0560  microP=0.674 microR=0.208 microF1=0.318
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 46/200
#   step 100/478  loss=0.0522  lr=0.089873
#   step 200/478  loss=0.0524  lr=0.089771
#   step 300/478  loss=0.0525  lr=0.089668
#   step 400/478  loss=0.0526  lr=0.089566
# Train: loss=0.0524  microP=0.744 microR=0.200 microF1=0.315
# Val:   loss=0.0560  microP=0.737 microR=0.190 microF1=0.302
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 47/200
#   step 100/478  loss=0.0524  lr=0.089382
#   step 200/478  loss=0.0520  lr=0.089277
#   step 300/478  loss=0.0520  lr=0.089173
#   step 400/478  loss=0.0522  lr=0.089068
# Train: loss=0.0522  microP=0.741 microR=0.203 microF1=0.319
# Val:   loss=0.0567  microP=0.672 microR=0.215 microF1=0.326
#
# Epoch 48/200
#   step 100/478  loss=0.0522  lr=0.088880
#   step 200/478  loss=0.0522  lr=0.088774
#   step 300/478  loss=0.0522  lr=0.088667
#   step 400/478  loss=0.0522  lr=0.088560
# Train: loss=0.0521  microP=0.742 microR=0.204 microF1=0.320
# Val:   loss=0.0563  microP=0.668 microR=0.205 microF1=0.314
#
# Epoch 49/200
#   step 100/478  loss=0.0517  lr=0.088369
#   step 200/478  loss=0.0516  lr=0.088260
#   step 300/478  loss=0.0517  lr=0.088152
#   step 400/478  loss=0.0518  lr=0.088043
# Train: loss=0.0519  microP=0.744 microR=0.208 microF1=0.325
# Val:   loss=0.0556  microP=0.743 microR=0.162 microF1=0.266
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 50/200
#   step 100/478  loss=0.0510  lr=0.087847
#   step 200/478  loss=0.0516  lr=0.087737
#   step 300/478  loss=0.0517  lr=0.087626
#   step 400/478  loss=0.0518  lr=0.087515
# Train: loss=0.0517  microP=0.744 microR=0.208 microF1=0.325
# Val:   loss=0.0559  microP=0.707 microR=0.188 microF1=0.297
#
# Epoch 51/200
#   step 100/478  loss=0.0519  lr=0.087316
#   step 200/478  loss=0.0515  lr=0.087204
#   step 300/478  loss=0.0516  lr=0.087091
#   step 400/478  loss=0.0515  lr=0.086978
# Train: loss=0.0515  microP=0.746 microR=0.214 microF1=0.332
# Val:   loss=0.0555  microP=0.715 microR=0.192 microF1=0.303
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 52/200
#   step 100/478  loss=0.0504  lr=0.086775
#   step 200/478  loss=0.0510  lr=0.086661
#   step 300/478  loss=0.0514  lr=0.086546
#   step 400/478  loss=0.0513  lr=0.086431
# Train: loss=0.0514  microP=0.740 microR=0.211 microF1=0.329
# Val:   loss=0.0548  microP=0.735 microR=0.188 microF1=0.300
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 53/200
#   step 100/478  loss=0.0511  lr=0.086225
#   step 200/478  loss=0.0512  lr=0.086108
#   step 300/478  loss=0.0511  lr=0.085991
#   step 400/478  loss=0.0510  lr=0.085874
# Train: loss=0.0511  microP=0.750 microR=0.217 microF1=0.337
# Val:   loss=0.0556  microP=0.654 microR=0.225 microF1=0.335
#
# Epoch 54/200
#   step 100/478  loss=0.0511  lr=0.085665
#   step 200/478  loss=0.0510  lr=0.085546
#   step 300/478  loss=0.0510  lr=0.085428
#   step 400/478  loss=0.0510  lr=0.085309
# Train: loss=0.0510  microP=0.749 microR=0.219 microF1=0.339
# Val:   loss=0.0553  microP=0.773 microR=0.174 microF1=0.284
#
# Epoch 55/200
#   step 100/478  loss=0.0511  lr=0.085096
#   step 200/478  loss=0.0511  lr=0.084975
#   step 300/478  loss=0.0510  lr=0.084855
#   step 400/478  loss=0.0509  lr=0.084734
# Train: loss=0.0509  microP=0.753 microR=0.222 microF1=0.343
# Val:   loss=0.0550  microP=0.674 microR=0.232 microF1=0.345
#
# Epoch 56/200
#   step 100/478  loss=0.0503  lr=0.084517
#   step 200/478  loss=0.0504  lr=0.084395
#   step 300/478  loss=0.0505  lr=0.084273
#   step 400/478  loss=0.0507  lr=0.084150
# Train: loss=0.0507  microP=0.753 microR=0.224 microF1=0.345
# Val:   loss=0.0554  microP=0.663 microR=0.245 microF1=0.358
#
# Epoch 57/200
#   step 100/478  loss=0.0500  lr=0.083930
#   step 200/478  loss=0.0503  lr=0.083806
#   step 300/478  loss=0.0505  lr=0.083682
#   step 400/478  loss=0.0506  lr=0.083557
# Train: loss=0.0505  microP=0.752 microR=0.225 microF1=0.346
# Val:   loss=0.0548  microP=0.670 microR=0.252 microF1=0.366
#
# Epoch 58/200
#   step 100/478  loss=0.0501  lr=0.083334
#   step 200/478  loss=0.0503  lr=0.083208
#   step 300/478  loss=0.0505  lr=0.083082
#   step 400/478  loss=0.0503  lr=0.082956
# Train: loss=0.0503  microP=0.754 microR=0.228 microF1=0.350
# Val:   loss=0.0542  microP=0.748 microR=0.193 microF1=0.307
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 59/200
#   step 100/478  loss=0.0506  lr=0.082729
#   step 200/478  loss=0.0504  lr=0.082602
#   step 300/478  loss=0.0505  lr=0.082474
#   step 400/478  loss=0.0503  lr=0.082346
# Train: loss=0.0503  microP=0.752 microR=0.227 microF1=0.348
# Val:   loss=0.0541  microP=0.695 microR=0.228 microF1=0.344
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 60/200
#   step 100/478  loss=0.0497  lr=0.082116
#   step 200/478  loss=0.0500  lr=0.081987
#   step 300/478  loss=0.0498  lr=0.081857
#   step 400/478  loss=0.0499  lr=0.081727
# Train: loss=0.0500  microP=0.752 microR=0.231 microF1=0.353
# Val:   loss=0.0539  microP=0.738 microR=0.195 microF1=0.309
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 61/200
#   step 100/478  loss=0.0492  lr=0.081495
#   step 200/478  loss=0.0497  lr=0.081364
#   step 300/478  loss=0.0498  lr=0.081232
#   step 400/478  loss=0.0499  lr=0.081100
# Train: loss=0.0500  microP=0.750 microR=0.232 microF1=0.355
# Val:   loss=0.0539  microP=0.710 microR=0.216 microF1=0.331
#
# Epoch 62/200
#   step 100/478  loss=0.0500  lr=0.080865
#   step 200/478  loss=0.0500  lr=0.080732
#   step 300/478  loss=0.0500  lr=0.080599
#   step 400/478  loss=0.0499  lr=0.080466
# Train: loss=0.0498  microP=0.751 microR=0.233 microF1=0.356
# Val:   loss=0.0546  microP=0.645 microR=0.250 microF1=0.360
#
# Epoch 63/200
#   step 100/478  loss=0.0491  lr=0.080227
#   step 200/478  loss=0.0496  lr=0.080093
#   step 300/478  loss=0.0494  lr=0.079958
#   step 400/478  loss=0.0493  lr=0.079823
# Train: loss=0.0496  microP=0.751 microR=0.237 microF1=0.361
# Val:   loss=0.0544  microP=0.727 microR=0.203 microF1=0.318
#
# Epoch 64/200
#   step 100/478  loss=0.0494  lr=0.079582
#   step 200/478  loss=0.0495  lr=0.079446
#   step 300/478  loss=0.0495  lr=0.079309
#   step 400/478  loss=0.0495  lr=0.079173
# Train: loss=0.0496  microP=0.758 microR=0.238 microF1=0.362
# Val:   loss=0.0544  microP=0.737 microR=0.210 microF1=0.327
#
# Epoch 65/200
#   step 100/478  loss=0.0486  lr=0.078929
#   step 200/478  loss=0.0491  lr=0.078791
#   step 300/478  loss=0.0492  lr=0.078653
#   step 400/478  loss=0.0493  lr=0.078515
# Train: loss=0.0494  microP=0.754 microR=0.238 microF1=0.362
# Val:   loss=0.0540  microP=0.698 microR=0.226 microF1=0.342
#
# Epoch 66/200
#   step 100/478  loss=0.0494  lr=0.078268
#   step 200/478  loss=0.0495  lr=0.078129
#   step 300/478  loss=0.0494  lr=0.077989
#   step 400/478  loss=0.0494  lr=0.077850
# Train: loss=0.0493  microP=0.756 microR=0.240 microF1=0.365
# Val:   loss=0.0537  microP=0.742 microR=0.195 microF1=0.309
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 67/200
#   step 100/478  loss=0.0488  lr=0.077600
#   step 200/478  loss=0.0486  lr=0.077459
#   step 300/478  loss=0.0489  lr=0.077318
#   step 400/478  loss=0.0492  lr=0.077177
# Train: loss=0.0491  microP=0.752 microR=0.243 microF1=0.368
# Val:   loss=0.0539  microP=0.701 microR=0.233 microF1=0.350
#
# Epoch 68/200
#   step 100/478  loss=0.0489  lr=0.076925
#   step 200/478  loss=0.0488  lr=0.076783
#   step 300/478  loss=0.0489  lr=0.076640
#   step 400/478  loss=0.0492  lr=0.076497
# Train: loss=0.0490  microP=0.754 microR=0.244 microF1=0.369
# Val:   loss=0.0533  microP=0.711 microR=0.236 microF1=0.355
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 69/200
#   step 100/478  loss=0.0485  lr=0.076243
#   step 200/478  loss=0.0486  lr=0.076099
#   step 300/478  loss=0.0489  lr=0.075955
#   step 400/478  loss=0.0489  lr=0.075811
# Train: loss=0.0490  microP=0.756 microR=0.243 microF1=0.368
# Val:   loss=0.0533  microP=0.720 microR=0.225 microF1=0.343
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 70/200
#   step 100/478  loss=0.0488  lr=0.075554
#   step 200/478  loss=0.0488  lr=0.075409
#   step 300/478  loss=0.0489  lr=0.075263
#   step 400/478  loss=0.0489  lr=0.075118
# Train: loss=0.0488  microP=0.758 microR=0.246 microF1=0.372
# Val:   loss=0.0541  microP=0.714 microR=0.223 microF1=0.340
#
# Epoch 71/200
#   step 100/478  loss=0.0486  lr=0.074858
#   step 200/478  loss=0.0482  lr=0.074712
#   step 300/478  loss=0.0488  lr=0.074565
#   step 400/478  loss=0.0487  lr=0.074418
# Train: loss=0.0487  microP=0.762 microR=0.250 microF1=0.377
# Val:   loss=0.0536  microP=0.693 microR=0.233 microF1=0.349
#
# Epoch 72/200
#   step 100/478  loss=0.0479  lr=0.074156
#   step 200/478  loss=0.0487  lr=0.074008
#   step 300/478  loss=0.0485  lr=0.073860
#   step 400/478  loss=0.0484  lr=0.073712
# Train: loss=0.0485  microP=0.758 microR=0.251 microF1=0.377
# Val:   loss=0.0533  microP=0.696 microR=0.248 microF1=0.366
#
# Epoch 73/200
#   step 100/478  loss=0.0486  lr=0.073447
#   step 200/478  loss=0.0485  lr=0.073298
#   step 300/478  loss=0.0483  lr=0.073149
#   step 400/478  loss=0.0485  lr=0.073000
# Train: loss=0.0485  microP=0.760 microR=0.252 microF1=0.378
# Val:   loss=0.0540  microP=0.727 microR=0.225 microF1=0.343
#
# Epoch 74/200
#   step 100/478  loss=0.0483  lr=0.072733
#   step 200/478  loss=0.0484  lr=0.072583
#   step 300/478  loss=0.0484  lr=0.072432
#   step 400/478  loss=0.0483  lr=0.072282
# Train: loss=0.0484  microP=0.761 microR=0.254 microF1=0.381
# Val:   loss=0.0531  microP=0.658 microR=0.248 microF1=0.360
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 75/200
#   step 100/478  loss=0.0484  lr=0.072013
#   step 200/478  loss=0.0483  lr=0.071861
#   step 300/478  loss=0.0482  lr=0.071710
#   step 400/478  loss=0.0482  lr=0.071558
# Train: loss=0.0482  microP=0.760 microR=0.254 microF1=0.381
# Val:   loss=0.0535  microP=0.742 microR=0.219 microF1=0.338
#
# Epoch 76/200
#   step 100/478  loss=0.0482  lr=0.071287
#   step 200/478  loss=0.0481  lr=0.071134
#   step 300/478  loss=0.0481  lr=0.070981
#   step 400/478  loss=0.0480  lr=0.070828
# Train: loss=0.0481  microP=0.762 microR=0.255 microF1=0.383
# Val:   loss=0.0541  microP=0.664 microR=0.259 microF1=0.372
#
# Epoch 77/200
#   step 100/478  loss=0.0475  lr=0.070555
#   step 200/478  loss=0.0478  lr=0.070401
#   step 300/478  loss=0.0482  lr=0.070247
#   step 400/478  loss=0.0480  lr=0.070093
# Train: loss=0.0480  microP=0.759 microR=0.258 microF1=0.385
# Val:   loss=0.0532  microP=0.697 microR=0.245 microF1=0.362
#
# Epoch 78/200
#   step 100/478  loss=0.0480  lr=0.069818
#   step 200/478  loss=0.0480  lr=0.069663
#   step 300/478  loss=0.0479  lr=0.069508
#   step 400/478  loss=0.0478  lr=0.069353
# Train: loss=0.0479  microP=0.764 microR=0.258 microF1=0.386
# Val:   loss=0.0531  microP=0.717 microR=0.227 microF1=0.345
#
# Epoch 79/200
#   step 100/478  loss=0.0476  lr=0.069076
#   step 200/478  loss=0.0479  lr=0.068920
#   step 300/478  loss=0.0476  lr=0.068764
#   step 400/478  loss=0.0478  lr=0.068608
# Train: loss=0.0478  microP=0.763 microR=0.258 microF1=0.386
# Val:   loss=0.0526  microP=0.715 microR=0.245 microF1=0.365
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 80/200
#   step 100/478  loss=0.0477  lr=0.068329
#   step 200/478  loss=0.0475  lr=0.068172
#   step 300/478  loss=0.0477  lr=0.068015
#   step 400/478  loss=0.0478  lr=0.067858
# Train: loss=0.0476  microP=0.764 microR=0.263 microF1=0.391
# Val:   loss=0.0527  microP=0.708 microR=0.252 microF1=0.372
#
# Epoch 81/200
#   step 100/478  loss=0.0475  lr=0.067577
#   step 200/478  loss=0.0475  lr=0.067420
#   step 300/478  loss=0.0477  lr=0.067261
#   step 400/478  loss=0.0477  lr=0.067103
# Train: loss=0.0476  microP=0.764 microR=0.262 microF1=0.390
# Val:   loss=0.0526  microP=0.703 microR=0.253 microF1=0.372
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 82/200
#   step 100/478  loss=0.0473  lr=0.066821
#   step 200/478  loss=0.0475  lr=0.066662
#   step 300/478  loss=0.0476  lr=0.066503
#   step 400/478  loss=0.0476  lr=0.066344
# Train: loss=0.0475  microP=0.763 microR=0.265 microF1=0.393
# Val:   loss=0.0524  microP=0.743 microR=0.239 microF1=0.362
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 83/200
#   step 100/478  loss=0.0476  lr=0.066060
#   step 200/478  loss=0.0475  lr=0.065901
#   step 300/478  loss=0.0475  lr=0.065741
#   step 400/478  loss=0.0473  lr=0.065581
# Train: loss=0.0473  microP=0.765 microR=0.266 microF1=0.394
# Val:   loss=0.0533  microP=0.694 microR=0.249 microF1=0.366
#
# Epoch 84/200
#   step 100/478  loss=0.0469  lr=0.065296
#   step 200/478  loss=0.0469  lr=0.065135
#   step 300/478  loss=0.0473  lr=0.064974
#   step 400/478  loss=0.0473  lr=0.064813
# Train: loss=0.0474  microP=0.763 microR=0.269 microF1=0.398
# Val:   loss=0.0527  microP=0.748 microR=0.227 microF1=0.348
#
# Epoch 85/200
#   step 100/478  loss=0.0474  lr=0.064527
#   step 200/478  loss=0.0471  lr=0.064365
#   step 300/478  loss=0.0472  lr=0.064204
#   step 400/478  loss=0.0473  lr=0.064042
# Train: loss=0.0471  microP=0.766 microR=0.268 microF1=0.397
# Val:   loss=0.0532  microP=0.699 microR=0.245 microF1=0.363
#
# Epoch 86/200
#   step 100/478  loss=0.0471  lr=0.063754
#   step 200/478  loss=0.0470  lr=0.063592
#   step 300/478  loss=0.0470  lr=0.063430
#   step 400/478  loss=0.0470  lr=0.063267
# Train: loss=0.0470  microP=0.769 microR=0.269 microF1=0.399
# Val:   loss=0.0522  microP=0.686 microR=0.265 microF1=0.382
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 87/200
#   step 100/478  loss=0.0478  lr=0.062978
#   step 200/478  loss=0.0471  lr=0.062815
#   step 300/478  loss=0.0469  lr=0.062652
#   step 400/478  loss=0.0468  lr=0.062489
# Train: loss=0.0470  microP=0.769 microR=0.272 microF1=0.401
# Val:   loss=0.0521  microP=0.699 microR=0.267 microF1=0.387
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 88/200
#   step 100/478  loss=0.0461  lr=0.062199
#   step 200/478  loss=0.0461  lr=0.062035
#   step 300/478  loss=0.0466  lr=0.061871
#   step 400/478  loss=0.0469  lr=0.061708
# Train: loss=0.0469  microP=0.767 microR=0.271 microF1=0.401
# Val:   loss=0.0531  microP=0.725 microR=0.236 microF1=0.356
#
# Epoch 89/200
#   step 100/478  loss=0.0476  lr=0.061416
#   step 200/478  loss=0.0472  lr=0.061252
#   step 300/478  loss=0.0472  lr=0.061087
#   step 400/478  loss=0.0468  lr=0.060923
# Train: loss=0.0468  microP=0.768 microR=0.274 microF1=0.404
# Val:   loss=0.0530  microP=0.682 microR=0.264 microF1=0.380
#
# Epoch 90/200
#   step 100/478  loss=0.0464  lr=0.060630
#   step 200/478  loss=0.0463  lr=0.060465
#   step 300/478  loss=0.0465  lr=0.060301
#   step 400/478  loss=0.0466  lr=0.060136
# Train: loss=0.0466  microP=0.772 microR=0.275 microF1=0.405
# Val:   loss=0.0523  microP=0.692 microR=0.264 microF1=0.382
#
# Epoch 91/200
#   step 100/478  loss=0.0462  lr=0.059842
#   step 200/478  loss=0.0461  lr=0.059677
#   step 300/478  loss=0.0465  lr=0.059511
#   step 400/478  loss=0.0465  lr=0.059346
# Train: loss=0.0465  microP=0.771 microR=0.277 microF1=0.407
# Val:   loss=0.0527  microP=0.765 microR=0.216 microF1=0.337
#
# Epoch 92/200
#   step 100/478  loss=0.0460  lr=0.059051
#   step 200/478  loss=0.0462  lr=0.058885
#   step 300/478  loss=0.0465  lr=0.058719
#   step 400/478  loss=0.0463  lr=0.058553
# Train: loss=0.0465  microP=0.774 microR=0.278 microF1=0.409
# Val:   loss=0.0514  microP=0.726 microR=0.254 microF1=0.376
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 93/200
#   step 100/478  loss=0.0465  lr=0.058258
#   step 200/478  loss=0.0460  lr=0.058091
#   step 300/478  loss=0.0463  lr=0.057925
#   step 400/478  loss=0.0464  lr=0.057759
# Train: loss=0.0463  microP=0.771 microR=0.281 microF1=0.411
# Val:   loss=0.0524  microP=0.740 microR=0.240 microF1=0.362
#
# Epoch 94/200
#   step 100/478  loss=0.0457  lr=0.057462
#   step 200/478  loss=0.0460  lr=0.057295
#   step 300/478  loss=0.0462  lr=0.057129
#   step 400/478  loss=0.0462  lr=0.056962
# Train: loss=0.0463  microP=0.774 microR=0.281 microF1=0.413
# Val:   loss=0.0531  microP=0.677 microR=0.253 microF1=0.369
#
# Epoch 95/200
#   step 100/478  loss=0.0466  lr=0.056665
#   step 200/478  loss=0.0464  lr=0.056498
#   step 300/478  loss=0.0462  lr=0.056331
#   step 400/478  loss=0.0462  lr=0.056163
# Train: loss=0.0462  microP=0.771 microR=0.281 microF1=0.412
# Val:   loss=0.0533  microP=0.652 microR=0.274 microF1=0.386
#
# Epoch 96/200
#   step 100/478  loss=0.0455  lr=0.055866
#   step 200/478  loss=0.0461  lr=0.055698
#   step 300/478  loss=0.0464  lr=0.055531
#   step 400/478  loss=0.0462  lr=0.055363
# Train: loss=0.0462  microP=0.770 microR=0.281 microF1=0.412
# Val:   loss=0.0515  microP=0.711 microR=0.269 microF1=0.391
#
# Epoch 97/200
#   step 100/478  loss=0.0456  lr=0.055065
#   step 200/478  loss=0.0459  lr=0.054897
#   step 300/478  loss=0.0460  lr=0.054730
#   step 400/478  loss=0.0461  lr=0.054562
# Train: loss=0.0461  microP=0.774 microR=0.282 microF1=0.414
# Val:   loss=0.0516  microP=0.722 microR=0.249 microF1=0.370
#
# Epoch 98/200
#   step 100/478  loss=0.0454  lr=0.054263
#   step 200/478  loss=0.0458  lr=0.054095
#   step 300/478  loss=0.0459  lr=0.053927
#   step 400/478  loss=0.0459  lr=0.053759
# Train: loss=0.0459  microP=0.773 microR=0.284 microF1=0.416
# Val:   loss=0.0515  microP=0.703 microR=0.271 microF1=0.391
#
# Epoch 99/200
#   step 100/478  loss=0.0451  lr=0.053460
#   step 200/478  loss=0.0451  lr=0.053292
#   step 300/478  loss=0.0454  lr=0.053124
#   step 400/478  loss=0.0456  lr=0.052955
# Train: loss=0.0458  microP=0.775 microR=0.286 microF1=0.418
# Val:   loss=0.0517  microP=0.683 microR=0.278 microF1=0.396
#
# Epoch 100/200
#   step 100/478  loss=0.0460  lr=0.052656
#   step 200/478  loss=0.0459  lr=0.052488
#   step 300/478  loss=0.0455  lr=0.052319
#   step 400/478  loss=0.0457  lr=0.052151
# Train: loss=0.0457  microP=0.774 microR=0.287 microF1=0.419
# Val:   loss=0.0512  microP=0.748 microR=0.245 microF1=0.369
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 101/200
#   step 100/478  loss=0.0458  lr=0.051851
#   step 200/478  loss=0.0456  lr=0.051683
#   step 300/478  loss=0.0455  lr=0.051515
#   step 400/478  loss=0.0455  lr=0.051346
# Train: loss=0.0456  microP=0.773 microR=0.288 microF1=0.420
# Val:   loss=0.0519  microP=0.752 microR=0.242 microF1=0.366
#
# Epoch 102/200
#   step 100/478  loss=0.0453  lr=0.051046
#   step 200/478  loss=0.0453  lr=0.050878
#   step 300/478  loss=0.0456  lr=0.050709
#   step 400/478  loss=0.0457  lr=0.050541
# Train: loss=0.0456  microP=0.779 microR=0.290 microF1=0.422
# Val:   loss=0.0514  microP=0.715 microR=0.267 microF1=0.389
#
# Epoch 103/200
#   step 100/478  loss=0.0451  lr=0.050241
#   step 200/478  loss=0.0449  lr=0.050072
#   step 300/478  loss=0.0451  lr=0.049904
#   step 400/478  loss=0.0453  lr=0.049735
# Train: loss=0.0454  microP=0.777 microR=0.292 microF1=0.424
# Val:   loss=0.0515  microP=0.706 microR=0.275 microF1=0.396
#
# Epoch 104/200
#   step 100/478  loss=0.0453  lr=0.049435
#   step 200/478  loss=0.0455  lr=0.049267
#   step 300/478  loss=0.0455  lr=0.049098
#   step 400/478  loss=0.0453  lr=0.048930
# Train: loss=0.0454  microP=0.774 microR=0.290 microF1=0.422
# Val:   loss=0.0522  microP=0.728 microR=0.249 microF1=0.371
#
# Epoch 105/200
#   step 100/478  loss=0.0454  lr=0.048630
#   step 200/478  loss=0.0454  lr=0.048462
#   step 300/478  loss=0.0455  lr=0.048293
#   step 400/478  loss=0.0455  lr=0.048125
# Train: loss=0.0453  microP=0.777 microR=0.292 microF1=0.424
# Val:   loss=0.0514  microP=0.701 microR=0.270 microF1=0.389
#
# Epoch 106/200
#   step 100/478  loss=0.0452  lr=0.047825
#   step 200/478  loss=0.0449  lr=0.047657
#   step 300/478  loss=0.0451  lr=0.047489
#   step 400/478  loss=0.0451  lr=0.047320
# Train: loss=0.0452  microP=0.779 microR=0.298 microF1=0.431
# Val:   loss=0.0521  microP=0.737 microR=0.243 microF1=0.365
#
# Epoch 107/200
#   step 100/478  loss=0.0443  lr=0.047021
#   step 200/478  loss=0.0450  lr=0.046853
#   step 300/478  loss=0.0452  lr=0.046685
#   step 400/478  loss=0.0451  lr=0.046516
# Train: loss=0.0451  microP=0.782 microR=0.297 microF1=0.431
# Val:   loss=0.0513  microP=0.728 microR=0.262 microF1=0.385
#
# Epoch 108/200
#   step 100/478  loss=0.0447  lr=0.046217
#   step 200/478  loss=0.0448  lr=0.046049
#   step 300/478  loss=0.0448  lr=0.045881
#   step 400/478  loss=0.0449  lr=0.045713
# Train: loss=0.0450  microP=0.780 microR=0.295 microF1=0.428
# Val:   loss=0.0514  microP=0.720 microR=0.246 microF1=0.367
#
# Epoch 109/200
#   step 100/478  loss=0.0447  lr=0.045415
#   step 200/478  loss=0.0449  lr=0.045247
#   step 300/478  loss=0.0445  lr=0.045079
#   step 400/478  loss=0.0446  lr=0.044912
# Train: loss=0.0449  microP=0.782 microR=0.299 microF1=0.432
# Val:   loss=0.0511  microP=0.682 microR=0.302 microF1=0.418
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 110/200
#   step 100/478  loss=0.0449  lr=0.044613
#   step 200/478  loss=0.0452  lr=0.044446
#   step 300/478  loss=0.0450  lr=0.044278
#   step 400/478  loss=0.0451  lr=0.044111
# Train: loss=0.0450  microP=0.780 microR=0.297 microF1=0.431
# Val:   loss=0.0511  microP=0.720 microR=0.263 microF1=0.385
#
# Epoch 111/200
#   step 100/478  loss=0.0442  lr=0.043813
#   step 200/478  loss=0.0442  lr=0.043646
#   step 300/478  loss=0.0444  lr=0.043479
#   step 400/478  loss=0.0448  lr=0.043312
# Train: loss=0.0448  microP=0.780 microR=0.301 microF1=0.434
# Val:   loss=0.0511  microP=0.713 microR=0.287 microF1=0.409
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 112/200
#   step 100/478  loss=0.0451  lr=0.043015
#   step 200/478  loss=0.0444  lr=0.042848
#   step 300/478  loss=0.0444  lr=0.042681
#   step 400/478  loss=0.0445  lr=0.042515
# Train: loss=0.0446  microP=0.783 microR=0.300 microF1=0.434
# Val:   loss=0.0507  microP=0.711 microR=0.282 microF1=0.404
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 113/200
#   step 100/478  loss=0.0448  lr=0.042218
#   step 200/478  loss=0.0445  lr=0.042052
#   step 300/478  loss=0.0445  lr=0.041885
#   step 400/478  loss=0.0447  lr=0.041719
# Train: loss=0.0445  microP=0.784 microR=0.303 microF1=0.437
# Val:   loss=0.0511  microP=0.719 microR=0.271 microF1=0.393
#
# Epoch 114/200
#   step 100/478  loss=0.0449  lr=0.041424
#   step 200/478  loss=0.0445  lr=0.041258
#   step 300/478  loss=0.0444  lr=0.041092
#   step 400/478  loss=0.0445  lr=0.040926
# Train: loss=0.0445  microP=0.781 microR=0.305 microF1=0.439
# Val:   loss=0.0509  microP=0.718 microR=0.272 microF1=0.395
#
# Epoch 115/200
#   step 100/478  loss=0.0440  lr=0.040631
#   step 200/478  loss=0.0440  lr=0.040466
#   step 300/478  loss=0.0444  lr=0.040300
#   step 400/478  loss=0.0445  lr=0.040135
# Train: loss=0.0445  microP=0.775 microR=0.303 microF1=0.435
# Val:   loss=0.0505  microP=0.729 microR=0.263 microF1=0.387
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 116/200
#   step 100/478  loss=0.0432  lr=0.039841
#   step 200/478  loss=0.0439  lr=0.039676
#   step 300/478  loss=0.0439  lr=0.039512
#   step 400/478  loss=0.0441  lr=0.039347
# Train: loss=0.0443  microP=0.784 microR=0.306 microF1=0.441
# Val:   loss=0.0507  microP=0.727 microR=0.269 microF1=0.393
#
# Epoch 117/200
#   step 100/478  loss=0.0445  lr=0.039054
#   step 200/478  loss=0.0444  lr=0.038890
#   step 300/478  loss=0.0443  lr=0.038725
#   step 400/478  loss=0.0444  lr=0.038561
# Train: loss=0.0443  microP=0.786 microR=0.306 microF1=0.440
# Val:   loss=0.0512  microP=0.702 microR=0.275 microF1=0.395
#
# Epoch 118/200
#   step 100/478  loss=0.0438  lr=0.038270
#   step 200/478  loss=0.0439  lr=0.038106
#   step 300/478  loss=0.0439  lr=0.037942
#   step 400/478  loss=0.0442  lr=0.037779
# Train: loss=0.0442  microP=0.783 microR=0.309 microF1=0.444
# Val:   loss=0.0510  microP=0.747 microR=0.246 microF1=0.370
#
# Epoch 119/200
#   step 100/478  loss=0.0439  lr=0.037488
#   step 200/478  loss=0.0442  lr=0.037325
#   step 300/478  loss=0.0440  lr=0.037162
#   step 400/478  loss=0.0440  lr=0.036999
# Train: loss=0.0440  microP=0.784 microR=0.311 microF1=0.446
# Val:   loss=0.0516  microP=0.743 microR=0.247 microF1=0.371
#
# Epoch 120/200
#   step 100/478  loss=0.0435  lr=0.036710
#   step 200/478  loss=0.0440  lr=0.036548
#   step 300/478  loss=0.0441  lr=0.036385
#   step 400/478  loss=0.0441  lr=0.036223
# Train: loss=0.0440  microP=0.784 microR=0.311 microF1=0.445
# Val:   loss=0.0507  microP=0.705 microR=0.285 microF1=0.406
#
# Epoch 121/200
#   step 100/478  loss=0.0439  lr=0.035935
#   step 200/478  loss=0.0438  lr=0.035774
#   step 300/478  loss=0.0438  lr=0.035612
#   step 400/478  loss=0.0439  lr=0.035451
# Train: loss=0.0440  microP=0.786 microR=0.311 microF1=0.446
# Val:   loss=0.0511  microP=0.727 microR=0.259 microF1=0.382
#
# Epoch 122/200
#   step 100/478  loss=0.0435  lr=0.035164
#   step 200/478  loss=0.0437  lr=0.035003
#   step 300/478  loss=0.0439  lr=0.034843
#   step 400/478  loss=0.0438  lr=0.034682
# Train: loss=0.0438  microP=0.785 microR=0.311 microF1=0.446
# Val:   loss=0.0519  microP=0.725 microR=0.266 microF1=0.389
#
# Epoch 123/200
#   step 100/478  loss=0.0437  lr=0.034397
#   step 200/478  loss=0.0439  lr=0.034237
#   step 300/478  loss=0.0440  lr=0.034077
#   step 400/478  loss=0.0438  lr=0.033918
# Train: loss=0.0438  microP=0.782 microR=0.311 microF1=0.445
# Val:   loss=0.0506  microP=0.699 microR=0.290 microF1=0.410
#
# Epoch 124/200
#   step 100/478  loss=0.0432  lr=0.033634
#   step 200/478  loss=0.0433  lr=0.033475
#   step 300/478  loss=0.0434  lr=0.033316
#   step 400/478  loss=0.0436  lr=0.033157
# Train: loss=0.0436  microP=0.787 microR=0.314 microF1=0.448
# Val:   loss=0.0508  microP=0.715 microR=0.276 microF1=0.398
#
# Epoch 125/200
#   step 100/478  loss=0.0425  lr=0.032875
#   step 200/478  loss=0.0430  lr=0.032717
#   step 300/478  loss=0.0434  lr=0.032559
#   step 400/478  loss=0.0434  lr=0.032401
# Train: loss=0.0435  microP=0.791 microR=0.316 microF1=0.452
# Val:   loss=0.0504  microP=0.714 microR=0.284 microF1=0.406
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 126/200
#   step 100/478  loss=0.0430  lr=0.032121
#   step 200/478  loss=0.0433  lr=0.031963
#   step 300/478  loss=0.0434  lr=0.031806
#   step 400/478  loss=0.0434  lr=0.031650
# Train: loss=0.0435  microP=0.787 microR=0.318 microF1=0.453
# Val:   loss=0.0506  microP=0.721 microR=0.281 microF1=0.404
#
# Epoch 127/200
#   step 100/478  loss=0.0431  lr=0.031371
#   step 200/478  loss=0.0434  lr=0.031215
#   step 300/478  loss=0.0432  lr=0.031059
#   step 400/478  loss=0.0433  lr=0.030903
# Train: loss=0.0434  microP=0.790 microR=0.317 microF1=0.453
# Val:   loss=0.0506  microP=0.739 microR=0.270 microF1=0.396
#
# Epoch 128/200
#   step 100/478  loss=0.0428  lr=0.030626
#   step 200/478  loss=0.0429  lr=0.030471
#   step 300/478  loss=0.0431  lr=0.030316
#   step 400/478  loss=0.0432  lr=0.030161
# Train: loss=0.0432  microP=0.789 microR=0.320 microF1=0.456
# Val:   loss=0.0505  microP=0.723 microR=0.280 microF1=0.404
#
# Epoch 129/200
#   step 100/478  loss=0.0424  lr=0.029886
#   step 200/478  loss=0.0432  lr=0.029732
#   step 300/478  loss=0.0431  lr=0.029578
#   step 400/478  loss=0.0431  lr=0.029424
# Train: loss=0.0432  microP=0.786 microR=0.320 microF1=0.455
# Val:   loss=0.0508  microP=0.712 microR=0.286 microF1=0.409
#
# Epoch 130/200
#   step 100/478  loss=0.0428  lr=0.029151
#   step 200/478  loss=0.0429  lr=0.028998
#   step 300/478  loss=0.0428  lr=0.028845
#   step 400/478  loss=0.0429  lr=0.028693
# Train: loss=0.0431  microP=0.793 microR=0.322 microF1=0.458
# Val:   loss=0.0505  microP=0.704 microR=0.308 microF1=0.428
#
# Epoch 131/200
#   step 100/478  loss=0.0433  lr=0.028422
#   step 200/478  loss=0.0430  lr=0.028270
#   step 300/478  loss=0.0429  lr=0.028118
#   step 400/478  loss=0.0429  lr=0.027967
# Train: loss=0.0430  microP=0.793 microR=0.325 microF1=0.461
# Val:   loss=0.0498  microP=0.714 microR=0.299 microF1=0.421
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 132/200
#   step 100/478  loss=0.0421  lr=0.027698
#   step 200/478  loss=0.0427  lr=0.027548
#   step 300/478  loss=0.0430  lr=0.027397
#   step 400/478  loss=0.0429  lr=0.027247
# Train: loss=0.0429  microP=0.791 microR=0.324 microF1=0.460
# Val:   loss=0.0498  microP=0.723 microR=0.287 microF1=0.411
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 133/200
#   step 100/478  loss=0.0423  lr=0.026980
#   step 200/478  loss=0.0425  lr=0.026831
#   step 300/478  loss=0.0425  lr=0.026682
#   step 400/478  loss=0.0429  lr=0.026533
# Train: loss=0.0429  microP=0.791 microR=0.325 microF1=0.461
# Val:   loss=0.0504  microP=0.734 microR=0.277 microF1=0.403
#
# Epoch 134/200
#   step 100/478  loss=0.0424  lr=0.026268
#   step 200/478  loss=0.0428  lr=0.026120
#   step 300/478  loss=0.0428  lr=0.025972
#   step 400/478  loss=0.0428  lr=0.025825
# Train: loss=0.0427  microP=0.790 microR=0.326 microF1=0.462
# Val:   loss=0.0506  microP=0.720 microR=0.281 microF1=0.404
#
# Epoch 135/200
#   step 100/478  loss=0.0421  lr=0.025563
#   step 200/478  loss=0.0425  lr=0.025416
#   step 300/478  loss=0.0427  lr=0.025269
#   step 400/478  loss=0.0425  lr=0.025123
# Train: loss=0.0427  microP=0.790 microR=0.327 microF1=0.463
# Val:   loss=0.0498  microP=0.714 microR=0.294 microF1=0.417
#
# Epoch 136/200
#   step 100/478  loss=0.0427  lr=0.024863
#   step 200/478  loss=0.0427  lr=0.024718
#   step 300/478  loss=0.0426  lr=0.024572
#   step 400/478  loss=0.0426  lr=0.024428
# Train: loss=0.0426  microP=0.793 microR=0.329 microF1=0.465
# Val:   loss=0.0504  microP=0.709 microR=0.290 microF1=0.412
#
# Epoch 137/200
#   step 100/478  loss=0.0432  lr=0.024170
#   step 200/478  loss=0.0428  lr=0.024026
#   step 300/478  loss=0.0429  lr=0.023882
#   step 400/478  loss=0.0427  lr=0.023739
# Train: loss=0.0426  microP=0.795 microR=0.329 microF1=0.465
# Val:   loss=0.0502  microP=0.749 microR=0.266 microF1=0.392
#
# Epoch 138/200
#   step 100/478  loss=0.0424  lr=0.023484
#   step 200/478  loss=0.0424  lr=0.023341
#   step 300/478  loss=0.0423  lr=0.023199
#   step 400/478  loss=0.0424  lr=0.023057
# Train: loss=0.0425  microP=0.793 microR=0.329 microF1=0.465
# Val:   loss=0.0500  microP=0.724 microR=0.279 microF1=0.403
#
# Epoch 139/200
#   step 100/478  loss=0.0422  lr=0.022805
#   step 200/478  loss=0.0423  lr=0.022664
#   step 300/478  loss=0.0423  lr=0.022523
#   step 400/478  loss=0.0423  lr=0.022382
# Train: loss=0.0424  microP=0.795 microR=0.332 microF1=0.468
# Val:   loss=0.0508  microP=0.698 microR=0.287 microF1=0.407
#
# Epoch 140/200
#   step 100/478  loss=0.0417  lr=0.022132
#   step 200/478  loss=0.0419  lr=0.021993
#   step 300/478  loss=0.0421  lr=0.021853
#   step 400/478  loss=0.0422  lr=0.021714
# Train: loss=0.0422  microP=0.795 microR=0.333 microF1=0.470
# Val:   loss=0.0505  microP=0.740 microR=0.271 microF1=0.397
#
# Epoch 141/200
#   step 100/478  loss=0.0417  lr=0.021467
#   step 200/478  loss=0.0417  lr=0.021329
#   step 300/478  loss=0.0419  lr=0.021191
#   step 400/478  loss=0.0420  lr=0.021054
# Train: loss=0.0422  microP=0.794 microR=0.333 microF1=0.469
# Val:   loss=0.0499  microP=0.707 microR=0.295 microF1=0.417
#
# Epoch 142/200
#   step 100/478  loss=0.0419  lr=0.020810
#   step 200/478  loss=0.0423  lr=0.020673
#   step 300/478  loss=0.0422  lr=0.020537
#   step 400/478  loss=0.0422  lr=0.020401
# Train: loss=0.0421  microP=0.797 microR=0.332 microF1=0.469
# Val:   loss=0.0497  microP=0.736 microR=0.284 microF1=0.410
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 143/200
#   step 100/478  loss=0.0417  lr=0.020160
#   step 200/478  loss=0.0418  lr=0.020025
#   step 300/478  loss=0.0421  lr=0.019890
#   step 400/478  loss=0.0421  lr=0.019756
# Train: loss=0.0421  microP=0.797 microR=0.336 microF1=0.472
# Val:   loss=0.0504  microP=0.728 microR=0.270 microF1=0.394
#
# Epoch 144/200
#   step 100/478  loss=0.0417  lr=0.019518
#   step 200/478  loss=0.0419  lr=0.019384
#   step 300/478  loss=0.0420  lr=0.019251
#   step 400/478  loss=0.0420  lr=0.019118
# ...
#   step 400/478  loss=0.0414  lr=0.014891
# Train: loss=0.0414  microP=0.800 microR=0.343 microF1=0.480
# Val:   loss=0.0496  microP=0.729 microR=0.292 microF1=0.417
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 152/200
#   step 100/478  loss=0.0415  lr=0.014678
#   step 200/478  loss=0.0410  lr=0.014559
#   step 300/478  loss=0.0415  lr=0.014440
#   step 400/478  loss=0.0414  lr=0.014322
# Train: loss=0.0414  microP=0.800 microR=0.344 microF1=0.481
# Val:   loss=0.0501  microP=0.719 microR=0.287 microF1=0.411
#
# Epoch 153/200
#   step 100/478  loss=0.0412  lr=0.014112
#   step 200/478  loss=0.0412  lr=0.013995
#   step 300/478  loss=0.0415  lr=0.013879
#   step 400/478  loss=0.0413  lr=0.013762
# Train: loss=0.0412  microP=0.802 microR=0.345 microF1=0.482
# Val:   loss=0.0502  microP=0.711 microR=0.294 microF1=0.416
#
# Epoch 154/200
#   step 100/478  loss=0.0408  lr=0.013556
#   step 200/478  loss=0.0410  lr=0.013441
#   step 300/478  loss=0.0410  lr=0.013326
#   step 400/478  loss=0.0412  lr=0.013212
# Train: loss=0.0412  microP=0.802 microR=0.346 microF1=0.484
# Val:   loss=0.0501  microP=0.726 microR=0.280 microF1=0.404
#
# Epoch 155/200
#   step 100/478  loss=0.0413  lr=0.013010
#   step 200/478  loss=0.0414  lr=0.012897
#   step 300/478  loss=0.0412  lr=0.012784
#   step 400/478  loss=0.0410  lr=0.012672
# Train: loss=0.0411  microP=0.802 microR=0.347 microF1=0.484
# Val:   loss=0.0499  microP=0.709 microR=0.304 microF1=0.425
#
# Epoch 156/200
#   step 100/478  loss=0.0407  lr=0.012473
#   step 200/478  loss=0.0408  lr=0.012362
#   step 300/478  loss=0.0408  lr=0.012251
#   step 400/478  loss=0.0409  lr=0.012141
# Train: loss=0.0411  microP=0.802 microR=0.346 microF1=0.483
# Val:   loss=0.0497  microP=0.731 microR=0.292 microF1=0.418
#
# Epoch 157/200
#   step 100/478  loss=0.0406  lr=0.011946
#   step 200/478  loss=0.0408  lr=0.011837
#   step 300/478  loss=0.0408  lr=0.011728
#   step 400/478  loss=0.0409  lr=0.011620
# Train: loss=0.0410  microP=0.803 microR=0.350 microF1=0.487
# Val:   loss=0.0496  microP=0.725 microR=0.290 microF1=0.414
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 158/200
#   step 100/478  loss=0.0405  lr=0.011428
#   step 200/478  loss=0.0405  lr=0.011321
#   step 300/478  loss=0.0406  lr=0.011215
#   step 400/478  loss=0.0410  lr=0.011109
# Train: loss=0.0409  microP=0.803 microR=0.348 microF1=0.486
# Val:   loss=0.0494  microP=0.745 microR=0.286 microF1=0.413
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 159/200
#   step 100/478  loss=0.0402  lr=0.010921
#   step 200/478  loss=0.0410  lr=0.010816
#   step 300/478  loss=0.0409  lr=0.010712
#   step 400/478  loss=0.0407  lr=0.010608
# Train: loss=0.0409  microP=0.802 microR=0.350 microF1=0.487
# Val:   loss=0.0497  microP=0.686 microR=0.324 microF1=0.441
#
# Epoch 160/200
#   step 100/478  loss=0.0412  lr=0.010424
#   step 200/478  loss=0.0409  lr=0.010321
#   step 300/478  loss=0.0409  lr=0.010219
#   step 400/478  loss=0.0407  lr=0.010117
# Train: loss=0.0407  microP=0.806 microR=0.352 microF1=0.490
# Val:   loss=0.0494  microP=0.729 microR=0.296 microF1=0.421
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 161/200
#   step 100/478  loss=0.0406  lr=0.009937
#   step 200/478  loss=0.0406  lr=0.009836
#   step 300/478  loss=0.0408  lr=0.009736
#   step 400/478  loss=0.0407  lr=0.009637
# Train: loss=0.0407  microP=0.808 microR=0.353 microF1=0.491
# Val:   loss=0.0493  microP=0.715 microR=0.309 microF1=0.431
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 162/200
#   step 100/478  loss=0.0402  lr=0.009460
#   step 200/478  loss=0.0401  lr=0.009362
#   step 300/478  loss=0.0403  lr=0.009264
#   step 400/478  loss=0.0406  lr=0.009167
# Train: loss=0.0406  microP=0.806 microR=0.352 microF1=0.490
# Val:   loss=0.0494  microP=0.728 microR=0.306 microF1=0.431
#
# Epoch 163/200
#   step 100/478  loss=0.0400  lr=0.008994
#   step 200/478  loss=0.0403  lr=0.008898
#   step 300/478  loss=0.0405  lr=0.008803
#   step 400/478  loss=0.0405  lr=0.008707
# Train: loss=0.0406  microP=0.805 microR=0.353 microF1=0.491
# Val:   loss=0.0494  microP=0.735 microR=0.294 microF1=0.420
#
# Epoch 164/200
#   step 100/478  loss=0.0402  lr=0.008539
#   step 200/478  loss=0.0404  lr=0.008445
#   step 300/478  loss=0.0404  lr=0.008352
#   step 400/478  loss=0.0405  lr=0.008259
# Train: loss=0.0404  microP=0.806 microR=0.356 microF1=0.494
# Val:   loss=0.0493  microP=0.728 microR=0.303 microF1=0.428
#
# Epoch 165/200
#   step 100/478  loss=0.0407  lr=0.008094
#   step 200/478  loss=0.0405  lr=0.008003
#   step 300/478  loss=0.0404  lr=0.007912
#   step 400/478  loss=0.0404  lr=0.007821
# Train: loss=0.0404  microP=0.809 microR=0.356 microF1=0.495
# Val:   loss=0.0494  microP=0.734 microR=0.295 microF1=0.421
#
# Epoch 166/200
#   step 100/478  loss=0.0401  lr=0.007661
#   step 200/478  loss=0.0401  lr=0.007571
#   step 300/478  loss=0.0403  lr=0.007483
#   step 400/478  loss=0.0405  lr=0.007394
# Train: loss=0.0403  microP=0.810 microR=0.358 microF1=0.496
# Val:   loss=0.0494  microP=0.737 microR=0.291 microF1=0.417
#
# Epoch 167/200
#   step 100/478  loss=0.0401  lr=0.007238
#   step 200/478  loss=0.0400  lr=0.007151
#   step 300/478  loss=0.0402  lr=0.007065
#   step 400/478  loss=0.0402  lr=0.006978
# Train: loss=0.0402  microP=0.810 microR=0.359 microF1=0.497
# Val:   loss=0.0496  microP=0.718 microR=0.302 microF1=0.425
#
# Epoch 168/200
#   step 100/478  loss=0.0401  lr=0.006826
#   step 200/478  loss=0.0400  lr=0.006742
#   step 300/478  loss=0.0401  lr=0.006658
#   step 400/478  loss=0.0401  lr=0.006574
# Train: loss=0.0402  microP=0.809 microR=0.359 microF1=0.497
# Val:   loss=0.0495  microP=0.714 microR=0.303 microF1=0.426
#
# Epoch 169/200
#   step 100/478  loss=0.0401  lr=0.006426
#   step 200/478  loss=0.0400  lr=0.006344
#   step 300/478  loss=0.0401  lr=0.006262
#   step 400/478  loss=0.0401  lr=0.006181
# Train: loss=0.0401  microP=0.808 microR=0.360 microF1=0.498
# Val:   loss=0.0491  microP=0.735 microR=0.297 microF1=0.423
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 170/200
#   step 100/478  loss=0.0399  lr=0.006037
#   step 200/478  loss=0.0400  lr=0.005957
#   step 300/478  loss=0.0399  lr=0.005878
#   step 400/478  loss=0.0399  lr=0.005799
# Train: loss=0.0400  microP=0.812 microR=0.360 microF1=0.499
# Val:   loss=0.0492  microP=0.744 microR=0.297 microF1=0.424
#
# Epoch 171/200
#   step 100/478  loss=0.0402  lr=0.005659
#   step 200/478  loss=0.0400  lr=0.005582
#   step 300/478  loss=0.0401  lr=0.005505
#   step 400/478  loss=0.0401  lr=0.005428
# Train: loss=0.0400  microP=0.813 microR=0.361 microF1=0.500
# Val:   loss=0.0493  microP=0.721 microR=0.306 microF1=0.429
#
# Epoch 172/200
#   step 100/478  loss=0.0403  lr=0.005293
#   step 200/478  loss=0.0399  lr=0.005218
#   step 300/478  loss=0.0400  lr=0.005143
#   step 400/478  loss=0.0399  lr=0.005069
# Train: loss=0.0399  microP=0.813 microR=0.362 microF1=0.501
# Val:   loss=0.0493  microP=0.697 microR=0.316 microF1=0.435
#
# Epoch 173/200
#   step 100/478  loss=0.0397  lr=0.004939
#   step 200/478  loss=0.0396  lr=0.004866
#   step 300/478  loss=0.0397  lr=0.004794
#   step 400/478  loss=0.0398  lr=0.004722
# Train: loss=0.0398  microP=0.815 microR=0.362 microF1=0.501
# Val:   loss=0.0494  microP=0.704 microR=0.317 microF1=0.437
#
# Epoch 174/200
#   step 100/478  loss=0.0397  lr=0.004596
#   step 200/478  loss=0.0396  lr=0.004526
#   step 300/478  loss=0.0397  lr=0.004456
#   step 400/478  loss=0.0397  lr=0.004387
# Train: loss=0.0399  microP=0.813 microR=0.364 microF1=0.503
# Val:   loss=0.0491  microP=0.721 microR=0.306 microF1=0.429
#
# Epoch 175/200
#   step 100/478  loss=0.0396  lr=0.004265
#   step 200/478  loss=0.0397  lr=0.004197
#   step 300/478  loss=0.0397  lr=0.004130
#   step 400/478  loss=0.0397  lr=0.004063
# Train: loss=0.0398  microP=0.816 microR=0.365 microF1=0.504
# Val:   loss=0.0491  microP=0.734 microR=0.299 microF1=0.425
#
# Epoch 176/200
#   step 100/478  loss=0.0390  lr=0.003945
#   step 200/478  loss=0.0396  lr=0.003880
#   step 300/478  loss=0.0396  lr=0.003815
#   step 400/478  loss=0.0397  lr=0.003751
# Train: loss=0.0398  microP=0.812 microR=0.364 microF1=0.503
# Val:   loss=0.0489  microP=0.714 microR=0.317 microF1=0.439
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 177/200
#   step 100/478  loss=0.0405  lr=0.003638
#   step 200/478  loss=0.0398  lr=0.003575
#   step 300/478  loss=0.0398  lr=0.003513
#   step 400/478  loss=0.0398  lr=0.003452
# Train: loss=0.0396  microP=0.818 microR=0.364 microF1=0.504
# Val:   loss=0.0492  microP=0.705 microR=0.317 microF1=0.437
#
# Epoch 178/200
#   step 100/478  loss=0.0397  lr=0.003343
#   step 200/478  loss=0.0397  lr=0.003283
#   step 300/478  loss=0.0395  lr=0.003223
#   step 400/478  loss=0.0396  lr=0.003164
# Train: loss=0.0396  microP=0.818 microR=0.366 microF1=0.506
# Val:   loss=0.0493  microP=0.732 microR=0.299 microF1=0.424
#
# Epoch 179/200
#   step 100/478  loss=0.0392  lr=0.003060
#   step 200/478  loss=0.0397  lr=0.003002
#   step 300/478  loss=0.0395  lr=0.002945
#   step 400/478  loss=0.0395  lr=0.002888
# Train: loss=0.0395  microP=0.818 microR=0.366 microF1=0.506
# Val:   loss=0.0489  microP=0.720 microR=0.312 microF1=0.436
#
# Epoch 180/200
#   step 100/478  loss=0.0398  lr=0.002789
#   step 200/478  loss=0.0396  lr=0.002734
#   step 300/478  loss=0.0397  lr=0.002679
#   step 400/478  loss=0.0396  lr=0.002625
# Train: loss=0.0396  microP=0.817 microR=0.365 microF1=0.505
# Val:   loss=0.0489  microP=0.725 microR=0.307 microF1=0.432
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 181/200
#   step 100/478  loss=0.0395  lr=0.002530
#   step 200/478  loss=0.0393  lr=0.002478
#   step 300/478  loss=0.0395  lr=0.002426
#   step 400/478  loss=0.0395  lr=0.002374
# Train: loss=0.0395  microP=0.813 microR=0.366 microF1=0.505
# Val:   loss=0.0489  microP=0.736 microR=0.302 microF1=0.429
#
# Epoch 182/200
#   step 100/478  loss=0.0399  lr=0.002284
#   step 200/478  loss=0.0393  lr=0.002234
#   step 300/478  loss=0.0394  lr=0.002185
#   step 400/478  loss=0.0394  lr=0.002136
# Train: loss=0.0395  microP=0.822 microR=0.366 microF1=0.506
# Val:   loss=0.0490  microP=0.727 microR=0.304 microF1=0.429
#
# Epoch 183/200
#   step 100/478  loss=0.0391  lr=0.002050
#   step 200/478  loss=0.0394  lr=0.002003
#   step 300/478  loss=0.0394  lr=0.001956
#   step 400/478  loss=0.0393  lr=0.001910
# Train: loss=0.0394  microP=0.819 microR=0.368 microF1=0.508
# Val:   loss=0.0492  microP=0.719 microR=0.310 microF1=0.433
#
# Epoch 184/200
#   step 100/478  loss=0.0391  lr=0.001829
#   step 200/478  loss=0.0392  lr=0.001784
#   step 300/478  loss=0.0392  lr=0.001740
#   step 400/478  loss=0.0391  lr=0.001696
# Train: loss=0.0394  microP=0.818 microR=0.369 microF1=0.509
# Val:   loss=0.0489  microP=0.729 microR=0.307 microF1=0.432
#
# Epoch 185/200
#   step 100/478  loss=0.0392  lr=0.001620
#   step 200/478  loss=0.0391  lr=0.001577
#   step 300/478  loss=0.0392  lr=0.001536
#   step 400/478  loss=0.0393  lr=0.001495
# Train: loss=0.0392  microP=0.820 microR=0.370 microF1=0.510
# Val:   loss=0.0489  microP=0.730 microR=0.306 microF1=0.431
#
# Epoch 186/200
#   step 100/478  loss=0.0390  lr=0.001423
#   step 200/478  loss=0.0391  lr=0.001384
#   step 300/478  loss=0.0391  lr=0.001345
#   step 400/478  loss=0.0392  lr=0.001306
# Train: loss=0.0393  microP=0.820 microR=0.367 microF1=0.507
# Val:   loss=0.0489  microP=0.735 microR=0.302 microF1=0.428
#
# Epoch 187/200
#   step 100/478  loss=0.0394  lr=0.001239
#   step 200/478  loss=0.0393  lr=0.001202
#   step 300/478  loss=0.0393  lr=0.001166
#   step 400/478  loss=0.0394  lr=0.001130
# Train: loss=0.0394  microP=0.820 microR=0.368 microF1=0.508
# Val:   loss=0.0490  microP=0.727 microR=0.308 microF1=0.433
#
# Epoch 188/200
#   step 100/478  loss=0.0390  lr=0.001068
#   step 200/478  loss=0.0392  lr=0.001034
#   step 300/478  loss=0.0392  lr=0.001000
#   step 400/478  loss=0.0392  lr=0.000967
# Train: loss=0.0392  microP=0.819 microR=0.370 microF1=0.510
# Val:   loss=0.0489  microP=0.714 microR=0.315 microF1=0.437
#
# Epoch 189/200
#   step 100/478  loss=0.0384  lr=0.000910
#   step 200/478  loss=0.0389  lr=0.000878
#   step 300/478  loss=0.0391  lr=0.000847
#   step 400/478  loss=0.0392  lr=0.000817
# Train: loss=0.0392  microP=0.817 microR=0.370 microF1=0.509
# Val:   loss=0.0489  microP=0.720 microR=0.310 microF1=0.434
#
# Epoch 190/200
#   step 100/478  loss=0.0391  lr=0.000764
#   step 200/478  loss=0.0389  lr=0.000735
#   step 300/478  loss=0.0389  lr=0.000707
#   step 400/478  loss=0.0390  lr=0.000679
# Train: loss=0.0391  microP=0.825 microR=0.370 microF1=0.511
# Val:   loss=0.0489  microP=0.710 microR=0.314 microF1=0.435
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 191/200
#   step 100/478  loss=0.0389  lr=0.000631
#   step 200/478  loss=0.0389  lr=0.000605
#   step 300/478  loss=0.0391  lr=0.000579
#   step 400/478  loss=0.0392  lr=0.000554
# Train: loss=0.0391  microP=0.820 microR=0.369 microF1=0.509
# Val:   loss=0.0488  microP=0.719 microR=0.311 microF1=0.435
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 192/200
#   step 100/478  loss=0.0393  lr=0.000511
#   step 200/478  loss=0.0392  lr=0.000487
#   step 300/478  loss=0.0390  lr=0.000464
#   step 400/478  loss=0.0391  lr=0.000442
# Train: loss=0.0391  microP=0.819 microR=0.372 microF1=0.511
# Val:   loss=0.0489  microP=0.721 microR=0.309 microF1=0.433
#
# Epoch 193/200
#   step 100/478  loss=0.0392  lr=0.000404
#   step 200/478  loss=0.0391  lr=0.000383
#   step 300/478  loss=0.0391  lr=0.000362
#   step 400/478  loss=0.0392  lr=0.000343
# Train: loss=0.0391  microP=0.821 microR=0.371 microF1=0.511
# Val:   loss=0.0488  microP=0.720 microR=0.312 microF1=0.435
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 194/200
#   step 100/478  loss=0.0385  lr=0.000309
#   step 200/478  loss=0.0390  lr=0.000291
#   step 300/478  loss=0.0389  lr=0.000273
#   step 400/478  loss=0.0390  lr=0.000256
# Train: loss=0.0390  microP=0.822 microR=0.372 microF1=0.512
# Val:   loss=0.0489  microP=0.718 microR=0.311 microF1=0.434
#
# Epoch 195/200
#   step 100/478  loss=0.0388  lr=0.000228
#   step 200/478  loss=0.0387  lr=0.000212
#   step 300/478  loss=0.0388  lr=0.000197
#   step 400/478  loss=0.0389  lr=0.000183
# Train: loss=0.0390  microP=0.823 microR=0.373 microF1=0.513
# Val:   loss=0.0488  microP=0.717 microR=0.311 microF1=0.434
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 196/200
#   step 100/478  loss=0.0390  lr=0.000159
#   step 200/478  loss=0.0388  lr=0.000146
#   step 300/478  loss=0.0390  lr=0.000134
#   step 400/478  loss=0.0391  lr=0.000123
# Train: loss=0.0390  microP=0.821 microR=0.373 microF1=0.513
# Val:   loss=0.0488  microP=0.723 microR=0.312 microF1=0.436
#   ✅ Saved best checkpoint: cornet_z_identification_model_big_200/20260116_110503/best.pt
#
# Epoch 197/200
#   step 100/478  loss=0.0388  lr=0.000103
#   step 200/478  loss=0.0389  lr=0.000093
#   step 300/478  loss=0.0391  lr=0.000084
#   step 400/478  loss=0.0390  lr=0.000075
# Train: loss=0.0390  microP=0.822 microR=0.371 microF1=0.512
# Val:   loss=0.0488  microP=0.719 microR=0.313 microF1=0.436
#
# Epoch 198/200
#   step 100/478  loss=0.0390  lr=0.000061
#   step 200/478  loss=0.0390  lr=0.000053
#   step 300/478  loss=0.0391  lr=0.000047
#   step 400/478  loss=0.0391  lr=0.000040
# Train: loss=0.0391  microP=0.823 microR=0.371 microF1=0.511
# Val:   loss=0.0488  microP=0.720 microR=0.313 microF1=0.437
#
# Epoch 199/200
#   step 100/478  loss=0.0386  lr=0.000031
#   step 200/478  loss=0.0389  lr=0.000026
#   step 300/478  loss=0.0388  lr=0.000022
#   step 400/478  loss=0.0388  lr=0.000019
# Train: loss=0.0389  microP=0.825 microR=0.374 microF1=0.514
# Val:   loss=0.0488  microP=0.719 microR=0.313 microF1=0.436
#
# Epoch 200/200
#   step 100/478  loss=0.0385  lr=0.000014
#   step 200/478  loss=0.0388  lr=0.000012
#   step 300/478  loss=0.0388  lr=0.000011
#   step 400/478  loss=0.0388  lr=0.000010
# Train: loss=0.0389  microP=0.824 microR=0.373 microF1=0.514
# Val:   loss=0.0488  microP=0.720 microR=0.313 microF1=0.437

# %%
from pathlib import Path

# assuming TRAIN_JSON and TRAIN_IMG_DIR are already set
import json

with open(TRAIN_JSON, "r") as f:
    coco = json.load(f)

missing = []
for im in coco["images"]:
    p = Path(TRAIN_IMG_DIR) / im["file_name"]
    if not p.exists():
        missing.append(im["file_name"])

print("Missing files:", len(missing))
print("First 20 missing:", missing[:20])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 # assuming TRAIN_JSON and TRAIN_IMG_DIR are already set
#       4 import json
# ----> 6 with open(TRAIN_JSON, "r") as f:
#       7     coco = json.load(f)
#       9 missing = []
#
# NameError: name 'TRAIN_JSON' is not defined

# %%
import sys
from pathlib import Path
import torch
import torch.nn as nn

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("DEVICE:", DEVICE)

# ---- EDIT THESE TWO PATHS ----
CORN_NET_REPO = Path("/zpool/vladlab/active_drive/omaltz/git_repos/CORnet")  # folder you cloned
BEST_CKPT = Path("/zpool/vladlab/active_drive/omaltz/scripts/geogaze/coco_scripts/models/cornet_z_identification_model_big_200/best.pt")  # your checkpoint

# Make CORnet importable
sys.path.insert(0, str(CORN_NET_REPO))
import cornet
print("Imported cornet from:", cornet.__file__)

# Load checkpoint
ckpt = torch.load(BEST_CKPT, map_location=DEVICE)
index_to_name = ckpt.get("index_to_name", None)
if index_to_name is None:
    raise RuntimeError("Checkpoint missing index_to_name. (Was it saved with the provided training loop?)")
num_classes = len(index_to_name)
print("num_classes:", num_classes)

def replace_last_linear(model: nn.Module, num_classes: int):
    last_name, last_linear = None, None
    for name, module in model.named_modules():
        if isinstance(module, nn.Linear):
            last_name, last_linear = name, module
    if last_linear is None:
        raise RuntimeError("No nn.Linear layer found in CORnet-Z.")
    parent = model
    parts = last_name.split(".")
    for p in parts[:-1]:
        parent = getattr(parent, p)
    setattr(parent, parts[-1], nn.Linear(last_linear.in_features, num_classes))
    print(f"Replaced final layer: {last_name} -> {num_classes} outputs")
    return model

# Rebuild architecture (random init) then load YOUR trained weights
model = cornet.cornet_z(pretrained=False)
model = replace_last_linear(model, num_classes)
model.load_state_dict(ckpt["model_state"], strict=True)
model = model.to(DEVICE).eval()

print("Loaded trained model from:", BEST_CKPT)
# Out:
# DEVICE: cuda
# Imported cornet from: /zpool/vladlab/active_drive/omaltz/git_repos/CORnet/cornet/__init__.py
# num_classes: 80
# Replaced final layer: module.decoder.linear -> 80 outputs
# Loaded trained model from: /zpool/vladlab/active_drive/omaltz/scripts/geogaze/coco_scripts/models/cornet_z_identification_model_big_200/best.pt

# %%
from PIL import Image
import torchvision.transforms as T

IMG_SIZE = 224  # must match training

eval_tfms = T.Compose([
    T.Resize((IMG_SIZE, IMG_SIZE)),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225]),
])

def load_image_tensor(image_path: str | Path):
    image_path = Path(image_path)
    img = Image.open(image_path).convert("RGB")
    x = eval_tfms(img).unsqueeze(0)  # (1,3,H,W)
    return x, img

# %%
import torch

def predict_one(image_path: str | Path, threshold: float = 0.3, topk: int = 10):
    x, img_pil = load_image_tensor(image_path)
    x = x.to(DEVICE)

    with torch.no_grad():
        logits = model(x)                 # (1, 80)
        probs = torch.sigmoid(logits)[0]  # (80,)

    # Top-k classes (ranked)
    topk = min(topk, probs.numel())
    top_vals, top_idx = torch.topk(probs, k=topk)
    top = [(int(i), index_to_name[int(i)], float(v)) for v, i in zip(top_vals.cpu(), top_idx.cpu())]

    # Thresholded present classes
    present_idx = torch.where(probs >= threshold)[0].cpu().tolist()
    present = [(i, index_to_name[i], float(probs[i].cpu())) for i in present_idx]
    present.sort(key=lambda t: t[2], reverse=True)

    return img_pil, top, present

TEST_IMG = "/zpool/vladlab/data_drive/stimulus_sets/geogaze_COCO_stim/coco_working/working_v2/val_working2/000000001296.jpg"  # EDIT
img_pil, top, present = predict_one(TEST_IMG, threshold=0.2, topk=10)

print("Top-10:")
for i, name, p in top:
    print(f"  {i:02d} {name:>15s}  {p:.3f}")

print("\nPredicted present (>=0.2):")
for i, name, p in present:
    print(f"  {i:02d} {name:>15s}  {p:.3f}")
# Out:
# Top-10:
#   60    dining table  0.282
#   41             cup  0.235
#   77      teddy bear  0.114
#   16             dog  0.099
#   54           donut  0.094
#   45            bowl  0.064
#   59             bed  0.062
#   40      wine glass  0.057
#   17           horse  0.054
#   55            cake  0.050
#
# Predicted present (>=0.2):
#   60    dining table  0.282
#   41             cup  0.235

# %%
import matplotlib.pyplot as plt

def show_prediction(img_pil, present, max_lines=12):
    plt.figure(figsize=(6,6))
    plt.imshow(img_pil)
    plt.axis("off")

    # Only show class names (no probabilities)
    lines = [f"{name}" for _, name, _ in present[:max_lines]]

    title = "Predicted present:\n" + (
        "\n".join(lines) if lines else "(none above threshold)"
    )

    plt.title(title, fontsize=10)
    plt.tight_layout()
    plt.show()

show_prediction(img_pil, present)

# %%
import random
from pathlib import Path
import matplotlib.pyplot as plt

def show_prediction_grid_with_top10(
    folder_path: str | Path,
    rows: int = 10,
    cols: int = 10,
    threshold: float = 0.3,
    topk: int = 10,
    seed: int | None = None,
    exts = (".jpg", ".jpeg", ".png"),
    figsize_per_cell: float = 2.6,
    text_fontsize: int = 7,
):
    folder = Path(folder_path)
    if seed is not None:
        random.seed(seed)

    # Collect images
    image_paths = []
    for ext in exts:
        image_paths.extend(folder.glob(f"*{ext}"))

    total = rows * cols
    if len(image_paths) < total:
        raise ValueError(f"Folder has only {len(image_paths)} images, need {total}")

    chosen = random.sample(image_paths, total)

    fig, axes = plt.subplots(
        rows, cols,
        figsize=(cols * figsize_per_cell, rows * figsize_per_cell * 1.35)
    )
    axes = axes.flatten()

    for ax, img_path in zip(axes, chosen):
        img_pil, top, present = predict_one(
            img_path, threshold=threshold, topk=topk
        )

        # Show image
        ax.imshow(img_pil)
        ax.axis("off")

        # ---- Build text block ----
        lines = []

        # Predicted present
        if present:
            present_lines = [f"{name} ({prob:.2f})" for _, name, prob in present[:4]]
            lines.append("Present: " + ", ".join(present_lines))
        else:
            lines.append("Present: none ≥ thr")

        # Top-k (one per line)
        top_lines = [f"{name} ({prob:.2f})" for _, name, prob in top[:topk]]
        lines.append("\n" + "\n".join(top_lines))


        text = "\n".join(lines)

        # ---- Place text BELOW image ----
        ax.text(
            0.5, -0.18, text,
            ha="center", va="top",
            transform=ax.transAxes,
            fontsize=text_fontsize,
            wrap=True
        )

    plt.subplots_adjust(hspace=0.55, wspace=0.25)
    plt.show()

# %%
TEST_FOLDER = "/zpool/vladlab/data_drive/stimulus_sets/geogaze_COCO_stim/coco_working/working_v3/val_working3"  

show_prediction_grid_with_top10(
    TEST_FOLDER,
    rows=1,
    cols=3,
    threshold=0.1,
    topk=0,
    seed=222
)

# %%
import random
from pathlib import Path
import matplotlib.pyplot as plt

def show_prediction_grid_with_top10(
    folder_path: str | Path,
    rows: int = 10,
    cols: int = 10,
    threshold: float = 0.3,
    topk: int = 10,
    seed: int | None = None,
    exts = (".jpg", ".jpeg", ".png"),
    figsize_per_cell: float = 2.6,
    text_fontsize: int = 7,
):
    folder = Path(folder_path)
    if seed is not None:
        random.seed(seed)

    # Collect images
    image_paths = []
    for ext in exts:
        image_paths.extend(folder.glob(f"*{ext}"))

    total = rows * cols
    if len(image_paths) < total:
        raise ValueError(f"Folder has only {len(image_paths)} images, need {total}")

    chosen = random.sample(image_paths, total)

    fig, axes = plt.subplots(
        rows, cols,
        figsize=(cols * figsize_per_cell, rows * figsize_per_cell * 1.35)
    )
    axes = axes.flatten()

    for ax, img_path in zip(axes, chosen):
        img_pil, top, present = predict_one(
            img_path, threshold=threshold, topk=topk
        )

        # Show image
        ax.imshow(img_pil)
        ax.axis("off")

        # ---- Build text block ----
        lines = []

        # Predicted present (each label on its own line; NO probabilities)
        if present:
            present_names = [name for _, name, _ in present[:4]]
            lines.append("Present: " + present_names[0])
            for nm in present_names[1:]:
                lines.append(nm)
        else:
            lines.append("Present: none ≥ thr")

        # Top-k (optional; each on new line; NO probabilities)
        if topk and top:
            top_names = [name for _, name, _ in top[:topk]]
            lines.append("")  # blank line separator (keeps your same look)
            lines.extend(top_names)

        text = "\n".join(lines)

        # ---- Place text BELOW image ----
        ax.text(
            0.5, -0.18, text,
            ha="center", va="top",
            transform=ax.transAxes,
            fontsize=text_fontsize,
            wrap=True
        )

    plt.subplots_adjust(hspace=0.55, wspace=0.25)
    plt.show()

TEST_FOLDER = "/zpool/vladlab/data_drive/stimulus_sets/geogaze_COCO_stim/coco_working/working_v3/val_working3"

show_prediction_grid_with_top10(
    TEST_FOLDER,
    rows=1,
    cols=3,
    threshold=0.2,
    topk=0,      
    seed=340
)
